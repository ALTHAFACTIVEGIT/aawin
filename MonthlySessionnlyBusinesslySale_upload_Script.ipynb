# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from main.models import *
from report.models import *
from django.db.models import Sum
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
from datetime import datetime, timedelta

try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO

# %%
def upload_leakage_allowance(sold_to, month, year, session_id):
    print("Working on {} :entries".format(sold_to))
    bt_sales = DailySessionllyBusinessllySale.objects.filter(session_id=session_id, delivery_date__month=month,delivery_date__year=year,sold_to=sold_to)
    print(bt_sales)
#                 Create an User table entry for this Agent
    if bt_sales.count() > 0:
        msbts, created =  MonthlySessionllyBusinessllySale.objects.update_or_create(
            month=month,
            year=year,
            session_id=session_id,
            union=bt_sales[0].union,
            sold_to=sold_to,
            route=bt_sales[0].route,
            zone=bt_sales[0].zone,
            defaults = {
                'created_by':User.objects.get(username='kutobot'),
                'modified_by':User.objects.get(username='kutobot'),
                'total_cost' : bt_sales.aggregate(Sum('total_cost'))['total_cost__sum']

            }
        )
        if created:
            print("\tRow Created: {}\t{}\t{}\t".format(msbts.month, msbts.session, msbts.union))
        else:
            print("\tRow Exists: {}\t{}\t{}\t".format(msbts.month, msbts.session, msbts.union))


        # Now fill the route wise sum

        # Milk
        if getattr(MonthlySessionllyBusinessllySale, 'tm500_pkt', True):
            msbts.tm500_pkt = bt_sales.aggregate(Sum('tm500_pkt'))['tm500_pkt__sum']
            msbts.tm500_litre = bt_sales.aggregate(Sum('tm500_litre'))['tm500_litre__sum']
            msbts.tm500_cost = bt_sales.aggregate(Sum('tm500_cost'))['tm500_cost__sum']
            msbts.tm500_unit_price = bt_sales.aggregate(Sum('tm500_unit_price'))['tm500_unit_price__sum']


        if getattr(MonthlySessionllyBusinessllySale, 'std250_pkt', True):
            msbts.std250_pkt = bt_sales.aggregate(Sum('std250_pkt'))['std250_pkt__sum']
            msbts.std250_litre = bt_sales.aggregate(Sum('std250_litre'))['std250_litre__sum']
            msbts.std250_cost = bt_sales.aggregate(Sum('std250_cost'))['std250_cost__sum']
            msbts.std250_unit_price = bt_sales.aggregate(Sum('std250_unit_price'))['std250_unit_price__sum']


        if getattr(MonthlySessionllyBusinessllySale, 'std500_pkt', True):
            msbts.std500_pkt = bt_sales.aggregate(Sum('std500_pkt'))['std500_pkt__sum']
            msbts.std500_litre = bt_sales.aggregate(Sum('std500_litre'))['std500_litre__sum']
            msbts.std500_cost = bt_sales.aggregate(Sum('std500_cost'))['std500_cost__sum']
            msbts.std500_unit_price = bt_sales.aggregate(Sum('std500_unit_price'))['std500_unit_price__sum']


        if getattr(MonthlySessionllyBusinessllySale, 'fcm500_pkt', True):
            msbts.fcm500_pkt = bt_sales.aggregate(Sum('fcm500_pkt'))['fcm500_pkt__sum']   
            msbts.fcm500_litre = bt_sales.aggregate(Sum('fcm500_litre'))['fcm500_litre__sum']   
            msbts.fcm500_cost = bt_sales.aggregate(Sum('fcm500_cost'))['fcm500_cost__sum']   
            msbts.fcm500_unit_price = bt_sales.aggregate(Sum('fcm500_unit_price'))['fcm500_unit_price__sum']

        if getattr(MonthlySessionllyBusinessllySale, 'fcm1000_pkt', True):
            msbts.fcm1000_pkt = bt_sales.aggregate(Sum('fcm1000_pkt'))['fcm1000_pkt__sum']   
            msbts.fcm1000_litre = bt_sales.aggregate(Sum('fcm1000_litre'))['fcm1000_litre__sum']   
            msbts.fcm1000_cost = bt_sales.aggregate(Sum('fcm1000_cost'))['fcm1000_cost__sum']   
            msbts.fcm1000_unit_price = bt_sales.aggregate(Sum('fcm1000_unit_price'))['fcm1000_unit_price__sum']

        if getattr(MonthlySessionllyBusinessllySale, 'tmcan', True):
            msbts.tmcan = bt_sales.aggregate(Sum('tmcan'))['tmcan__sum']
            msbts.tmcan_litre = bt_sales.aggregate(Sum('tmcan_litre'))['tmcan_litre__sum']
            msbts.tmcan_cost = bt_sales.aggregate(Sum('tmcan_cost'))['tmcan_cost__sum']
            msbts.tmcan_unit_price = bt_sales.aggregate(Sum('tmcan_unit_price'))['tmcan_unit_price__sum']



        if getattr(MonthlySessionllyBusinessllySale, 'smcan', True):
            msbts.smcan = bt_sales.aggregate(Sum('smcan'))['smcan__sum']
            msbts.smcan_litre = bt_sales.aggregate(Sum('smcan_litre'))['smcan_litre__sum']
            msbts.smcan_cost = bt_sales.aggregate(Sum('smcan_cost'))['smcan_cost__sum']
            msbts.smcan_unit_price = bt_sales.aggregate(Sum('smcan_unit_price'))['smcan_unit_price__sum']

        if getattr(MonthlySessionllyBusinessllySale, 'fcmcan', True):
            msbts.fcmcan = bt_sales.aggregate(Sum('fcmcan'))['fcmcan__sum']
            msbts.fcmcan_litre = bt_sales.aggregate(Sum('fcmcan_litre'))['fcmcan_litre__sum']
            msbts.fcmcan_cost = bt_sales.aggregate(Sum('fcmcan_cost'))['fcmcan_cost__sum']
            msbts.fcmcan_unit_price = bt_sales.aggregate(Sum('fcmcan_unit_price'))['fcmcan_unit_price__sum']


        # Curd    
        if getattr(MonthlySessionllyBusinessllySale, 'curd500_pkt', True):
            msbts.curd500_pkt = bt_sales.aggregate(Sum('curd500_pkt'))['curd500_pkt__sum']
            msbts.curd500_kgs = bt_sales.aggregate(Sum('curd500_kgs'))['curd500_kgs__sum']
            msbts.curd500_cost = bt_sales.aggregate(Sum('curd500_cost'))['curd500_cost__sum']
            msbts.curd500_unit_price = bt_sales.aggregate(Sum('curd500_unit_price'))['curd500_unit_price__sum']


        if getattr(MonthlySessionllyBusinessllySale, 'curd150_pkt', True):
            msbts.curd150_pkt = bt_sales.aggregate(Sum('curd150_pkt'))['curd150_pkt__sum']
            msbts.curd150_kgs = bt_sales.aggregate(Sum('curd150_kgs'))['curd150_kgs__sum']
            msbts.curd150_cost = bt_sales.aggregate(Sum('curd150_cost'))['curd150_cost__sum']
            msbts.curd150_unit_price = bt_sales.aggregate(Sum('curd150_unit_price'))['curd150_unit_price__sum']

        if getattr(MonthlySessionllyBusinessllySale, 'cupcurd_box', True):
            msbts.cupcurd_box = bt_sales.aggregate(Sum('cupcurd_box'))['cupcurd_box__sum']
            msbts.cupcurd_count = bt_sales.aggregate(Sum('cupcurd_count'))['cupcurd_count__sum']
            msbts.cupcurd_kgs = bt_sales.aggregate(Sum('cupcurd_kgs'))['cupcurd_kgs__sum']
            msbts.cupcurd_cost = bt_sales.aggregate(Sum('cupcurd_cost'))['cupcurd_cost__sum']
            msbts.cupcurd_unit_price = bt_sales.aggregate(Sum('cupcurd_unit_price'))['cupcurd_unit_price__sum']

        if getattr(MonthlySessionllyBusinessllySale, 'curd_bucket', True):
            msbts.curd_bucket = bt_sales.aggregate(Sum('curd_bucket'))['curd_bucket__sum']
            msbts.curd_bucket_kgs = bt_sales.aggregate(Sum('curd_bucket_kgs'))['curd_bucket_kgs__sum']
            msbts.curd_bucket_cost = bt_sales.aggregate(Sum('curd_bucket_cost'))['curd_bucket_cost__sum']
            msbts.curd_bucket_unit_price = bt_sales.aggregate(Sum('curd_bucket_unit_price'))['curd_bucket_unit_price__sum']

        if getattr(MonthlySessionllyBusinessllySale, 'lassi200_pkt', True):
            msbts.lassi200_pkt = bt_sales.aggregate(Sum('lassi200_pkt'))['lassi200_pkt__sum']
            msbts.lassi200_kgs = bt_sales.aggregate(Sum('lassi200_kgs'))['lassi200_kgs__sum']
            msbts.lassi200_cost = bt_sales.aggregate(Sum('lassi200_cost'))['lassi200_cost__sum']
            msbts.lassi200_unit_price = bt_sales.aggregate(Sum('lassi200_unit_price'))['lassi200_unit_price__sum']

        if getattr(MonthlySessionllyBusinessllySale, 'buttermilk200_pkt', True):
            msbts.buttermilk200_pkt = bt_sales.aggregate(Sum('buttermilk200_pkt'))['buttermilk200_pkt__sum']
            msbts.buttermilk200_litre = bt_sales.aggregate(Sum('buttermilk200_litre'))['buttermilk200_litre__sum']
            msbts.buttermilk200_cost = bt_sales.aggregate(Sum('buttermilk200_cost'))['buttermilk200_cost__sum']
            msbts.buttermilk200_unit_price = bt_sales.aggregate(Sum('buttermilk200_unit_price'))['buttermilk200_unit_price__sum']

        msbts.tm_litre = bt_sales.aggregate(Sum('tm_litre'))['tm_litre__sum']
        msbts.tm_cost = bt_sales.aggregate(Sum('tm_cost'))['tm_cost__sum']
        msbts.sm_litre = bt_sales.aggregate(Sum('sm_litre'))['sm_litre__sum']
        msbts.sm_cost = bt_sales.aggregate(Sum('sm_cost'))['sm_cost__sum']
        msbts.fcm_litre = bt_sales.aggregate(Sum('fcm_litre'))['fcm_litre__sum']
        msbts.fcm_cost = bt_sales.aggregate(Sum('fcm_cost'))['fcm_cost__sum']
        msbts.milk_litre = bt_sales.aggregate(Sum('milk_litre'))['milk_litre__sum']
        msbts.milk_cost = bt_sales.aggregate(Sum('milk_cost'))['milk_cost__sum']
        msbts.curd_kgs = bt_sales.aggregate(Sum('curd_kgs'))['curd_kgs__sum']
        msbts.curd_cost = bt_sales.aggregate(Sum('curd_cost'))['curd_cost__sum']
        msbts.buttermilk_cost = bt_sales.aggregate(Sum('buttermilk_cost'))['buttermilk_cost__sum']
        msbts.buttermilk_litre = bt_sales.aggregate(Sum('buttermilk_litre'))['buttermilk_litre__sum']
        msbts.lassi_litre = bt_sales.aggregate(Sum('lassi_litre'))['lassi_litre__sum']
        msbts.lassi_cost = bt_sales.aggregate(Sum('lassi_cost'))['lassi_cost__sum']
        msbts.fermented_products_litre = bt_sales.aggregate(Sum('fermented_products_litre'))['fermented_products_litre__sum']
        msbts.fermented_products_cost = bt_sales.aggregate(Sum('fermented_products_cost'))['fermented_products_cost__sum']
        msbts.total_litre = bt_sales.aggregate(Sum('total_litre'))['total_litre__sum']
        msbts.save()

# %%
def upload_agent_and_customer_order(sold_to, month, year, session_id):
    print("Working on {} :entries".format(sold_to))
    for business in Business.objects.all():
        print("\tWorking on {}".format(business.name))
        # GET ALL business type WISE SALES
        bt_sales = DailySessionllyBusinessllySale.objects.filter(session_id=session_id, delivery_date__month=month,delivery_date__year=year,sold_to=sold_to, business=business)
        print(bt_sales)
#                 Create an User table entry for this Agent
        if bt_sales.count() > 0:
            msbts, created =  MonthlySessionllyBusinessllySale.objects.update_or_create(
                month=month,
                year=year,
                session_id=session_id,
                union=bt_sales[0].union,
                business=business,
                sold_to=sold_to,
                route=bt_sales[0].route,
                zone=bt_sales[0].zone,
                defaults = {
                    'created_by':User.objects.get(username='kutobot'),
                    'modified_by':User.objects.get(username='kutobot'),
                    'total_cost' : bt_sales.aggregate(Sum('total_cost'))['total_cost__sum']
                }
            )
            if created:
                print("\tRow Created: {}\t{}\t{}\t{}".format(msbts.month, msbts.session, msbts.union, msbts.business_type))
            else:
                print("\tRow Exists: {}\t{}\t{}\t{}".format(msbts.month, msbts.session, msbts.union, msbts.business_type))


            # Now fill the route wise sum

            # Milk
            if getattr(MonthlySessionllyBusinessllySale, 'tm500_pkt', True):
                msbts.tm500_pkt = bt_sales.aggregate(Sum('tm500_pkt'))['tm500_pkt__sum']
                msbts.tm500_litre = bt_sales.aggregate(Sum('tm500_litre'))['tm500_litre__sum']
                msbts.tm500_cost = bt_sales.aggregate(Sum('tm500_cost'))['tm500_cost__sum']
                msbts.tm500_unit_price = bt_sales.aggregate(Sum('tm500_unit_price'))['tm500_unit_price__sum']


            if getattr(MonthlySessionllyBusinessllySale, 'std250_pkt', True):
                msbts.std250_pkt = bt_sales.aggregate(Sum('std250_pkt'))['std250_pkt__sum']
                msbts.std250_litre = bt_sales.aggregate(Sum('std250_litre'))['std250_litre__sum']
                msbts.std250_cost = bt_sales.aggregate(Sum('std250_cost'))['std250_cost__sum']
                msbts.std250_unit_price = bt_sales.aggregate(Sum('std250_unit_price'))['std250_unit_price__sum']


            if getattr(MonthlySessionllyBusinessllySale, 'std500_pkt', True):
                msbts.std500_pkt = bt_sales.aggregate(Sum('std500_pkt'))['std500_pkt__sum']
                msbts.std500_litre = bt_sales.aggregate(Sum('std500_litre'))['std500_litre__sum']
                msbts.std500_cost = bt_sales.aggregate(Sum('std500_cost'))['std500_cost__sum']
                msbts.std500_unit_price = bt_sales.aggregate(Sum('std500_unit_price'))['std500_unit_price__sum']


            if getattr(MonthlySessionllyBusinessllySale, 'fcm500_pkt', True):
                msbts.fcm500_pkt = bt_sales.aggregate(Sum('fcm500_pkt'))['fcm500_pkt__sum']   
                msbts.fcm500_litre = bt_sales.aggregate(Sum('fcm500_litre'))['fcm500_litre__sum']   
                msbts.fcm500_cost = bt_sales.aggregate(Sum('fcm500_cost'))['fcm500_cost__sum']   
                msbts.fcm500_unit_price = bt_sales.aggregate(Sum('fcm500_unit_price'))['fcm500_unit_price__sum']

            if getattr(MonthlySessionllyBusinessllySale, 'fcm1000_pkt', True):
                msbts.fcm1000_pkt = bt_sales.aggregate(Sum('fcm1000_pkt'))['fcm1000_pkt__sum']   
                msbts.fcm1000_litre = bt_sales.aggregate(Sum('fcm1000_litre'))['fcm1000_litre__sum']   
                msbts.fcm1000_cost = bt_sales.aggregate(Sum('fcm1000_cost'))['fcm1000_cost__sum']   
                msbts.fcm1000_unit_price = bt_sales.aggregate(Sum('fcm1000_unit_price'))['fcm1000_unit_price__sum']

            if getattr(MonthlySessionllyBusinessllySale, 'tmcan', True):
                msbts.tmcan = bt_sales.aggregate(Sum('tmcan'))['tmcan__sum']
                msbts.tmcan_litre = bt_sales.aggregate(Sum('tmcan_litre'))['tmcan_litre__sum']
                msbts.tmcan_cost = bt_sales.aggregate(Sum('tmcan_cost'))['tmcan_cost__sum']
                msbts.tmcan_unit_price = bt_sales.aggregate(Sum('tmcan_unit_price'))['tmcan_unit_price__sum']



            if getattr(MonthlySessionllyBusinessllySale, 'smcan', True):
                msbts.smcan = bt_sales.aggregate(Sum('smcan'))['smcan__sum']
                msbts.smcan_litre = bt_sales.aggregate(Sum('smcan_litre'))['smcan_litre__sum']
                msbts.smcan_cost = bt_sales.aggregate(Sum('smcan_cost'))['smcan_cost__sum']
                msbts.smcan_unit_price = bt_sales.aggregate(Sum('smcan_unit_price'))['smcan_unit_price__sum']

            if getattr(MonthlySessionllyBusinessllySale, 'fcmcan', True):
                msbts.fcmcan = bt_sales.aggregate(Sum('fcmcan'))['fcmcan__sum']
                msbts.fcmcan_litre = bt_sales.aggregate(Sum('fcmcan_litre'))['fcmcan_litre__sum']
                msbts.fcmcan_cost = bt_sales.aggregate(Sum('fcmcan_cost'))['fcmcan_cost__sum']
                msbts.fcmcan_unit_price = bt_sales.aggregate(Sum('fcmcan_unit_price'))['fcmcan_unit_price__sum']


            # Curd    
            if getattr(MonthlySessionllyBusinessllySale, 'curd500_pkt', True):
                msbts.curd500_pkt = bt_sales.aggregate(Sum('curd500_pkt'))['curd500_pkt__sum']
                msbts.curd500_kgs = bt_sales.aggregate(Sum('curd500_kgs'))['curd500_kgs__sum']
                msbts.curd500_cost = bt_sales.aggregate(Sum('curd500_cost'))['curd500_cost__sum']
                msbts.curd500_unit_price = bt_sales.aggregate(Sum('curd500_unit_price'))['curd500_unit_price__sum']


            if getattr(MonthlySessionllyBusinessllySale, 'curd150_pkt', True):
                msbts.curd150_pkt = bt_sales.aggregate(Sum('curd150_pkt'))['curd150_pkt__sum']
                msbts.curd150_kgs = bt_sales.aggregate(Sum('curd150_kgs'))['curd150_kgs__sum']
                msbts.curd150_cost = bt_sales.aggregate(Sum('curd150_cost'))['curd150_cost__sum']
                msbts.curd150_unit_price = bt_sales.aggregate(Sum('curd150_unit_price'))['curd150_unit_price__sum']

            if getattr(MonthlySessionllyBusinessllySale, 'cupcurd_box', True):
                msbts.cupcurd_box = bt_sales.aggregate(Sum('cupcurd_box'))['cupcurd_box__sum']
                msbts.cupcurd_count = bt_sales.aggregate(Sum('cupcurd_count'))['cupcurd_count__sum']
                msbts.cupcurd_kgs = bt_sales.aggregate(Sum('cupcurd_kgs'))['cupcurd_kgs__sum']
                msbts.cupcurd_cost = bt_sales.aggregate(Sum('cupcurd_cost'))['cupcurd_cost__sum']
                msbts.cupcurd_unit_price = bt_sales.aggregate(Sum('cupcurd_unit_price'))['cupcurd_unit_price__sum']

            if getattr(MonthlySessionllyBusinessllySale, 'curd_bucket', True):
                msbts.curd_bucket = bt_sales.aggregate(Sum('curd_bucket'))['curd_bucket__sum']
                msbts.curd_bucket_kgs = bt_sales.aggregate(Sum('curd_bucket_kgs'))['curd_bucket_kgs__sum']
                msbts.curd_bucket_cost = bt_sales.aggregate(Sum('curd_bucket_cost'))['curd_bucket_cost__sum']
                msbts.curd_bucket_unit_price = bt_sales.aggregate(Sum('curd_bucket_unit_price'))['curd_bucket_unit_price__sum']

            if getattr(MonthlySessionllyBusinessllySale, 'lassi200_pkt', True):
                msbts.lassi200_pkt = bt_sales.aggregate(Sum('lassi200_pkt'))['lassi200_pkt__sum']
                msbts.lassi200_kgs = bt_sales.aggregate(Sum('lassi200_kgs'))['lassi200_kgs__sum']
                msbts.lassi200_cost = bt_sales.aggregate(Sum('lassi200_cost'))['lassi200_cost__sum']
                msbts.lassi200_unit_price = bt_sales.aggregate(Sum('lassi200_unit_price'))['lassi200_unit_price__sum']

            if getattr(MonthlySessionllyBusinessllySale, 'buttermilk200_pkt', True):
                msbts.buttermilk200_pkt = bt_sales.aggregate(Sum('buttermilk200_pkt'))['buttermilk200_pkt__sum']
                msbts.buttermilk200_litre = bt_sales.aggregate(Sum('buttermilk200_litre'))['buttermilk200_litre__sum']
                msbts.buttermilk200_cost = bt_sales.aggregate(Sum('buttermilk200_cost'))['buttermilk200_cost__sum']
                msbts.buttermilk200_unit_price = bt_sales.aggregate(Sum('buttermilk200_unit_price'))['buttermilk200_unit_price__sum']

            msbts.tm_litre = bt_sales.aggregate(Sum('tm_litre'))['tm_litre__sum']
            msbts.tm_cost = bt_sales.aggregate(Sum('tm_cost'))['tm_cost__sum']
            msbts.sm_litre = bt_sales.aggregate(Sum('sm_litre'))['sm_litre__sum']
            msbts.sm_cost = bt_sales.aggregate(Sum('sm_cost'))['sm_cost__sum']
            msbts.fcm_litre = bt_sales.aggregate(Sum('fcm_litre'))['fcm_litre__sum']
            msbts.fcm_cost = bt_sales.aggregate(Sum('fcm_cost'))['fcm_cost__sum']
            msbts.milk_litre = bt_sales.aggregate(Sum('milk_litre'))['milk_litre__sum']
            msbts.milk_cost = bt_sales.aggregate(Sum('milk_cost'))['milk_cost__sum']
            msbts.curd_kgs = bt_sales.aggregate(Sum('curd_kgs'))['curd_kgs__sum']
            msbts.curd_cost = bt_sales.aggregate(Sum('curd_cost'))['curd_cost__sum']
            msbts.buttermilk_cost = bt_sales.aggregate(Sum('buttermilk_cost'))['buttermilk_cost__sum']
            msbts.buttermilk_litre = bt_sales.aggregate(Sum('buttermilk_litre'))['buttermilk_litre__sum']
            msbts.lassi_litre = bt_sales.aggregate(Sum('lassi_litre'))['lassi_litre__sum']
            msbts.lassi_cost = bt_sales.aggregate(Sum('lassi_cost'))['lassi_cost__sum']
            msbts.fermented_products_litre = bt_sales.aggregate(Sum('fermented_products_litre'))['fermented_products_litre__sum']
            msbts.fermented_products_cost = bt_sales.aggregate(Sum('fermented_products_cost'))['fermented_products_cost__sum']
            msbts.total_litre = bt_sales.aggregate(Sum('total_litre'))['total_litre__sum']
            


            msbts.save()

# %%
sold_to_list = list(set(DailySessionllyBusinessllySale.objects.all().values_list('sold_to', flat=True)))
month = 5
year = 2020
for session in Session.objects.filter():
    if MonthlySessionllyBusinessllySale.objects.filter(session_id=session.id, month=month, year=year).exists():
        MonthlySessionllyBusinessllySale.objects.filter(session_id=session.id, month=month, year=year).delete()
        print('deleting {} - {}'.format(month, session.id))
for sold_to in sold_to_list:
    if sold_to == 'Leakage':
        print(' excecuting leakage allowance script')
        upload_leakage_allowance(sold_to, month, year, session.id)
    else:
        print('excecuting Agent or customer script')
        upload_agent_and_customer_order(sold_to, month, year, session.id)
# Out:
#  excecuting leakage allowance script
# Working on Leakage :entries
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union
# excecuting Agent or customer script
# Working on Agent :entries
# 	Working on 415 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 458 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 639 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 84 - Booth
# <QuerySet []>
# 	Working on 112 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 130 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 138 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 156 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 208 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 209 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 214 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 216 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 217 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 218 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 240 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 83 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 252 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 254 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 260 - Booth
# <QuerySet []>
# 	Working on 261 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 250 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 251 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 286 - Booth
# <QuerySet []>
# 	Working on 296 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 307 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 309 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 276 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 285 - Booth
# <QuerySet []>
# 	Working on 354 - Booth
# <QuerySet []>
# 	Working on 392 - Booth
# <QuerySet []>
# 	Working on 411 - Booth
# <QuerySet []>
# 	Working on 414 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 417 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 418 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 419 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 433 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 437 - Booth
# ...
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 493 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 499 - Booth
# <QuerySet []>
# 	Working on 655 - Booth
# <QuerySet []>
# 	Working on 750 - Booth
# <QuerySet []>
# 	Working on 803 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 1136 - Booth
# <QuerySet []>
# 	Working on 1225 - Booth
# <QuerySet []>
# 	Working on 1623 - Parlour
# <QuerySet []>
# 	Working on 1740 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 1756 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 1786 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 264 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 2675booth
# <QuerySet []>
# 	Working on 2668BOOTH
# <QuerySet []>
# 	Working on 9032WSD
# <QuerySet []>
# 	Working on 9032
# <QuerySet []>
# 	Working on 626 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 1233 - Booth
# <QuerySet []>
# 	Working on 1819 - Parlour
# <QuerySet []>
# 	Working on 8104 - Own parlour
# <QuerySet []>
# 	Working on 8105 - Own parlour
# <QuerySet []>
# 	Working on MTP Zone Leak Sale Counter
# <QuerySet []>
# 	Working on 2003 - COMBODIA MILL
# <QuerySet []>
# 	Working on 3017 - LG BALAKRISHNAN BROS
# <QuerySet []>
# 	Working on 4197 - ASST-COMR COPRN (RN PURAM 80FE
# <QuerySet []>
# 	Working on 4198 - ASST-COMR COPRN (MK PALAYAM AM
# <QuerySet []>
# 	Working on 1881 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 5531 - THE CHAIRMEN SIRUVANI MILK STO
# <QuerySet []>
# 	Working on 4214 - COMMISS-MUNICI(AMMA UNAVAGAM-P
# <QuerySet []>
# 	Working on 1981 - Parlour
# <QuerySet []>
# 	Working on 4216 - Amrita Vidyalayam, Nallampalay
# <QuerySet []>
# 	Working on 2115 - Booth
# <QuerySet []>
# 	Working on 2382 - Relaince Retail Ltd- Ramanatha
# <QuerySet []>
# 	Working on 2184 - Booth
# <QuerySet []>
# 	Working on 2212 - Booth
# <QuerySet []>
# 	Working on 2215 - Parlour
# <QuerySet []>
# 	Working on 2365 - Parlour
# <QuerySet []>
# 	Working on 2410 - Booth
# <QuerySet [<DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, <DailySessionllyBusinessllySale: DailySessionllyBusinessllySale object>, '...(remaining elements truncated)...']>
# 	Row Created: 5	Mor	COIMBATORE Union	None
# 	Working on 4259 - SHREEE ABOORVAS  PUR VEG RESTA
# <QuerySet []>

# %%
total = 0
for sale in DailySessionllyBusinessllySale.objects.filter(business__code=123, session_id=1):
    total +=sale.total_litre
total
# Out:
# Decimal('0.000')

# %%
MonthlySessionllyBusinessllySale.objects.filter(business__code=1, session_id=123).aggregate(Sum('total_litre'))
# Out:
# {'total_litre__sum': None}
