# %%
for business in BusinessWiseProductDiscount.objects.filter(business__business_type_id=10, product__group_id=1):
    print( business.business.code,business.product.short_name, business.discounted_price)
# Out:
# 20190 TM 500 20.62
# 21103 TM 500 20.62
# 21118 TM 500 21.50
# 21257 TM 500 21.50
# 20718 TM 500 20.62
# 20187 TM 500 20.62
# 21206 TM 500 20.62
# 23772 TM 500 20.62
# 20738 TM 500 20.62
# 22272 TM 500 20.62
# 28524 TM 500 20.62
# 21152 TM 500 20.62
# 20154 TM 500 20.62
# 20147 TM 500 20.62
# 20164 TM 500 20.62
# 29316 TM 500 20.62
# 20718 STD 500 22.54
# 20190 STD 500 22.54
# 21103 STD 500 22.54
# 21118 STD 500 22.50
# 21257 STD 500 22.50
# 23772 STD 500 22.60
# 20187 STD 500 22.54
# 21206 STD 500 22.54
# 20738 STD 500 22.54
# 22272 STD 500 22.54
# 28524 STD 500 22.54
# 21152 STD 500 22.54
# 20154 STD 500 22.54
# 20147 STD 500 22.54
# 20164 STD 500 22.54
# 29316 STD 500 22.54
# 20718 STD 250 11.51
# 20190 STD 250 11.51
# 21103 STD 250 11.51
# 21118 STD 250 12.00
# 21257 STD 250 12.00
# 20187 STD 250 11.51
# 21206 STD 250 11.51
# 23772 STD 250 11.51
# 20738 STD 250 11.51
# 22272 STD 250 11.51
# 28524 STD 250 11.51
# 21152 STD 250 11.51
# 20154 STD 250 11.51
# 20147 STD 250 11.51
# 20164 STD 250 11.51
# 29316 STD 250 11.51
# 20718 FCM 500 24.46
# 20190 FCM 500 24.46
# 21118 FCM 500 24.50
# 21257 FCM 500 24.50
# 21103 FCM 500 24.46
# 20187 FCM 500 24.46
# 21206 FCM 500 24.46
# 23772 FCM 500 24.46
# 20738 FCM 500 24.46
# 22272 FCM 500 24.46
# 28524 FCM 500 24.46
# 21152 FCM 500 24.46
# 20154 FCM 500 24.46
# 20147 FCM 500 24.46
# 20164 FCM 500 24.46
# 29316 FCM 500 24.46
# 20190 FCM 1000 48.91
# 20718 FCM 1000 48.91
# 21118 FCM 1000 49.00
# 21257 FCM 1000 49.00
# 21103 FCM 1000 48.91
# 20187 FCM 1000 48.91
# 21206 FCM 1000 48.91
# 23772 FCM 1000 48.91
# 20738 FCM 1000 48.91
# 22272 FCM 1000 48.91
# 28524 FCM 1000 48.91
# 21152 FCM 1000 48.91
# 20154 FCM 1000 48.91
# 20147 FCM 1000 48.91
# 20164 FCM 1000 48.91
# 29316 FCM 1000 48.91
