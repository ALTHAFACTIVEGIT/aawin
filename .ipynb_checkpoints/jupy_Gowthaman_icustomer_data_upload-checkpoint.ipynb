# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1QwSweXB3N7hOAIAeE2Y-yFkSbPGTG0w-zqVHE330sTE/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df.head(1)
# Out:
#    SNo CustomerCode CustomerCode032020 CustomerName032020    CustomerName  \
# 0    1    CBE100001          CBE100001     Shanmugham.A.M  Shanmugham.A.M
#
#              SupplyPointName  SupplyPointCode ZoneName       RouteName  \
# 0  NEAR AMMA MEDICALS(OPP.TO             1727     West  POOSARIPALAYAM
#
#                    DOB                                            Address  \
# 0  1947-09-14 00:00:00  9/3, Rama boyan thottam,\nNew Thillai Nagar,\n...
#
#        IDProof     IDProofNo  \
# 0  Ration Card  13/G/1304413
#
#                                       ContactAddress Telephone No MobileNo  \
# 0  9/3, Rama boyan thottam,\nNew Thillai Nagar,\n...      2442249  2442249
#
#    ZoneCode  RouteCode
# 0         4         21

# %%
row['DOB']

# %%
current_cust_code = "None"
jump="dont_skip"

# %%
# Loops saves the last seen id from spreadsheet. 
# If jump is set to "skip" it will not process any line until it comes across that line
# If you want to swtich off that behaviour set jump to "dont_skip"
jump="skip"

# %%
cust_type = ICustomerType.objects.get(name='Customer')
cust_user_type = UserType.objects.get(name='Icustomer')
union = Union.objects.get(id=1)
gender = Gender.objects.get(id=1)
taluk = Taluk.objects.get(id=4)
district = District.objects.get(id=1)
state = State.objects.get(id=1)

count = 0


for index, row in df.iterrows():
    count = count+1
    cust_code = row['CustomerCode']

    if 'CBE' in row['CustomerCode032020']:
        continueu
    
    if cust_code == current_cust_code:
        jump = "dont_skip"

    if jump == "skip":
        print(cust_code, 'Count:', count, "\t Skipped")
        continue
        
    current_cust_code = cust_code
    cust_name = row['CustomerName']
    first_name = cust_name
    last_name = ""
    if '.' in cust_name:
        [first_name, last_name] = cust_name.split('.', 1)

    
    cust_dob = row['DOB']
    cust_address = row['Address']
    cust_contact_address = row['ContactAddress']
    cust_id_type = row['IDProof']
    cust_id_value = row['IDProofNo']
    
    # contact info
    # Fill mobile number. if it is landline no (7 len) add 422 to it and fill
    # if there are two mobile numbers, add first to mobile sencond to alternate_phone.
    # if alternate mobile nummber and landline number exists, give pref to alternate_phone
    cust_phone = row['Telephone No']
    cust_mobile = row['MobileNo']
    cust_mobile_alt =""
    if ',' in cust_mobile:
        cust_mobile, cust_mobile_alt = cust_mobile.split(',')
    
    if '/' in cust_mobile:
        cust_mobile, cust_mobile_alt = cust_mobile.split('/')
    
    if len(cust_mobile_alt) > 7:
        cust_phone = cust_mobile_alt
    if len(cust_mobile) == 7:
        cust_mobile = int('0422' + str(cust_mobile))
    if not isinstance(cust_phone, float):
        if len(cust_phone) == 7:
            cust_phone = int('0422' + str(cust_phone))
    

    # delivery point
    bus_name = row['SupplyPointName']
    bus_code = row['SupplyPointCode'] 
        
    
    zone_name = row['ZoneName']
    zone_code = row['ZoneCode']
    route_name = row['RouteName']
    route_code= row['RouteCode']
    
    # Create an User table entry for this iCustomer
    cust_user, created =  User.objects.get_or_create(
        username=cust_mobile,
        defaults = {
            'password':make_password(cust_mobile),
            'first_name': first_name,
            'last_name': last_name,
            'is_staff': False,
            'is_active': True,
            'is_superuser': False,
        }
        
    )
    if created:
        print(cust_user.first_name, '(', cust_code, ')', 'Count:', count, "\n\tuser created")
    else:
        print(cust_user.first_name,  '(', cust_code, ')','Count:', count, "\n\tuser existed already")
        

    
    # Create new User Profile for this iCustomer
    cust_userprofile, created = UserProfile.objects.get_or_create(
        user=cust_user,
        defaults = {
            'union':union,
            'user_type':cust_user_type,
            'street':cust_address,
            'gender':gender,
            'taluk':taluk,
            'district':district,
            'state':state,
            'mobile':cust_mobile
            }
    )
    
    if created:
        print("\tuser profile created")
    else:
        print("\tuser profile existed already")
    
    if cust_phone:
        cust_userprofile.phone = cust_phone
        cust_userprofile.save()
        
    if cust_mobile_alt:
        cust_userprofile.alternate_mobile = cust_mobile_alt
        cust_userprofile.save()
        
    
    
    # Finally fill in the iCustomer table
    
    kyc_idproof_document_type = KycIDProofDocumentType.objects.get(name=cust_id_type) 
    
    new_icustomer, created = ICustomer.objects.get_or_create(
        user_profile=cust_userprofile,
        defaults = {    
            'customer_code':cust_code,
            'customer_type':cust_type,
            'is_business_approved':False,
            'kyc_idproof_document_type':kyc_idproof_document_type,
            'kyc_idproof_document_value':cust_id_value,
        }
    
    )

    if created:
        print("\tICustomer  created")
    else:
        print("\tICustomer  existed already")
        
        
    if cust_id_type == 'aadhar':
        new_icustomer.aadhar_number = cust_id_value
        new_icustomer.save()
    
    if Business.objects.filter(code=bus_code).exists():
        business = Business.objects.get(code=bus_code)
        new_icustomer.business=business
        new_icustomer.save()
        
    # Create wallet for each of the icustomer
    new_icustomer_wallet, created = ICustomerWallet.objects.get_or_create(
        customer=new_icustomer,
        defaults = {    
            'current_balance':0,
            'credit_limit':0
        }
    
    )  
    
    if created:
        print("\tWallet  created")
    else:
        print("\tWallet  existed already")
        
    print("=============================================")
# Out:
# Shanmugham ( CBE100001 ) Count: 1
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Parthasarathy ( CBE100010 ) Count: 2
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Chidambaram ( CBE100124 ) Count: 3
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Krishna Moorthy ( CBE101165 ) Count: 4
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Mahendar babu ( CBE118146 ) Count: 5
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# ANADARAJ ( CBE118147 ) Count: 6
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# RAMAKRISHNAN ( CBE118148 ) Count: 7
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# RUKMANI ( CBE118149 ) Count: 8
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# BALAKRISHNAN ( CBE118150 ) Count: 9
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# KALYANAKRISHNAN ( CBE118151 ) Count: 10
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# JOSEPH RAYAN ( CBE118152 ) Count: 11
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Aravind ( CBE118153 ) Count: 12
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Parbhakaran ( CBE118154 ) Count: 13
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Mohan Subramanian ( CBE118155 ) Count: 14
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Thangavelu ( CBE101166 ) Count: 15
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Sumesh Gupta ( CBE118156 ) Count: 16
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Mahalakshmi ( CBE118157 ) Count: 17
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Srinivasan ( CBE118158 ) Count: 18
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Gururajan ( CBE118159 ) Count: 19
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
#
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Mallika vellingiri ( CBE120022 ) Count: 604
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# S ( CBE120023 ) Count: 605
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# P ( CBE120024 ) Count: 606
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Dilip ( CBE120026 ) Count: 607
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# P ( CBE120027 ) Count: 608
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# S ( CBE120028 ) Count: 609
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# A ( CBE120029 ) Count: 610
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# Kamal ( CBE120030 ) Count: 611
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# K ( CBE120031 ) Count: 612
# 	user existed already
# 	user profile existed already
# 	ICustomer  existed already
# 	Wallet  existed already
# =============================================
# R ( CBE120033 ) Count: 613
# 	user created
# 	user profile created
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/query.py in get_or_create(self, defaults, **kwargs)
#     463         try:
# --> 464             return self.get(**lookup), False
#     465         except self.model.DoesNotExist:
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     379                 "%s matching query does not exist." %
# --> 380                 self.model._meta.object_name
#     381             )
#
# DoesNotExist: ICustomer matching query does not exist.
#
# During handling of the above exception, another exception occurred:
#
# UniqueViolation                           Traceback (most recent call last)
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#
# UniqueViolation: duplicate key value violates unique constraint "main_icustomer_customer_code_key"
# DETAIL:  Key (customer_code)=(CBE120033) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-114-01d91033e594> in <module>
#     129             'is_business_approved':False,
#     130             'kyc_idproof_document_type':kyc_idproof_document_type,
# --> 131             'kyc_idproof_document_value':cust_id_value,
#     132         }
#     133
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/query.py in get_or_create(self, defaults, **kwargs)
#     464             return self.get(**lookup), False
#     465         except self.model.DoesNotExist:
# --> 466             return self._create_object_from_params(lookup, params)
#     467
#     468     def update_or_create(self, defaults=None, **kwargs):
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/query.py in _create_object_from_params(self, lookup, params, lock)
#     507             except self.model.DoesNotExist:
#     508                 pass
# --> 509             six.reraise(*exc_info)
#     510
#     511     def _extract_model_params(self, defaults, **kwargs):
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/utils/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#     688 else:
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/query.py in _create_object_from_params(self, lookup, params, lock)
#     498             with transaction.atomic(using=self.db):
#     499                 params = {k: v() if callable(v) else v for k, v in params.items()}
# --> 500                 obj = self.create(**params)
#     501             return obj, True
#     502         except IntegrityError:
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/query.py in create(self, **kwargs)
#     392         obj = self.model(**kwargs)
#     393         self._for_write = True
# --> 394         obj.save(force_insert=True, using=self.db)
#     395         return obj
#     396
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     806
#     807         self.save_base(using=using, force_insert=force_insert,
# --> 808                        force_update=force_update, update_fields=update_fields)
#     809     save.alters_data = True
#     810
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     836             if not raw:
#     837                 self._save_parents(cls, using, update_fields)
# --> 838             updated = self._save_table(raw, cls, force_insert, force_update, using, update_fields)
#     839         # Store the database on which the object was saved
#     840         self._state.db = using
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/base.py in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     922
#     923             update_pk = meta.auto_field and not pk_set
# --> 924             result = self._do_insert(cls._base_manager, using, fields, update_pk, raw)
#     925             if update_pk:
#     926                 setattr(self, meta.pk.attname, result)
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/base.py in _do_insert(self, manager, using, fields, update_pk, raw)
#     961         """
#     962         return manager._insert([self], fields=fields, return_id=update_pk,
# --> 963                                using=using, raw=raw)
#     964
#     965     def delete(self, using=None, keep_parents=False):
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/query.py in _insert(self, objs, fields, return_id, raw, using)
#    1077         query = sql.InsertQuery(self.model)
#    1078         query.insert_values(fields, objs, raw=raw)
# -> 1079         return query.get_compiler(using=using).execute_sql(return_id)
#    1080     _insert.alters_data = True
#    1081     _insert.queryset_only = False
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/models/sql/compiler.py in execute_sql(self, return_id)
#    1110         with self.connection.cursor() as cursor:
#    1111             for sql, params in self.as_sql():
# -> 1112                 cursor.execute(sql, params)
#    1113             if not (return_id and cursor):
#    1114                 return
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      77         start = time()
#      78         try:
# ---> 79             return super(CursorDebugWrapper, self).execute(sql, params)
#      80         finally:
#      81             stop = time()
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      62                 return self.cursor.execute(sql)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#      66     def executemany(self, sql, param_list):
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      92                 if dj_exc_type not in (DataError, IntegrityError):
#      93                     self.wrapper.errors_occurred = True
# ---> 94                 six.reraise(dj_exc_type, dj_exc_value, traceback)
#      95
#      96     def __call__(self, func):
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/utils/six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# ~/Software/virtualenv/aavin/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      62                 return self.cursor.execute(sql)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#      66     def executemany(self, sql, param_list):
#
# IntegrityError: duplicate key value violates unique constraint "main_icustomer_customer_code_key"
# DETAIL:  Key (customer_code)=(CBE120033) already exists.

# %%
current_cust_code
# Out:
# 'CBE118145'

# %%
current_cust_code='CBE117351'

# %%
# new model, fields

class KycIDProofDocumentType(models.Model):
    name = models.CharField(max_length=50)
    #aadhar, ration card, bank account number, voter id,  PAN, DL, passport
    
    
class ICustomer(models.Model):
    customer_code = models.CharField(max_length=13, unique=True)
    customer_type = models.ForeignKey(ICustomerType)
    business = models.ForeignKey(Business,  blank=True, null=True)
    is_business_approved = models.BooleanField(default=False)
    user_profile = models.OneToOneField(UserProfile, on_delete=models.CASCADE)
    aadhar_number = models.CharField(max_length=12, blank=True, null=True)
    aadhar_document = models.FileField(max_length=1000, blank=True, null=True, upload_to=get_icustomer_aadhar_image)
    kyc_idproof_document_type = models.ForeignKey(KycIDProofDocumentType, blank=True, null=True)
    kyc_idproof_document_value = models.CharField(max_length=25, blank=True, null=True)
    time_created = models.DateTimeField(auto_now_add=True)
    time_modified = models.DateTimeField(auto_now=True)

# %%
# here is how i populate the new table
KycIDProofDocumentType(name='Aadhar').save()
KycIDProofDocumentType(name='Bank Account Number').save()
KycIDProofDocumentType(name='Driving Licence').save()
KycIDProofDocumentType(name='Family Card').save()
KycIDProofDocumentType(name='PAN Card').save()
KycIDProofDocumentType(name='Passport').save()
KycIDProofDocumentType(name='Voter ID').save()
KycIDProofDocumentType(name='ULIP PROPOSAL NUMBER').save()
KycIDProofDocumentType(name='Other').save()

KycIDProofDocumentType.objects.all()

# %%
KycIDProofDocumentType.objects.all().values_list('name', 'id')
# Out:
# <QuerySet [('Aadhar', 1), ('Bank Account Number', 2), ('Driving Licence', 3), ('PAN Card', 5), ('Passport', 6), ('Voter ID', 7), ('Other', 8), ('ULIP PROPOSAL NUMBER', 10), ('Ration Card', 4)]>
