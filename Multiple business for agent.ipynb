# %%
for business_agent in BusinessAgentMap.objects.filter():
    business_agent.business.user_profile_id = business_agent.agent.user_profile.id
    business_agent.business.save()
    print('{} to {}'.format(business_agent.agent.user_profile.user.first_name, business_agent.business.user_profile.user.first_name))
# Out:
# RAGHAVAN.P to RAGHAVAN.P
# M.PREMKUMAR to M.PREMKUMAR
# ANANDAKUMAR.R.C - [250] to ANANDAKUMAR.R.C - [250]
# DHANALAKSHIMI to DHANALAKSHIMI
# THEIVAMANI .C to THEIVAMANI .C
# M.PREMKUMAR to M.PREMKUMAR
# NAGARAJ .M - [1525] to NAGARAJ .M - [1525]
# SENTHILKUMAR.M to SENTHILKUMAR.M
# MURUGAN .K to MURUGAN .K
# PALANISAMY .M to PALANISAMY .M
# BABU.G to BABU.G
# JAYANTHI .S to JAYANTHI .S
# M.Ramesh to M.Ramesh
# MANI .T to MANI .T
# RAJENDRAN .B to RAJENDRAN .B
# KAVITHAMANI .S to KAVITHAMANI .S
# RAJENDERAN.G.M to RAJENDERAN.G.M
# SAMIADIYAN.I to SAMIADIYAN.I
# ANANDAKUMAR.R.C - [250] to ANANDAKUMAR.R.C - [250]
# RAGHAVAN.P to RAGHAVAN.P
# SARAVANAN.M to SARAVANAN.M
# RANJITHAM .D to RANJITHAM .D
# PALANISAMY .P.K. to PALANISAMY .P.K.
# Pushpa.S to Pushpa.S
# LAKSHMI .R to LAKSHMI .R
# G SELVAM to G SELVAM
# MANI .P to MANI .P
# SHANTHY .K to SHANTHY .K
# MARUTHACHALAM .S to MARUTHACHALAM .S
# PARIMALA .P to PARIMALA .P
# KANNAMMAL .P to KANNAMMAL .P
# ANGAMUTHU.P to ANGAMUTHU.P
# M.Thiyagarajan to M.Thiyagarajan
# K.NAVEEN to K.NAVEEN
# ABIRAHAM .E to ABIRAHAM .E
# MALLIKA.S to MALLIKA.S
# SREENIVASAN.M to SREENIVASAN.M
# VENUGOPAL.S to VENUGOPAL.S
# KANAGARAJ .C to KANAGARAJ .C
# SUBBULAKSHMI .N to SUBBULAKSHMI .N
# LATHA .A to LATHA .A
# RAMAKRISHNAN .D to RAMAKRISHNAN .D
# JAGADEESAN  .C to JAGADEESAN  .C
# G.MANJULA to G.MANJULA
# SATHIYASEELAN .S to SATHIYASEELAN .S
# DEVAKI.G to DEVAKI.G
# DEVARAJ .A to DEVARAJ .A
# BALASUBRAMANIAN.K.A to BALASUBRAMANIAN.K.A
# S.A.MURUGESAN to S.A.MURUGESAN
# JAYACHANDRAN .B to JAYACHANDRAN .B
# SATHIYASEELAN .S to SATHIYASEELAN .S
# DHANAGOPAL .S to DHANAGOPAL .S
# SIVARAMAN.S to SIVARAMAN.S
# RAJESWARI.G to RAJESWARI.G
# PALANISAMY.M to PALANISAMY.M
# MANIKANDAN.C to MANIKANDAN.C
# BASHA .B to BASHA .B
# SADHASIVAM .P to SADHASIVAM .P
# SENTHILVEL .B to SENTHILVEL .B
# MANJULA to MANJULA
# LALITHAMANI.K to LALITHAMANI.K
# SHANTHAMANI.R to SHANTHAMANI.R
# Chinnadurai.V to Chinnadurai.V
# VELLINGIRI.K to VELLINGIRI.K
# BASHEER .M.M to BASHEER .M.M
# PAARTHIBAN .J to PAARTHIBAN .J
# D.SURESH to D.SURESH
# KANNAN .A to KANNAN .A
# AZHA.C to AZHA.C
# RATHIKA.T to RATHIKA.T
# M.Pappathi to M.Pappathi
# JEYANTHI.S.M to JEYANTHI.S.M
# UDAYAKUMAR .K to UDAYAKUMAR .K
# KARTHIKEYAN .S.P. to KARTHIKEYAN .S.P.
# AMIRTHAM.R to AMIRTHAM.R
# RAJASHANKER.S.G to RAJASHANKER.S.G
# CHARLES JOSEPH.J.M to CHARLES JOSEPH.J.M
# RAVI.V to RAVI.V
# MUTHUKUMARASWAMY.R to MUTHUKUMARASWAMY.R
# SANKARI BADRI LAKSHIMI.L to SANKARI BADRI LAKSHIMI.L
# SELVARAJ.A to SELVARAJ.A
# PUSPAM.M to PUSPAM.M
# RANI.A to RANI.A
# JAYAMMA.R to JAYAMMA.R
# MOHAMED YUSUF.K.A to MOHAMED YUSUF.K.A
# DEVARAJ.S to DEVARAJ.S
# SATHYAPRIYA.P to SATHYAPRIYA.P
# JAYAKUMAR.P to JAYAKUMAR.P
# SAMPATH.M to SAMPATH.M
# SURESHKUMAR.R to SURESHKUMAR.R
# BALASUNDRAM.P to BALASUNDRAM.P
# SHANTHAMANI.R to SHANTHAMANI.R
# RAJESH.N to RAJESH.N
# KAMATCHI.G to KAMATCHI.G
# KAVIRAJ.R to KAVIRAJ.R
# GEORGE .J to GEORGE .J
# DULASIAMMAL.V to DULASIAMMAL.V
# RAJAPANDIAN.G to RAJAPANDIAN.G
# RENUGA to RENUGA
# NAGARAJ  to NAGARAJ
# AMBIRAJ.T.S to AMBIRAJ.T.S
# COMBODIA MILL to COMBODIA MILL
# RANGAVILAS MILL to RANGAVILAS MILL
# PANKAJA MILL to PANKAJA MILL
# SRI KANNAPIRAN MILLS to SRI KANNAPIRAN MILLS
# SanjeevKumar to SanjeevKumar
# Revathi.P to Revathi.P
# KUMARAVEL.S to KUMARAVEL.S
# MANIKANDAN.S to MANIKANDAN.S
# KASTHURIGANGA to KASTHURIGANGA
# JAYANTHI.K to JAYANTHI.K
# VASANTHI to VASANTHI
# ESWARAN.N.R to ESWARAN.N.R
# RAJAMANICKAM .V to RAJAMANICKAM .V
# MANOKARAN.A.V to MANOKARAN.A.V
# P.BALAMURUGAN to P.BALAMURUGAN
# L.JEGAJEEVAN to L.JEGAJEEVAN
# Sarojini.K to Sarojini.K
# Kavitha.K to Kavitha.K
# MYTHILI.V to MYTHILI.V
# Gunasekaran.A to Gunasekaran.A
# RAJAMMAL.P to RAJAMMAL.P
# MALAIAPPAN.A to MALAIAPPAN.A
# R.KANCHANA to R.KANCHANA
# P.KANNAN to P.KANNAN
# V.MUTHURAMAN to V.MUTHURAMAN
# D.SAKTHIVEL to D.SAKTHIVEL
# N.SUSEELA to N.SUSEELA
# C.V.SRINIVASAN to C.V.SRINIVASAN
# B.Ravikumar to B.Ravikumar
# R.GANDHINATHAN to R.GANDHINATHAN
# V.N.JOTHIMANI to V.N.JOTHIMANI
# V.N.RAVANAN to V.N.RAVANAN
# A.RATHINAM to A.RATHINAM
# M.AMUTHA to M.AMUTHA
# M.Manimekalai to M.Manimekalai
# M.ANNADURAI to M.ANNADURAI
# K.THANGAVEL to K.THANGAVEL
# C.RAJU to C.RAJU
# S.AMSAVENNI to S.AMSAVENNI
# P . SUGANTHI to P . SUGANTHI
# J.Chitra Devi to J.Chitra Devi
# M.Jagatheessan to M.Jagatheessan
# P.UMAMAHESWARI to P.UMAMAHESWARI
# A.Karuppasamy to A.Karuppasamy
# S.A.Arumugam to S.A.Arumugam
# R.Ashok kumar to R.Ashok kumar
# M.Then mozhi to M.Then mozhi
# Singai Ranganathan to Singai Ranganathan
# HEMAVATHI.B to HEMAVATHI.B
# KARTHIKEYAN to KARTHIKEYAN
# UDAYAKUMAR .K to UDAYAKUMAR .K
# TNSTC - ONDIPUDUR BRANCH to TNSTC - ONDIPUDUR BRANCH
# UNIT RATION STAND SULUR to UNIT RATION STAND SULUR
# ASG RACE COURSE to ASG RACE COURSE
# WILMAC ENGG INDIA P LTD to WILMAC ENGG INDIA P LTD
# G-PLAST (P)LTD to G-PLAST (P)LTD
# G PLAST  A to G PLAST  A
# LAKSHMI ELECTRICAL CONTROL SYS to LAKSHMI ELECTRICAL CONTROL SYS
# TNSTC - KARUMATHAMPATTI BRANCH to TNSTC - KARUMATHAMPATTI BRANCH
# LAKSHIMI PRECISION TOOLS LTD to LAKSHIMI PRECISION TOOLS LTD
# P.S.KARTHIKEYAN to P.S.KARTHIKEYAN
# J.Solomon to J.Solomon
# M.Yasodha Sree to M.Yasodha Sree
# M.Sripriya to M.Sripriya
# P.Kalamani to P.Kalamani
# K.Mariya joseph to K.Mariya joseph
# P.Jayaraman to P.Jayaraman
# V.Shanmuga Sundaram to V.Shanmuga Sundaram
# Mohanraj to Mohanraj
# M.Gaushal vashini to M.Gaushal vashini
# R.Gopalakrishnan to R.Gopalakrishnan
# K.Nithya to K.Nithya
# P.Chairman Rajkumar to P.Chairman Rajkumar
# K.Ramthilak to K.Ramthilak
# M.Palaniyappa Deva to M.Palaniyappa Deva
# K.Indirani to K.Indirani
# C.DHANAPAL to C.DHANAPAL
# MANOHAR to MANOHAR
# A.KANNAMAL to A.KANNAMAL
# YesodhaSri to YesodhaSri
# C.SATHYAVAN to C.SATHYAVAN
# N TAMILMANI to N TAMILMANI
# D.CHANDRA to D.CHANDRA
# M VAISNAVI to M VAISNAVI
# V SUGANYA to V SUGANYA
# R JAYASAKTHI to R JAYASAKTHI
# N KARTHIK to N KARTHIK
# T DHANDAPANI to T DHANDAPANI
# N NANDHAKUMAR to N NANDHAKUMAR
# K RAJKUMAR to K RAJKUMAR
# KV ANANDHI to KV ANANDHI
# R VENKATACHALAM to R VENKATACHALAM
# N GEETHA LAXMI to N GEETHA LAXMI
# V MURUGANANDHAM to V MURUGANANDHAM
# M THANARAJ to M THANARAJ
# B SHANMUGASUNDARAM to B SHANMUGASUNDARAM
# B VEERATHAL to B VEERATHAL
# S.Jayaparvathi to S.Jayaparvathi
# PSG & SONS FOUNDARY NEELAMB to PSG & SONS FOUNDARY NEELAMB
# DOG SQUAD SULUR POLICE ST CAMP to DOG SQUAD SULUR POLICE ST CAMP
# WATER TEC INDIA PVT LTD to WATER TEC INDIA PVT LTD
# K to K
# COSMOPLITON CLUB to COSMOPLITON CLUB
# PSG to PSG
# PSG TECH HOSTEL to PSG TECH HOSTEL
# GRG CANTEEN to GRG CANTEEN
# GRG LADIES HOSTEL to GRG LADIES HOSTEL
# PSG HOSPITALS - DIETARY to PSG HOSPITALS - DIETARY
# GOVTPOLYTECHNIC HOSTEL FOR MEN to GOVTPOLYTECHNIC HOSTEL FOR MEN
# SNR COLLEGE to SNR COLLEGE
# RATHNAVEL SUBRAMANIAM COLLEGE to RATHNAVEL SUBRAMANIAM COLLEGE
# COIMBATORE MEDICAL COLLEGE LAD to COIMBATORE MEDICAL COLLEGE LAD
# SNR COLLEGE LADIES to SNR COLLEGE LADIES
# HINDUSTAN COLLEGE HOSTEL(MEN) to HINDUSTAN COLLEGE HOSTEL(MEN)
# HINDUSTAN COLLEGE LADIES HOSTE to HINDUSTAN COLLEGE LADIES HOSTE
# RVS LADIES HOSTEL  to RVS LADIES HOSTEL
# NCC CAMP to NCC CAMP
# TAMILNADU COLLEGE ENGG HOSTEL to TAMILNADU COLLEGE ENGG HOSTEL
# CBE MEDICAL COLL MENS HOSTEL to CBE MEDICAL COLL MENS HOSTEL
# TEJAA SAKTHI INSTITUTE OF TECH to TEJAA SAKTHI INSTITUTE OF TECH
# PSG CAFEPERIA to PSG CAFEPERIA
# Relaince Retail Ltd- Masakkali to Relaince Retail Ltd- Masakkali
# SARASWATHY.S to SARASWATHY.S
# JOTHI .K to JOTHI .K
# CHARLES.P to CHARLES.P
# MOORTHY.A to MOORTHY.A
# GANESAN.K to GANESAN.K
# BALASUNDARAM M. to BALASUNDARAM M.
# EZILARASI.S to EZILARASI.S
# M.Rajeshwari to M.Rajeshwari
# R.Manikandan to R.Manikandan
# Air force Admn - College to Air force Admn - College
# M THANDAPANI to M THANDAPANI
# V NARAYANAN to V NARAYANAN
# A TARUN to A TARUN
# M SIVAKUMAR to M SIVAKUMAR
# S NARMADHA to S NARMADHA
# S.NARMATHA to S.NARMATHA
# S.ELAKKIYA to S.ELAKKIYA
# S.AROKKIYASELI to S.AROKKIYASELI
# P.Prince to P.Prince
#  S.Sathishkumar  to  S.Sathishkumar
# Relaince Retail Ltd- Ramanatha to Relaince Retail Ltd- Ramanatha
# A Prabu to A Prabu
# K.Sameem Mohammed Ali to K.Sameem Mohammed Ali
# S.JAYAKUMAR to S.JAYAKUMAR
# S.Poongodi to S.Poongodi
# RADHAMANI.R to RADHAMANI.R
# MOORTHY.A to MOORTHY.A
# USHA to USHA
# SRI JAYENDRA SARASWATHY TRUST to SRI JAYENDRA SARASWATHY TRUST
# NCC CAMP to NCC CAMP
# GRDC S MEN S HOSTEL to GRDC S MEN S HOSTEL
# GRDC S WOMEN S HOSTEL to GRDC S WOMEN S HOSTEL
# POLICE HPL to POLICE HPL
# OBSERVATION HOME to OBSERVATION HOME
# ESI HOSPITAL to ESI HOSPITAL
# PR SCHOOL to PR SCHOOL
# ASST-COMR COPRN (SIN to ASST-COMR COPRN (SIN
# PSG TECH CANTEEN to PSG TECH CANTEEN
# PARK COLLEGE to PARK COLLEGE
# SULUR GOVT HOSPITAL to SULUR GOVT HOSPITAL
# NCC CAMP to NCC CAMP
# NCC CAMP to NCC CAMP
# SENTHILKUMAR to SENTHILKUMAR
# SULOCHANA .V to SULOCHANA .V
# KOUSALYA.R to KOUSALYA.R
# USHA.R to USHA.R
# MOHAN DAS M. to MOHAN DAS M.
# R RAJA to R RAJA
# BALAN.V to BALAN.V
# MANI.T to MANI.T
# IRUDAYARAJ to IRUDAYARAJ
# DHARAMARAJ.M to DHARAMARAJ.M
# SULOCHANA .V to SULOCHANA .V
# SASIKALA.N to SASIKALA.N
# VELLINGIRI P. to VELLINGIRI P.
# SHANMUGASUNDARAM.R - [1992] to SHANMUGASUNDARAM.R - [1992]
# MANI.R to MANI.R
# SARASWATHI.M to SARASWATHI.M
# MAHALASHMI.M to MAHALASHMI.M
# ASST-COMR.COPRN (R.N.PURAM.80F to ASST-COMR.COPRN (R.N.PURAM.80F
# ASST-COMR.COPRN (M.K.PALAYAM.  to ASST-COMR.COPRN (M.K.PALAYAM.
# ASST.COMMISSIONER-AMMA UNAVAGA to ASST.COMMISSIONER-AMMA UNAVAGA
# Reliance Retail Ltd - Fun Mall to Reliance Retail Ltd - Fun Mall
# Shanthi Gears  A&B Unit to Shanthi Gears  A&B Unit
# Shanthi Gears Foundary to Shanthi Gears Foundary
# Shanthi Gears C Unit to Shanthi Gears C Unit
# GBJ Hotels Pvt ltd to GBJ Hotels Pvt ltd
# Thiru Murugar Spinning Mill to Thiru Murugar Spinning Mill
# Dr NGP School to Dr NGP School
# TNSTC - SULUR to TNSTC - SULUR
# P.S.G. HOSTEL - MEDICAL to P.S.G. HOSTEL - MEDICAL
# SERENE ROSE to SERENE ROSE
# MADURA MESS to MADURA MESS
# SUSEELA to SUSEELA
# RAVICHANDRAN.V to RAVICHANDRAN.V
# SUSEELA to SUSEELA
# IRUDAYARAJ to IRUDAYARAJ
# MALARVIZHI to MALARVIZHI
# DHARAMARAJ.M to DHARAMARAJ.M
# CHITRA.S.P to CHITRA.S.P
# THANGAPANDIAN.P to THANGAPANDIAN.P
# SELVI.V to SELVI.V
# MALARVIZHI to MALARVIZHI
# INDIRA.P to INDIRA.P
# MANI.S.M to MANI.S.M
# JAYAMANI .S to JAYAMANI .S
# GURUMOORTHY.K to GURUMOORTHY.K
# MUTHUMANI .M to MUTHUMANI .M
# JOTHIMANI.D to JOTHIMANI.D
# SARASWATHI to SARASWATHI
# RAVINDRAN.N to RAVINDRAN.N
# INDRAMANI.N to INDRAMANI.N
# POONKOTHAI.B to POONKOTHAI.B
# RAJASEKAR.R to RAJASEKAR.R
# V.Narayanan to V.Narayanan
# S.GANDHINATHAN to S.GANDHINATHAN
# THANGAM.M to THANGAM.M
# PALANI.U to PALANI.U
# SARADHA to SARADHA
# R ARJUNAN to R ARJUNAN
# RANGANATHAN.S.N. to RANGANATHAN.S.N.
# SENTHIL KUMAR.R to SENTHIL KUMAR.R
# SORIMUTHU.C to SORIMUTHU.C
# LALY ABRAHAM to LALY ABRAHAM
# VALLIMYIL.R to VALLIMYIL.R
# VIJAYARAJ.M to VIJAYARAJ.M
# SOUNDRAPANDI.T to SOUNDRAPANDI.T
# M.Ananda Kumar to M.Ananda Kumar
# RAMESH.R to RAMESH.R
# RAMASAMY.N to RAMASAMY.N
# MOHANASUNDARAM.K to MOHANASUNDARAM.K
# SRINIVASAN.K to SRINIVASAN.K
# SHANMUGAM.M to SHANMUGAM.M
# JAYASENTHILAN.V to JAYASENTHILAN.V
# DEEPAN.P to DEEPAN.P
# JOSEPH JAYAKUMAR.J to JOSEPH JAYAKUMAR.J
# JANAKARAJ.A to JANAKARAJ.A
# SIVAPACKIYAM.M to SIVAPACKIYAM.M
# AMBUJAM.R to AMBUJAM.R
# RAMKUMAR to RAMKUMAR
# PALANISAMY.S to PALANISAMY.S
# NANDHINIDEVI.G to NANDHINIDEVI.G
# KANNAN.K to KANNAN.K
# ANITHAKUMARI. V to ANITHAKUMARI. V
# N SOMASUNDHARAM to N SOMASUNDHARAM
# NAGENDRAN.A to NAGENDRAN.A
# SORIMUTHU  to SORIMUTHU
# SULOCHANA V to SULOCHANA V
# KRISHNAMOORTHY to KRISHNAMOORTHY
# PECHIMUTHU to PECHIMUTHU
# KANNAMAL LADIES HOSTER(BHA to KANNAMAL LADIES HOSTER(BHA
# TNSTC - MARUTHAMALAI BRANCH to TNSTC - MARUTHAMALAI BRANCH
# GOVT COLLEGE OF TECH HOSTEL to GOVT COLLEGE OF TECH HOSTEL
# GOVT COLLEGE OF TECH CANTEEN to GOVT COLLEGE OF TECH CANTEEN
# SFSC STUDENTS MESS to SFSC STUDENTS MESS
# The Wardern, Studt Hos,TNAU,Cb to The Wardern, Studt Hos,TNAU,Cb
# DEAF AND DUMB SCHOOL to DEAF AND DUMB SCHOOL
# THIRUVALLUVAR HOSTEL(BHA to THIRUVALLUVAR HOSTEL(BHA
# ELANGO HOSTEL(BHA to ELANGO HOSTEL(BHA
# GUNASEKARAN.S to GUNASEKARAN.S
# MALAISAMY.A to MALAISAMY.A
# KRISHNAMOORTHY.A to KRISHNAMOORTHY.A
# NARAYANAN.T to NARAYANAN.T
# RENNUKKA.D to RENNUKKA.D
# NAGARAJ.K to NAGARAJ.K
# KENNADY.A to KENNADY.A
# REENARAGUPATHY to REENARAGUPATHY
# KANNAN.R to KANNAN.R
# AMUTHAVALLI.R to AMUTHAVALLI.R
# VANITHA.K to VANITHA.K
# SRINIVASAN.M to SRINIVASAN.M
# HARIKRISHNAN.T to HARIKRISHNAN.T
# VIJAYA.A to VIJAYA.A
# P.Kesavaraj to P.Kesavaraj
# SARASWATHI.R to SARASWATHI.R
# SHANMUGASUNDARAM.C to SHANMUGASUNDARAM.C
# THIRUMANI.S.P to THIRUMANI.S.P
# POOBALAKRISHNAN.R to POOBALAKRISHNAN.R
# ARUMUGAM .P to ARUMUGAM .P
# KANNAMMAL .A to KANNAMMAL .A
# RANGARAJ.A to RANGARAJ.A
# ROBERT .R.M to ROBERT .R.M
# MALLIKA .J to MALLIKA .J
# A.H.S.ENGG.COLLEGE to A.H.S.ENGG.COLLEGE
# SOTHERN ROADWAYS TSNO8MTP.ROAD to SOTHERN ROADWAYS TSNO8MTP.ROAD
# SHENAKAVALLI.J to SHENAKAVALLI.J
# LATHA R to LATHA R
# CHOKALINGAM.K to CHOKALINGAM.K
# B.Chithra to B.Chithra
# VANISREE.S to VANISREE.S
# Kuyili.A to Kuyili.A
# Chandran.N to Chandran.N
# ARCHANA to ARCHANA
# VASANTHA to VASANTHA
# B.Tamilselvan  to B.Tamilselvan
# NANDHINIDEVI.G to NANDHINIDEVI.G
# SULAIGH BEEBI.K.M to SULAIGH BEEBI.K.M
# HIDAYATHULLAH.A to HIDAYATHULLAH.A
# JOTHIMANI.R to JOTHIMANI.R
# SUBBURAM.C to SUBBURAM.C
# NEELA.S to NEELA.S
# MANGALAM to MANGALAM
# BOOPATHY RAJAN.N to BOOPATHY RAJAN.N
# SHANMUGAVALLI.K to SHANMUGAVALLI.K
# THANGARAJ.G to THANGARAJ.G
# VIJAYA.S to VIJAYA.S
# SENTHILKUMAR.B to SENTHILKUMAR.B
# SREENIVASAN.R to SREENIVASAN.R
# GOPALAKRISHNAN.V to GOPALAKRISHNAN.V
# SENTHILKANNAN.R to SENTHILKANNAN.R
# MOHAN.D to MOHAN.D
# KAMBAR HOSTEL(BHA.UNI) to KAMBAR HOSTEL(BHA.UNI)
# BALASUBRAMANI.P to BALASUBRAMANI.P
# RAJAMOHAMAD to RAJAMOHAMAD
# S.Saradhamani to S.Saradhamani
# SELLAMAL to SELLAMAL
# M.Krishnan to M.Krishnan
# M.P.Kumar to M.P.Kumar
# Reliance Retail Ltd- Saibaba C to Reliance Retail Ltd- Saibaba C
# B.CHITRADEVI to B.CHITRADEVI
# R.Seethalakshmi to R.Seethalakshmi
# P.Jinath to P.Jinath
# S.RAVI to S.RAVI
# K.Natesan to K.Natesan
# SARATHAMANI to SARATHAMANI
# V.SIVALINGAM to V.SIVALINGAM
# SL.MANIKAM to SL.MANIKAM
# E.PALANISAMY to E.PALANISAMY
# K CHITRA to K CHITRA
# S RATHINAM to S RATHINAM
# S.SETHU GAYATHRI DEVI to S.SETHU GAYATHRI DEVI
# J DINESH BABU to J DINESH BABU
# K SARAVANAN to K SARAVANAN
# J LAKSHMI to J LAKSHMI
# KV.DURAISAMY to KV.DURAISAMY
# N.Sharmila to N.Sharmila
# Anna University ,coimbatore to Anna University ,coimbatore
# Vidhya Kala to Vidhya Kala
# D.BALAJI to D.BALAJI
# N.Renuka to N.Renuka
# KANNA MOBILES  to KANNA MOBILES
# A.Natarajan to A.Natarajan
# K.Lakshmi to K.Lakshmi
# R.Barathy to R.Barathy
# BALASUBRAMANIAM.M to BALASUBRAMANIAM.M
# AHS FACULTY OF EDU to AHS FACULTY OF EDU
# SPL CAMP AHSENG COLLEGE to SPL CAMP AHSENG COLLEGE
# SEKHIZLAR HOSTEL - BHA UNIV to SEKHIZLAR HOSTEL - BHA UNIV
# SELLAMMAL LADIES HOSTEL to SELLAMMAL LADIES HOSTEL
# PERIYAR LADIES HOSTEL - BHA UN to PERIYAR LADIES HOSTEL - BHA UN
# ST PAULS M HR S SCHOOL to ST PAULS M HR S SCHOOL
# UNION STAFF BENEFIT ACCCOUNT to UNION STAFF BENEFIT ACCCOUNT
# ASST-COMR COPRN (FLOWER MARKET to ASST-COMR COPRN (FLOWER MARKET
# NCC Camp Coimbatore to NCC Camp Coimbatore
# NCC Camp-Agri to NCC Camp-Agri
# GOVINDAN.C.R to GOVINDAN.C.R
# KANAGAVALLI.B to KANAGAVALLI.B
# HARIHARAN..V to HARIHARAN..V
# BOOPATHY.S to BOOPATHY.S
# KARTHIK.L to KARTHIK.L
# THIRVENI.SMT to THIRVENI.SMT
# K.Sunilkumar  to K.Sunilkumar
# VIJAYAKUMAR.N to VIJAYAKUMAR.N
# NARAYANASAMY.K to NARAYANASAMY.K
# PECHIMUTHU.K to PECHIMUTHU.K
# RANGARAJ.V to RANGARAJ.V
# VENKATACHALAM.P to VENKATACHALAM.P
# RAJU S. to RAJU S.
# SARADHAMANI.K to SARADHAMANI.K
# RAJESWARI.G to RAJESWARI.G
# BHARKATH NISHA.S to BHARKATH NISHA.S
# SUBBAIAH.P to SUBBAIAH.P
# R.Dharani to R.Dharani
# VASAN.R.S to VASAN.R.S
# SARASWATHY.A to SARASWATHY.A
# RAJASEKRAN.C to RAJASEKRAN.C
# THE MADUKKRAI C.W.E.C.S.LTD to THE MADUKKRAI C.W.E.C.S.LTD
# RAHAMATHDULLA A. to RAHAMATHDULLA A.
# ABDUL SAMAD.I to ABDUL SAMAD.I
# YUVARAJ.A to YUVARAJ.A
# PARYJOHN BEGHAM.K to PARYJOHN BEGHAM.K
# V.Sasikala Gnasampantham to V.Sasikala Gnasampantham
# STELLAMARY.M to STELLAMARY.M
# UNION PARLOUR to UNION PARLOUR
# EXHIBITION to EXHIBITION
# Amrita Vidyalayam, Nallampalay to Amrita Vidyalayam, Nallampalay
# Pannai Pasumai - RS Puram to Pannai Pasumai - RS Puram
# Pannai Pasumai - Vadavalli to Pannai Pasumai - Vadavalli
# Pannai Pasumai - Flower Market to Pannai Pasumai - Flower Market
# Pannai Pasumai - Townhall to Pannai Pasumai - Townhall
# Pannai Pasumai - SB Colony to Pannai Pasumai - SB Colony
# B.U.-KASTHURIBAI HOSTEL to B.U.-KASTHURIBAI HOSTEL
# B.U.- VASUGI HOSTEL to B.U.- VASUGI HOSTEL
# V DANASEKARAN to V DANASEKARAN
# SHANMUGAM.K to SHANMUGAM.K
# GOVINDAN.C.R to GOVINDAN.C.R
# JOHNSON to JOHNSON
# VENKATACHALAM.P.A to VENKATACHALAM.P.A
# VAITHEESWARAN.V to VAITHEESWARAN.V
# SILAMBARASAN.T.M to SILAMBARASAN.T.M
# KOMARSEBASTIN.G to KOMARSEBASTIN.G
# CHINNARAJ.A to CHINNARAJ.A
# ABOOTHAHEER to ABOOTHAHEER
# ANNADURAI.S to ANNADURAI.S
# MENAKA.S to MENAKA.S
# MURUGESHAN.N to MURUGESHAN.N
# SURESH KUMAR.H to SURESH KUMAR.H
# MANIVANNAN.V to MANIVANNAN.V
# THANGAM.Y to THANGAM.Y
# INDIRANI.K to INDIRANI.K
# SELVAPANDIAN.M to SELVAPANDIAN.M
# PARVATHIMUTHU.C to PARVATHIMUTHU.C
# FATHIMABEEBE to FATHIMABEEBE
# SARADHA.H to SARADHA.H
# MUTHULAKSHMI.S to MUTHULAKSHMI.S
# ABDIL NAZAR to ABDIL NAZAR
# SUBRAMANIAN.P to SUBRAMANIAN.P
# ABUBACKER SITHQUE .A to ABUBACKER SITHQUE .A
# LOGANATHA GUPTHA to LOGANATHA GUPTHA
# KALAISELVI to KALAISELVI
# MOHAMAD HANSAR to MOHAMAD HANSAR
# Ravikumar.P to Ravikumar.P
# DEVASAGAYAM.D to DEVASAGAYAM.D
# MURUGESWARI.N to MURUGESWARI.N
# R.Shanthi to R.Shanthi
# MALLIKA.K to MALLIKA.K
# BABY HEMALATHA to BABY HEMALATHA
# PUNITHAVALLI.A to PUNITHAVALLI.A
# RAVINDRAN.R to RAVINDRAN.R
# ARUNACHALAM.S to ARUNACHALAM.S
# GUNASINGH.S.R to GUNASINGH.S.R
# SARASWATHY.D to SARASWATHY.D
# SUNDARAVADIVEL.P to SUNDARAVADIVEL.P
# BALAKRISHNAN.S to BALAKRISHNAN.S
# UMMAR FARUK.A to UMMAR FARUK.A
# KALA.S to KALA.S
# SHANMUGASUNDRAM.N to SHANMUGASUNDRAM.N
# SULIMAN.M.M to SULIMAN.M.M
# GOWRI.G to GOWRI.G
# R.USHA to R.USHA
# JAYAGANESH.C to JAYAGANESH.C
# PILDOSS.I to PILDOSS.I
# PAGAYARAJ.A to PAGAYARAJ.A
# V.JAYARAMAN to V.JAYARAMAN
# SARASWATHY.R to SARASWATHY.R
# MURUGESAN to MURUGESAN
# KARANYA GENTS HOSTEL to KARANYA GENTS HOSTEL
# ANTONISAMY.R to ANTONISAMY.R
# JAYANACHIAR.S to JAYANACHIAR.S
# PREMAKUMARI.V to PREMAKUMARI.V
# ABDULRAHMAN .V.I to ABDULRAHMAN .V.I
# BABURAJ.P to BABURAJ.P
# RAMESHKUMAR.K to RAMESHKUMAR.K
# MAREESWARAN.M to MAREESWARAN.M
# DHAMODARAN.C to DHAMODARAN.C
# GEORGE.C.C. to GEORGE.C.C.
# MOHANKUMAR.V to MOHANKUMAR.V
# SOUNTHER JOHN.K to SOUNTHER JOHN.K
# MOHAMED SALIM.K to MOHAMED SALIM.K
# MOHAMMED UBAIS K.A to MOHAMMED UBAIS K.A
# SATHIYA to SATHIYA
# SUBBIAH .K to SUBBIAH .K
# RAJAN.S to RAJAN.S
# MATHIVANAN.V.R to MATHIVANAN.V.R
# SOWKKATHALI.S.M to SOWKKATHALI.S.M
# Ganesan R.R to Ganesan R.R
# LavanyaDevi to LavanyaDevi
# Neelaveni.R to Neelaveni.R
# SenthilKumar.P to SenthilKumar.P
# JAYARAM.L to JAYARAM.L
# ASHOK KUMAR.P to ASHOK KUMAR.P
# ARUMUGAM.N to ARUMUGAM.N
# MANJU.J to MANJU.J
# SUBRAMANIAN .N to SUBRAMANIAN .N
# KRISHNAVENI.K to KRISHNAVENI.K
# S.SENTHILKUMAR to S.SENTHILKUMAR
# Ayyasamy.N to Ayyasamy.N
# RAMASWAMY.R to RAMASWAMY.R
# POONITHAVALLI.S to POONITHAVALLI.S
# POONGODI.R to POONGODI.R
# JAHEER HUSSAN to JAHEER HUSSAN
# S.MUTHUKUMAR to S.MUTHUKUMAR
# RANGARAJ . A to RANGARAJ . A
# T SURESH KUMAR to T SURESH KUMAR
# K JEYA SURIYA to K JEYA SURIYA
# M USHA to M USHA
# V.Muruganandam to V.Muruganandam
# S .POONGODI to S .POONGODI
# B.DINESHKUMAR to B.DINESHKUMAR
# S.Shanmuganathan to S.Shanmuganathan
# I.Rifana to I.Rifana
# S.Karthika to S.Karthika
# C.Jananarthanan to C.Jananarthanan
# Palanichamy.A to Palanichamy.A
# R.Ramesh to R.Ramesh
# ASSOCIATED CEMENT CO LIMITED to ASSOCIATED CEMENT CO LIMITED
# MILITARY CAMP MADUKKARAI OLD to MILITARY CAMP MADUKKARAI OLD
# MULLAIVANANAYAKI to MULLAIVANANAYAKI
# AMALI SIRUMALAR to AMALI SIRUMALAR
# NARAANA PERUMAL.S to NARAANA PERUMAL.S
# V.R. BALASUBRAMANI to V.R. BALASUBRAMANI
# A.RADHAMANI to A.RADHAMANI
# M.Swaminathan to M.Swaminathan
# M.R.Vijay to M.R.Vijay
# S.KUMAR to S.KUMAR
# C.Prakash to C.Prakash
# M.Shanmugam to M.Shanmugam
# Ramesh.R to Ramesh.R
# M.Velumani to M.Velumani
# T.Marishwari to T.Marishwari
# M.Samsath Nisha to M.Samsath Nisha
# S. SANTHOSH KUMAR to S. SANTHOSH KUMAR
# v.raju to v.raju
# A.Baby Anthony to A.Baby Anthony
# C.SAKTHIVEL to C.SAKTHIVEL
# V.R.Jothimani to V.R.Jothimani
# T.SAMINATHAN to T.SAMINATHAN
# V.JAYALAKSHMI to V.JAYALAKSHMI
# S.Arumuga perumal to S.Arumuga perumal
# SP.Arunkumar to SP.Arunkumar
# M.Prakash to M.Prakash
# A Prabhu to A Prabhu
# A.Nagarajan to A.Nagarajan
# KOUSHIK TRADING to KOUSHIK TRADING
# CHITHRA to CHITHRA
# HARIKRISHNAN to HARIKRISHNAN
# S.GANESH KUMAR to S.GANESH KUMAR
# T.RAJESWARI to T.RAJESWARI
# AGRITZ ENTERPRISES to AGRITZ ENTERPRISES
# VI PANDIYAN to VI PANDIYAN
# SUDAROLI to SUDAROLI
# DAVID KUMAR to DAVID KUMAR
# C PERIYASAMY to C PERIYASAMY
# S SANKARA NARAYANAN to S SANKARA NARAYANAN
# MM ISMAIL to MM ISMAIL
# KP MOHAMMED RIYAZ to KP MOHAMMED RIYAZ
# K SUMITHA to K SUMITHA
# IM KARTHIKEYAN to IM KARTHIKEYAN
# K VIGNESH to K VIGNESH
# R CHELLAMANI to R CHELLAMANI
# N DURAISAMY to N DURAISAMY
# R DIVYA to R DIVYA
# I ANTHONY MARIYA JOSEPH to I ANTHONY MARIYA JOSEPH
# N.RAJAKUMARI to N.RAJAKUMARI
# Umadevi.N to Umadevi.N
# TNSTC - UKKADAM BRANCH to TNSTC - UKKADAM BRANCH
# SRI AYYAPPA POOJA SANGHAM to SRI AYYAPPA POOJA SANGHAM
# TAMIL NADU SPL POLICE FORCE to TAMIL NADU SPL POLICE FORCE
# MILITARY CAMP MADUKKARAI NEW to MILITARY CAMP MADUKKARAI NEW
# AHS CHILD LAB to AHS CHILD LAB
# AHS to AHS
# THE COMMISSIONER OF POLICE ,   to THE COMMISSIONER OF POLICE ,
# PRESENTATION CONVENT (HEAD POS to PRESENTATION CONVENT (HEAD POS
# KARUNYA LADIES HOSTEL to KARUNYA LADIES HOSTEL
# AHS BEd HOSTEL to AHS BEd HOSTEL
# KARPAGAM COLLEGE OF ARTS to KARPAGAM COLLEGE OF ARTS
# AHS SARATHA ILLAM (OLD AGE) to AHS SARATHA ILLAM (OLD AGE)
# RAMAKRISHNA INSTITUTE OF TECH to RAMAKRISHNA INSTITUTE OF TECH
# NCC CAMP POY to NCC CAMP POY
# PRG MIDDLE SCHOOL to PRG MIDDLE SCHOOL
# REGISTAR AHS PROJECT-II to REGISTAR AHS PROJECT-II
# AMRITA INSTITUTION MESS to AMRITA INSTITUTION MESS
# AMRITA INSTITUTION MESS 2 to AMRITA INSTITUTION MESS 2
# CBE MEDICAL COLLEGE HOSPITAL to CBE MEDICAL COLLEGE HOSPITAL
# GOVT HOSPITAL THONDAMUTHUR to GOVT HOSPITAL THONDAMUTHUR
# RAMACHANDRAN.L to RAMACHANDRAN.L
# RAMESH.S to RAMESH.S
# UKKADAM BUS STAND PARLOUR to UKKADAM BUS STAND PARLOUR
# SIGNAL & TELECOM CANTEEN to SIGNAL & TELECOM CANTEEN
# KIRTILAL KALIDAS JEWELLERY PVT to KIRTILAL KALIDAS JEWELLERY PVT
# NDC CANTEEN to NDC CANTEEN
# RAPID ACTION FORCE-CRPF VELLAL to RAPID ACTION FORCE-CRPF VELLAL
# HARIKUMAR.RN to HARIKUMAR.RN
# A.NOORMUHAMAD to A.NOORMUHAMAD
# R.THANGAVEL to R.THANGAVEL
# S.ARULJOTHI to S.ARULJOTHI
# M.NAGAMANI to M.NAGAMANI
# J.Samitha to J.Samitha
# P.Subbulakshmi to P.Subbulakshmi
# P.K.SAMBU KUMARAN to P.K.SAMBU KUMARAN
# Day to day Supermarket to Day to day Supermarket
# K.KRISHNASAMY to K.KRISHNASAMY
# C.Kailash Raja to C.Kailash Raja
# L.Muthukrishnan to L.Muthukrishnan
# M.Anandakumar to M.Anandakumar
# H.Faizal Rahman to H.Faizal Rahman
# I.SHEMIR to I.SHEMIR
# R.Jayamani to R.Jayamani
# R.Kannan to R.Kannan
# V.Sankili to V.Sankili
# M.SARAVANAKUMAR to M.SARAVANAKUMAR
# P.Dhamodhiran to P.Dhamodhiran
# K.Aadhisivan to K.Aadhisivan
# V.Kumar to V.Kumar
# SUBBAIYA.M to SUBBAIYA.M
# ASST-COMR COPRN (THIRUMAL ST A to ASST-COMR COPRN (THIRUMAL ST A
# ASST-COMR COPRN (KUNIYAMUTHUR  to ASST-COMR COPRN (KUNIYAMUTHUR
# POTHIES PRIVATELTD to POTHIES PRIVATELTD
# KARANYAGENTSHOSTEL to KARANYAGENTSHOSTEL
# HINDUSTAN CEP MENS HOSTEL  to HINDUSTAN CEP MENS HOSTEL
# N to N
# RAHAMATHDULLA A to RAHAMATHDULLA A
# GOPALAKRISHNAN.S to GOPALAKRISHNAN.S
# MOHANRAJ.V to MOHANRAJ.V
# KOILRAJ.P to KOILRAJ.P
# SAKTHIANANDAM.S to SAKTHIANANDAM.S
# MAHALAXMI.R to MAHALAXMI.R
# UTHAYAKUMAR.R to UTHAYAKUMAR.R
# ALWIN.D to ALWIN.D
# MANICAKM.A to MANICAKM.A
# RAJASEKARAN.K to RAJASEKARAN.K
# KOUSALYA.V to KOUSALYA.V
# DEVASENATHIPATHII.K.P to DEVASENATHIPATHII.K.P
# LAKSHMANAN.K.N to LAKSHMANAN.K.N
# KARTHIKEYAN.C to KARTHIKEYAN.C
# VELLAISAMY.S to VELLAISAMY.S
# ASHOK KUMAR.T to ASHOK KUMAR.T
# ASST-COMR.COPRN (KURUCHI. AMMA to ASST-COMR.COPRN (KURUCHI. AMMA
# BALAKRISHNAN.B to BALAKRISHNAN.B
# RAJAMANIKANDAN.K to RAJAMANIKANDAN.K
# RAJA MUHAMAD.D to RAJA MUHAMAD.D
# NAGARAJAN.A to NAGARAJAN.A
# N.C.C.CAMP(KARUNYA) GENTS to N.C.C.CAMP(KARUNYA) GENTS
# MANONMANI.G to MANONMANI.G
# THE CHAIRMEN SIRUVANI MILK STO to THE CHAIRMEN SIRUVANI MILK STO
# R.RANGARAJ to R.RANGARAJ
# NEELAVATHY.G to NEELAVATHY.G
# ASST COMMISS-CORPN(AMMA UNAVAG to ASST COMMISS-CORPN(AMMA UNAVAG
# G Vasantha Devi to G Vasantha Devi
# V Loganayaki to V Loganayaki
# D.Deepa Damodaran to D.Deepa Damodaran
# S.Mayilsamy to S.Mayilsamy
# A.Venkatachalapathy to A.Venkatachalapathy
# M.Sabiya Beygam to M.Sabiya Beygam
# N.Devarajan to N.Devarajan
# S. SAROJINI to S. SAROJINI
# K.Rajesh to K.Rajesh
# TN SPL POLICE 4TH BTN KOVAI PU to TN SPL POLICE 4TH BTN KOVAI PU
# GH MADHUKARAI to GH MADHUKARAI
# HI-TECH PARLOUR to HI-TECH PARLOUR
# SERENE INDUS to SERENE INDUS
# NCC CAMP MADHUKARAI to NCC CAMP MADHUKARAI
# SATTVIC FOOD SOLUTION PVT.LTDK to SATTVIC FOOD SOLUTION PVT.LTDK
# Govt. Hospital Sundakamuthur to Govt. Hospital Sundakamuthur
# SOUNDARARAJAN.R to SOUNDARARAJAN.R
# TNSTC - POLLACHI III BRANCH to TNSTC - POLLACHI III BRANCH
# TNSTC - POLLACHI ENGG to TNSTC - POLLACHI ENGG
# TNSTC - UDUMALPET BRANCH to TNSTC - UDUMALPET BRANCH
# GOVERNMENT HOSPITAL UDUMALPET to GOVERNMENT HOSPITAL UDUMALPET
# GOVT HOSPITAL (POLLACHI) to GOVT HOSPITAL (POLLACHI)
# SUB-JAIL UDUMALPET to SUB-JAIL UDUMALPET
# SUB-JAIL POLLACHI to SUB-JAIL POLLACHI
# valaparai exhibition to valaparai exhibition
# DEVARAJAN R.V. to DEVARAJAN R.V.
# ARUMUGHAM.G to ARUMUGHAM.G
# GANESAN.K to GANESAN.K
# PALANISAMY to PALANISAMY
# SELVA RAJ.S.R to SELVA RAJ.S.R
# SUDHA SHANKAR.D to SUDHA SHANKAR.D
# HAJA.S to HAJA.S
# T.N.S.T.C. - POLLACHI II BRANC to T.N.S.T.C. - POLLACHI II BRANC
# WINNY T D to WINNY T D
# LIVINGSTON MOHANRAJ.T to LIVINGSTON MOHANRAJ.T
# VELMURUGAN.P to VELMURUGAN.P
# MOUNAGURUSAMY.V to MOUNAGURUSAMY.V
# COMMIS-MUNICIPALITY(UDUMALAI-A to COMMIS-MUNICIPALITY(UDUMALAI-A
# S.Senthil kumaravel to S.Senthil kumaravel
# S.P.Aravinth to S.P.Aravinth
# N.Shanthi to N.Shanthi
# A.Mariammal to A.Mariammal
# P.Marimuthu to P.Marimuthu
# D.Krishnan to D.Krishnan
# M.Suregha Banu to M.Suregha Banu
# N. Murugesan to N. Murugesan
# A.P.S. Selvamurali to A.P.S. Selvamurali
# P. Karunakaran to P. Karunakaran
# J.Suresh kumar to J.Suresh kumar
# L.Amudha to L.Amudha
# A.Srinivasan to A.Srinivasan
# S.Dineshkumar to S.Dineshkumar
# K.R.Rasa Gounder, to K.R.Rasa Gounder,
# V.S.Nataraj Kumar to V.S.Nataraj Kumar
# V.Saraswathi to V.Saraswathi
# P. Saraswathi to P. Saraswathi
# A.S.Jabarali to A.S.Jabarali
# K.ARUCHAMY to K.ARUCHAMY
# A.Nagarajan to A.Nagarajan
# V.Mahalakshmi to V.Mahalakshmi
# K.Vellingiri to K.Vellingiri
# K.Sivaganeshan to K.Sivaganeshan
# S.Velumani to S.Velumani
# M.Madhan kumar to M.Madhan kumar
# Darsath Begam to Darsath Begam
# K-879 Udumalpet Town co-op soc to K-879 Udumalpet Town co-op soc
# THIAGARAJAN.V to THIAGARAJAN.V
# R to R
# THIAGARAJAN.V to THIAGARAJAN.V
# SUDHA SHANKAR.D to SUDHA SHANKAR.D
# MICHELRAJ.P to MICHELRAJ.P
# POULOSE.R to POULOSE.R
# PALANISWAMY S.V. to PALANISWAMY S.V.
# A ARUL MURALI to A ARUL MURALI
# KV RAMKUMAR to KV RAMKUMAR
# VIJAYA KUMAR.S to VIJAYA KUMAR.S
# PAULRAJ.C to PAULRAJ.C
# KRISHNAN.M to KRISHNAN.M
# MARIAMMAL.M to MARIAMMAL.M
# THANGAVELU.S to THANGAVELU.S
# AYYAPPAN.M to AYYAPPAN.M
# SUMATHI .S to SUMATHI .S
# PALANI.S to PALANI.S
# TAMILARASAN.K to TAMILARASAN.K
# GOVINDARAJ.M to GOVINDARAJ.M
# SENTHILKUMAR .V to SENTHILKUMAR .V
# MICHELRAJ.P to MICHELRAJ.P
# NEELAMANI.R to NEELAMANI.R
# RAJKUMAR.T to RAJKUMAR.T
# SHANKAR .N to SHANKAR .N
# ANBU SANTHAM .J to ANBU SANTHAM .J
# PADMAVATHY.D to PADMAVATHY.D
# MANI.D to MANI.D
# MURUGESAN.A to MURUGESAN.A
# SEDHURAMALINGAM.S to SEDHURAMALINGAM.S
# MANI KANDAN.V to MANI KANDAN.V
# SAROJINI .R to SAROJINI .R
# JAYAKUMAR .A to JAYAKUMAR .A
# SARAVANAKUMAR.K to SARAVANAKUMAR.K
# KARTHIK.M to KARTHIK.M
# MALATHI.M to MALATHI.M
# SELVI.K to SELVI.K
# K.Gnaprakasam to K.Gnaprakasam
# R SIVAKUMAR to R SIVAKUMAR
# NCC CAMP POLLACHI to NCC CAMP POLLACHI
# G.ANANDHAKUMAR  to G.ANANDHAKUMAR
# MURUGAN.S to MURUGAN.S
# D NANTHAKUMAR to D NANTHAKUMAR
# RAJILA UDUMALAIPET DIRECT to RAJILA UDUMALAIPET DIRECT
# BALAJI (UDUMALAI) to BALAJI (UDUMALAI)
# k.vadivel to k.vadivel
# K 879 UTCS to K 879 UTCS
# V.Velmurugan to V.Velmurugan
# R.Elangesh to R.Elangesh
# N.Radhakrishnan to N.Radhakrishnan
# C.D.Sivakumar to C.D.Sivakumar
# ALPHONESMORY to ALPHONESMORY
# PAULRAJ.C to PAULRAJ.C
# THAINIS SAHAYARANI to THAINIS SAHAYARANI
# VENKATESH.R to VENKATESH.R
# BALASINGAM.C to BALASINGAM.C
# SIVA.G to SIVA.G
# RUKKUMANI.P to RUKKUMANI.P
# JAIPHOON.M to JAIPHOON.M
# J.Rajesh to J.Rajesh
# SELVARAJ.R to SELVARAJ.R
# R.DINESH to R.DINESH
# DHAMODHARAN.A to DHAMODHARAN.A
# JOTHIMANI.P to JOTHIMANI.P
# RAMALINGAM.M to RAMALINGAM.M
# GUNASINGH.D to GUNASINGH.D
# CHANDHRASEKARAN .P to CHANDHRASEKARAN .P
# LAXMI.M to LAXMI.M
# GOVINDARAJ .P to GOVINDARAJ .P
# MANIKANDAN.K to MANIKANDAN.K
# SAMPATH to SAMPATH
# BALUSAMY.R to BALUSAMY.R
# SHARMILA.R to SHARMILA.R
# THAINIS SAHAYARANI to THAINIS SAHAYARANI
# NANDHA KUMAR to NANDHA KUMAR
# ISAKI SELVAM.S to ISAKI SELVAM.S
# BHARATH KUMAR.N to BHARATH KUMAR.N
# RAMASAMY.S to RAMASAMY.S
# SIVARAJ .P to SIVARAJ .P
# DHANAGOPAL.S.V to DHANAGOPAL.S.V
# RAJA MOHAMED(A)COVAI RAJA to RAJA MOHAMED(A)COVAI RAJA
# RAMAKRISHNAN.R to RAMAKRISHNAN.R
# BHUVANESWARAN .K to BHUVANESWARAN .K
# KANAGARAJAN.U to KANAGARAJAN.U
# LINGASAMY .M to LINGASAMY .M
# NATARAJAN .R to NATARAJAN .R
# PONNUSAMY.P to PONNUSAMY.P
# THIRUMAL NADAR.R to THIRUMAL NADAR.R
# BALASUBRAMANIAN.P to BALASUBRAMANIAN.P
# SASIKALA.P to SASIKALA.P
# MANI.K to MANI.K
# SETHU.K to SETHU.K
# Mariya Jagan.J to Mariya Jagan.J
# LAKSHMI.G to LAKSHMI.G
# ITHAYAKANIRAJA.S to ITHAYAKANIRAJA.S
# AROKKIYA SWAMY.T to AROKKIYA SWAMY.T
# SURESH LINGAM .M to SURESH LINGAM .M
# RAJAMANICKEM.M to RAJAMANICKEM.M
# KRISHNA KANTH.N to KRISHNA KANTH.N
# UMA.V to UMA.V
# IMRANKHAN to IMRANKHAN
# LOURDUMARY to LOURDUMARY
# MANIKANDAN to MANIKANDAN
# MICHELRAJ to MICHELRAJ
# SUBRAMANIAN to SUBRAMANIAN
# PAVITHRAN .K.P to PAVITHRAN .K.P
# RAMANI .P.K to RAMANI .P.K
# LAKSHMI.M to LAKSHMI.M
# PARAMASIVAM .R to PARAMASIVAM .R
# SATHICK BATSHA .J to SATHICK BATSHA .J
# RAMAR .T to RAMAR .T
# JAYARAJ .Y to JAYARAJ .Y
# SIVASAKTHIVEL to SIVASAKTHIVEL
# LINGA KUMAR.S to LINGA KUMAR.S
# ANANDHA PABU to ANANDHA PABU
# CHERAMANATHEN .T to CHERAMANATHEN .T
# SARASWATHI .S to SARASWATHI .S
# KUMUTHAM.R to KUMUTHAM.R
# SELVARANI .D to SELVARANI .D
# KRISHNA KUMAR. S to KRISHNA KUMAR. S
# BALAMANI. G to BALAMANI. G
# RAVI .N to RAVI .N
# MADURAMBAL. B to MADURAMBAL. B
# MANOKARAN. A to MANOKARAN. A
# CBE RAILWAY USER S WELFAR ASSO to CBE RAILWAY USER S WELFAR ASSO
# MAZID.P.P to MAZID.P.P
# BALA MURUGAN .M to BALA MURUGAN .M
# ESWARAN.B to ESWARAN.B
# Selvi.K to Selvi.K
# Nagaraj.A to Nagaraj.A
# Raviprakash.V to Raviprakash.V
# G.Chitra to G.Chitra
# Gandhimathy.R to Gandhimathy.R
# VIJAYA.M to VIJAYA.M
# Senthilkumar.S to Senthilkumar.S
# MANONMANI to MANONMANI
# V.S.NAGARAJ to V.S.NAGARAJ
# RAJATHI to RAJATHI
# CHITRA.M to CHITRA.M
# BALAJI.N to BALAJI.N
# THAMILSELVAN.J to THAMILSELVAN.J
# MYLSAMY.R to MYLSAMY.R
# R.Vijayakumar to R.Vijayakumar
# HOTEL SRI RAGHAVASAI to HOTEL SRI RAGHAVASAI
# S.P.JAISANKAR to S.P.JAISANKAR
# Kannan.T to Kannan.T
# sivakumar to sivakumar
# GANESHAN.S to GANESHAN.S
# VEERABATHIRAN to VEERABATHIRAN
# ARUKKANI to ARUKKANI
# VICE CHAIRMAN CO_OPP STAFF to VICE CHAIRMAN CO_OPP STAFF
# KANDASWAMY.S to KANDASWAMY.S
# LAKSHMI PRIYA.M to LAKSHMI PRIYA.M
# MANIGANDAN.K to MANIGANDAN.K
# JAYAPRAKASH.R to JAYAPRAKASH.R
# S.SANTHANALAKSHMI to S.SANTHANALAKSHMI
# P.BALASUBRAMANIAM to P.BALASUBRAMANIAM
# R.Velumani to R.Velumani
# A Rahamathullah to A Rahamathullah
# M.Karthik to M.Karthik
# K.Karthikeyan to K.Karthikeyan
# N.Senthaamarai to N.Senthaamarai
# M.Saravanan to M.Saravanan
# S.Gowreeshwari to S.Gowreeshwari
# M.Nandhini to M.Nandhini
# R Jayalakshmi to R Jayalakshmi
# S.Kandasamy to S.Kandasamy
# A.Chinnathambi to A.Chinnathambi
# G.Govindaraj to G.Govindaraj
# Easwari to Easwari
# R.Selvi, to R.Selvi,
# G.Mohanraj to G.Mohanraj
# S.Saminathan to S.Saminathan
# P.Saraswathi to P.Saraswathi
# K.Boominathan to K.Boominathan
# G.MANICKAVALLI to G.MANICKAVALLI
# V.SUBHA to V.SUBHA
# S.SANTHALINGAM to S.SANTHALINGAM
# S.Kumararajapandiyan to S.Kumararajapandiyan
# R.Vijay amirtharaj to R.Vijay amirtharaj
# Ravishankar ganesh to Ravishankar ganesh
# D.KRISHNAVENI to D.KRISHNAVENI
# NR.RAJENDRAN to NR.RAJENDRAN
# P.LINGAM to P.LINGAM
# N.VIVEKANANDHAN to N.VIVEKANANDHAN
# C.SOUNDHARARAJ to C.SOUNDHARARAJ
# K.BALASUBRAMANI to K.BALASUBRAMANI
# R.JAMUNA RANI to R.JAMUNA RANI
# D VASANTHAKUMARI to D VASANTHAKUMARI
# S SIVADHASAN to S SIVADHASAN
# DEVI KARUPPUSAMI to DEVI KARUPPUSAMI
# S LATHA to S LATHA
# R AKILA to R AKILA
# R PATEESWARAN to R PATEESWARAN
# K SURESH KUMAR to K SURESH KUMAR
# S LOGAPRIYA to S LOGAPRIYA
# GUNASELAN W to GUNASELAN W
# A Sharmal to A Sharmal
# KRISHNAKUMARI to KRISHNAKUMARI
# N.SIDHARTHAN to N.SIDHARTHAN
# T SOUNDHARAPANDIYAN to T SOUNDHARAPANDIYAN
# CHANDRAN.K.C to CHANDRAN.K.C
# VISPARK JEWELLERY MFRS (P)LTD to VISPARK JEWELLERY MFRS (P)LTD
# M/S SUNDHARAM & CO, N to M/S SUNDHARAM & CO, N
# STATE EXPRESS TRANSPORT COPN to STATE EXPRESS TRANSPORT COPN
# JAI KRISHNA AUTO to JAI KRISHNA AUTO
# SHIVA DISTILLERIES LTD to SHIVA DISTILLERIES LTD
# DIST to DIST
# CMS Edu&ChariTrust(MenHostel) to CMS Edu&ChariTrust(MenHostel)
# CMS COLLEGE NSS CAMP to CMS COLLEGE NSS CAMP
# NCC CAMP - GIRLS to NCC CAMP - GIRLS
# INFO INSTITUTE OF ENGG to INFO INSTITUTE OF ENGG
# KIRTILAL KALIDASS JEWELLRY (P) to KIRTILAL KALIDASS JEWELLRY (P)
# KIRTHILAL KALIDASS "A" to KIRTHILAL KALIDASS "A"
# SDAT SPORTS HOSTEL COIMBATORE to SDAT SPORTS HOSTEL COIMBATORE
# CENTRAL PRISON to CENTRAL PRISON
# CRPF Central Prision to CRPF Central Prision
# ASST-COMR COPRN (SARAVANAMPATT to ASST-COMR COPRN (SARAVANAMPATT
# Reliance Retail Ltd-Saravanamp to Reliance Retail Ltd-Saravanamp
# CMS Edu&ChariTrust(WomenHostel to CMS Edu&ChariTrust(WomenHostel
# ASST-COMR.COPRN (MTP.BUS STAND to ASST-COMR.COPRN (MTP.BUS STAND
# ASST-COMR.COPRN (MANI.KARAPALA to ASST-COMR.COPRN (MANI.KARAPALA
# G.Manikandan to G.Manikandan
# Iswariya Fertility Centre to Iswariya Fertility Centre
# Tamilnadu Hotel to Tamilnadu Hotel
# T.N.S.T.C - ANNUR BRANCH to T.N.S.T.C - ANNUR BRANCH
# NCC Camp Boys to NCC Camp Boys
# N.C.C CAMP to N.C.C CAMP
# TRAINING CENTER CENTRAL PRISON to TRAINING CENTER CENTRAL PRISON
# V SARANYA to V SARANYA
# G MOHANRAJ to G MOHANRAJ
# K SENTHIL to K SENTHIL
# SERENE to SERENE
# S RAJESHKUMAR to S RAJESHKUMAR
# JUSTIN to JUSTIN
# A ANTHONY JHON PAUL to A ANTHONY JHON PAUL
# A SUMATHI to A SUMATHI
# A MANIKAVASAGAM to A MANIKAVASAGAM
# A.SASIKALA to A.SASIKALA
# S.RANISHANMUGAM to S.RANISHANMUGAM
# Superentendent of prisons to Superentendent of prisons
# M SARAVAN KUMAR to M SARAVAN KUMAR
# T.PREMAVATHI to T.PREMAVATHI
# R.Mohan to R.Mohan
# S.Gomathi to S.Gomathi
# Thiudiyalur Urban Coop Agricul to Thiudiyalur Urban Coop Agricul
# M.Srilakshmi to M.Srilakshmi
# R.Manikandan to R.Manikandan
# SHREEE ABOORVAS  PUR VEG RESTA to SHREEE ABOORVAS  PUR VEG RESTA
# S.Murugesan to S.Murugesan
# D.Alexander to D.Alexander
# GOVT POLYTECHNIC HOSTEL FOR WO to GOVT POLYTECHNIC HOSTEL FOR WO
# VICE CHAIRMAN CO_OPP STAFF to VICE CHAIRMAN CO_OPP STAFF
# ZAHEER HUSAIN.A.J to ZAHEER HUSAIN.A.J
# SHAJAHAN to SHAJAHAN
# STEPHAN JOSEPH.D to STEPHAN JOSEPH.D
# GAYATHRI.K to GAYATHRI.K
# RAJAPPAN.R to RAJAPPAN.R
# JAYASELVI.G to JAYASELVI.G
# MOORTHY.R to MOORTHY.R
# EASWARAN.S to EASWARAN.S
# SREERANGARAJ.P to SREERANGARAJ.P
# KALLA PERUMAL.S to KALLA PERUMAL.S
# SADAYAPPAN.S to SADAYAPPAN.S
# BALASUNDARAM.K to BALASUNDARAM.K
# RAJKUMAR to RAJKUMAR
# RATHINASAMY to RATHINASAMY
# SELVASEKARAN.P to SELVASEKARAN.P
# YASHODHA to YASHODHA
# MAHENDRAN.D to MAHENDRAN.D
# ASRAF ALI.P.T. to ASRAF ALI.P.T.
# MOHANA.S to MOHANA.S
# GAYATHRI.S to GAYATHRI.S
# RAMAKRISHANAN to RAMAKRISHANAN
# RAJAN.A to RAJAN.A
# SENTHILKUMAR .S to SENTHILKUMAR .S
# RAVI.N to RAVI.N
# KAMARAJ.C.P to KAMARAJ.C.P
# SELVI.D to SELVI.D
# SMT.A.HEMALATHA to SMT.A.HEMALATHA
# JAYAKUMAR.B to JAYAKUMAR.B
# ARUTHAL KUMAR.D to ARUTHAL KUMAR.D
# KOUSALYA.S to KOUSALYA.S
# BHUVANESWARI.T to BHUVANESWARI.T
# PREMILA.N to PREMILA.N
# SHANMUGAM.M to SHANMUGAM.M
# MATHANKUMAR .S to MATHANKUMAR .S
# VIJAYAKUMAR to VIJAYAKUMAR
# MOHANKUMAR .C to MOHANKUMAR .C
# BATHAKARA SELVAN to BATHAKARA SELVAN
# RAILWAY STATION PARLOUR to RAILWAY STATION PARLOUR
# Gandhi Puram Bus Stand Parlour to Gandhi Puram Bus Stand Parlour
# V.O.C.PARK PARLOUR to V.O.C.PARK PARLOUR
# L.G.BALAKRISHNAN BROS to L.G.BALAKRISHNAN BROS
# RAJAPERUMAL A to RAJAPERUMAL A
# SURESH KUMAR .D to SURESH KUMAR .D
# A.Parvinbanu to A.Parvinbanu
# J.Ponraj to J.Ponraj
# M.Joy Vimal to M.Joy Vimal
# G.Ravichandran to G.Ravichandran
# L.Rajkumar to L.Rajkumar
# NABISHA BEHAM to NABISHA BEHAM
# HOTEL EMS MYURA METTUPALAYAM to HOTEL EMS MYURA METTUPALAYAM
# SWAMI SATCHITHANANTHA HIGER SE to SWAMI SATCHITHANANTHA HIGER SE
# TAMIL NADU FOREST COLLEGE & RE to TAMIL NADU FOREST COLLEGE & RE
# ELEPHANT CAMP MTP to ELEPHANT CAMP MTP
# GOVT HOSPITAL (METTUPALAYAM) to GOVT HOSPITAL (METTUPALAYAM)
# GOVT HOSPITAL PERIYACKENPALAYA to GOVT HOSPITAL PERIYACKENPALAYA
# PRICOL PLANT 1 to PRICOL PLANT 1
# Reliance Retail Ltd- PN Palaya to Reliance Retail Ltd- PN Palaya
# THANGAVEL.K to THANGAVEL.K
# T.N.S.T.C. - METTUPPALAYAM BRA to T.N.S.T.C. - METTUPPALAYAM BRA
# SIVAKUMAR K to SIVAKUMAR K
# Mani K to Mani K
# RAJU.K to RAJU.K
# k.SHANMUGAVADIVEL to k.SHANMUGAVADIVEL
# COMMISSI-MUNICIPALAITY(MTP-AMM to COMMISSI-MUNICIPALAITY(MTP-AMM
# S.Radha to S.Radha
# T.R.Shanmuga sundaram to T.R.Shanmuga sundaram
# R.Bahyalaskhmi to R.Bahyalaskhmi
# P.UMARANI to P.UMARANI
# M.CHANDRASEKARAN to M.CHANDRASEKARAN
# A.KAMARAJ to A.KAMARAJ
# A.Susheela to A.Susheela
# N.Pragadeeswaran to N.Pragadeeswaran
# R.Kulandaivel to R.Kulandaivel
# JOTHIRAJ.G to JOTHIRAJ.G
# SYED HARIZ ABDHUL KADHAR to SYED HARIZ ABDHUL KADHAR
# NCC CAMP MTP to NCC CAMP MTP
# M SUBRAMANI to M SUBRAMANI
# SRI ALLIMUTHU to SRI ALLIMUTHU
# D SATHEESH to D SATHEESH
# M KARUNAKARAN to M KARUNAKARAN
# VS BALAYOGESHWARAN to VS BALAYOGESHWARAN
# R RAVI to R RAVI
# R SRINIVASAN to R SRINIVASAN
# R DAISY RANI to R DAISY RANI
# R.JEBA ESTHER RANI to R.JEBA ESTHER RANI
# D MURALIDHARAN to D MURALIDHARAN
# V NAVAMANI to V NAVAMANI
# R DEVAKUMAR to R DEVAKUMAR
# P.Vaiyapuri Ganesh to P.Vaiyapuri Ganesh
# S.Agathursamy to S.Agathursamy
# S.Veralakshmi to S.Veralakshmi
# P.Kathiroli to P.Kathiroli
# Y.IMMANUVEL to Y.IMMANUVEL
# A.Rahimabeevi  to A.Rahimabeevi
# S.Thangamani to S.Thangamani
# D.Nithya to D.Nithya
# D.Savithiri to D.Savithiri
# K.Arthi to K.Arthi
# BHUVANESWARI.R to BHUVANESWARI.R
# LEAKAGE ALLOWANCE to LEAKAGE ALLOWANCE
# TIRUPPUR CO-OP to TIRUPPUR CO-OP
# TCMCS to TCMCS
# VELLAISAMY to VELLAISAMY
# R to R
# KANAGARAJAN.S to KANAGARAJAN.S
# N.C.C.CAMP TPR to N.C.C.CAMP TPR
# K.VELLAISAMY to K.VELLAISAMY
# Eeswari.P to Eeswari.P
# NILGRIS MCCS to NILGRIS MCCS
# GOVERNMENTHOSPITALTPR to GOVERNMENTHOSPITALTPR
# A.V.TRADING ENTERPRISES to A.V.TRADING ENTERPRISES
# SRI KUMARAN ENTERPRISES to SRI KUMARAN ENTERPRISES
# P.SAKTHIVEL to P.SAKTHIVEL
# HIGH TECH PARLOUR-TPR. to HIGH TECH PARLOUR-TPR.
# Eastman exports global clothin to Eastman exports global clothin
# Tiruppur Ari Co-Op Marketing S to Tiruppur Ari Co-Op Marketing S
# SREE ANNAPOORNA SREE GOWRISANK to SREE ANNAPOORNA SREE GOWRISANK
# M.SATHISH KUMAR to M.SATHISH KUMAR
# S SATHYASEELAN to S SATHYASEELAN
# D SATHISH KUMAR to D SATHISH KUMAR
# MULAIVANANAYAGI to MULAIVANANAYAGI
# VIKAS VIDHYALAYA SCHOOL to VIKAS VIDHYALAYA SCHOOL
# SWAMY AIYAPPAN AGENCIES to SWAMY AIYAPPAN AGENCIES
# KP MOHAMMED RIYAZ to KP MOHAMMED RIYAZ
# vishnu clothing company to vishnu clothing company
# DHARAPURAM to DHARAPURAM
# PALANISAMY.E. to PALANISAMY.E.
# ERD STAFF MILK to ERD STAFF MILK
# COLLE PARLOUR to COLLE PARLOUR
# PRISON BAZAAR (PETROL OUTLET) to PRISON BAZAAR (PETROL OUTLET)
# P.Jothimani to P.Jothimani
# Jayabalthomas Koilraj to Jayabalthomas Koilraj
# P.Rameshkumar to P.Rameshkumar
# V.Edwin Paul to V.Edwin Paul
# Marimuthu.S to Marimuthu.S
# M.Sujini to M.Sujini
# R.M.KARMUHILAN to R.M.KARMUHILAN
# B.PRAVEENBOOPATHY to B.PRAVEENBOOPATHY
# SUMATHI.L to SUMATHI.L
# DINESH.K to DINESH.K
# Thiripurasundari.N to Thiripurasundari.N
# Shanthi.P to Shanthi.P
# M.Prakash to M.Prakash
# P.Tamilselvi to P.Tamilselvi
# J.SELVAN to J.SELVAN
# M.PALANIVEL to M.PALANIVEL
# G.S.KALISHWARI to G.S.KALISHWARI
# Coimbatore District Milk Agent to Coimbatore District Milk Agent
# TIRUPPUR to TIRUPPUR
# M THANARAJ to M THANARAJ
# NANDHINIDEVI to NANDHINIDEVI
# NANDHINIDEVI to NANDHINIDEVI
# E to E
# MANIVANNAN to MANIVANNAN
# KP MOHAMMED RIYAZ to KP MOHAMMED RIYAZ
# Day to day Supermarket to Day to day Supermarket
# L to L
# SRI ALLIMUTHU to SRI ALLIMUTHU
# S SATHYASEELAN to S SATHYASEELAN
# D SATHISH KUMAR to D SATHISH KUMAR
# MULAIVANANAYAGI to MULAIVANANAYAGI
# FROSTO to FROSTO
# SWAMY AIYAPPAN AGENCIES to SWAMY AIYAPPAN AGENCIES
# KP MOHAMMED RIYAZ to KP MOHAMMED RIYAZ
# PALANISAMY to PALANISAMY
# PRISON BAZAAR (PETROL OUTLET to PRISON BAZAAR (PETROL OUTLET
# A to A
# SRI KUMARAN ENTERPRISES to SRI KUMARAN ENTERPRISES
# coim to coim
# abdu to abdu
# poot to poot
# SK agency to SK agency
# R.Sivamanikandan to R.Sivamanikandan
#  to
# SANTHOH KUMAR S to SANTHOH KUMAR S
# Geetha to Geetha
# TCMPF CHENNAI to TCMPF CHENNAI
# T SURESH KUMAR to T SURESH KUMAR
# suyaraj.L to suyaraj.L
# K.Karnan Maharaja Krishnan to K.Karnan Maharaja Krishnan
# suresh kumar charles to suresh kumar charles
# poorani.s to poorani.s
# Sri Murugappa Traders to Sri Murugappa Traders
# Annathangaraj.N to Annathangaraj.N
# ELANGOVAN to ELANGOVAN
# J.Mahenthiran to J.Mahenthiran
# C.Paramasivam to C.Paramasivam
# V. Ganeshkumar to V. Ganeshkumar
# S.K.AGENCES  to S.K.AGENCES
# R.Ramamoorthy to R.Ramamoorthy
# BABUSHANKER to BABUSHANKER
# K.Sakthivel to K.Sakthivel
# Joseph jeromay to Joseph jeromay
# Selvi to Selvi
# Prakashraja to Prakashraja
# MUHAMMAD SALI KOYILATH to MUHAMMAD SALI KOYILATH
# M.SENTHILKUMAR to M.SENTHILKUMAR
# M.R.Geetha to M.R.Geetha
# Sasikala Hepzibha to Sasikala Hepzibha
# Azhagudurai to Azhagudurai
# Jenifer to Jenifer
# MICHELRAJ to MICHELRAJ
# AMUTHAM CANTEEN to AMUTHAM CANTEEN
# TNSTC - CBE HEAD OFFICE to TNSTC - CBE HEAD OFFICE
# AHS HIGHER SECONDARY SCHOOL to AHS HIGHER SECONDARY SCHOOL
# PSG ARTS AND SCIENCE HOSTEL to PSG ARTS AND SCIENCE HOSTEL
# KARPAGAM ENGG to KARPAGAM ENGG
# ADITHYA INSTITUTE OF TECH to ADITHYA INSTITUTE OF TECH
# Velumani to Velumani
# ALAGESAN.B to ALAGESAN.B
# MANORANJITHAM to MANORANJITHAM
# SIVAKUMAR .K to SIVAKUMAR .K
# Mrs.MANICKAM .R to Mrs.MANICKAM .R
# BOOPATHY R. to BOOPATHY R.
# BALAKRISHNAN.S to BALAKRISHNAN.S
# VELUMANI.R to VELUMANI.R
# CHINNASAMY.R to CHINNASAMY.R
# MURUGESAN.S to MURUGESAN.S
# RAJENDRAN.V to RAJENDRAN.V
# KAVITHA .A to KAVITHA .A
# JOHNSON to JOHNSON
# SUNDRAM.R to SUNDRAM.R
# JABASEELAN.I to JABASEELAN.I
# SUMATHI.S to SUMATHI.S
# SIVABACKIYAM.R to SIVABACKIYAM.R
# MUTHUKRISHNAN .A to MUTHUKRISHNAN .A
# VADIVEL.K to VADIVEL.K
# KALYANASUNDARAM.S to KALYANASUNDARAM.S
# LAKSHMI .M to LAKSHMI .M
# STELLA.M to STELLA.M
# SRIGOVINDAN.A.K to SRIGOVINDAN.A.K
# SAMYNATHAN.A to SAMYNATHAN.A
# VIJAYAKUMAR.J to VIJAYAKUMAR.J
# RENUGA.R to RENUGA.R
# VIJAYALAKSHMI.G to VIJAYALAKSHMI.G
# MAGESH KUMAR .P to MAGESH KUMAR .P
# SIVAATHAL.R to SIVAATHAL.R
# SUNDRAN .K to SUNDRAN .K
# U. ASAN KOYA to U. ASAN KOYA
# CBE SPINNING & WEAVING MILL (S to CBE SPINNING & WEAVING MILL (S
# T.N.S T.C. - SUNGAM BRANCH to T.N.S T.C. - SUNGAM BRANCH
# SIVAKAMI R to SIVAKAMI R
# ALAMELU.A.R to ALAMELU.A.R
# R.BALASUBRAMANIYAN to R.BALASUBRAMANIYAN
# K.Dhandapani to K.Dhandapani
# N . SUDHA to N . SUDHA
# A.M.Krishnamurthy to A.M.Krishnamurthy
# MOHAN .R to MOHAN .R
# MURUGAN MILL to MURUGAN MILL
# Sasireka to Sasireka
# ASAN KOYA to ASAN KOYA
# Tamilselvi to Tamilselvi
# L.VADIVELKUMAR to L.VADIVELKUMAR
# KANNA MOBILES	 to KANNA MOBILES
# joyvimal to joyvimal
# Gowtham to Gowtham
# Natraj to Natraj
# C.GANESH KUMAR  to C.GANESH KUMAR
# R.Manimaran to R.Manimaran
# REXALIN.V. to REXALIN.V.
# P.R.P.ENTERPRISES to P.R.P.ENTERPRISES
# Sasikumar to Sasikumar
# C VADIVELU to C VADIVELU
# SERENE SENBAGAM to SERENE SENBAGAM
# R ARUNKUMAR to R ARUNKUMAR
# SM JAMEELAHMED to SM JAMEELAHMED
# PREMLATHA.S to PREMLATHA.S
# S.Saravanan to S.Saravanan
# MURUGESAN.V to MURUGESAN.V
# NDC COFFEE PARLOUR to NDC COFFEE PARLOUR
# ABDUL RAHIMAN.M.K.S to ABDUL RAHIMAN.M.K.S
# UNION BOOTH CARD to UNION BOOTH CARD
# LAKSHMANAN.M to LAKSHMANAN.M
# SELVA RAJ N. to SELVA RAJ N.
# LEELAVATHI.R to LEELAVATHI.R
# AVINACHIAPPAN.K to AVINACHIAPPAN.K
# DHANALAKSHIMI to DHANALAKSHIMI
# PRITHIVIRAJ.T to PRITHIVIRAJ.T
# REKHA.K to REKHA.K
# S.BALASUBRAMANIAN to S.BALASUBRAMANIAN
# SUBBULAKSHMI.M to SUBBULAKSHMI.M
# R.DharmendraDuraikannan to R.DharmendraDuraikannan
# GUNASEKARAN.S to GUNASEKARAN.S
# GEETHA.C to GEETHA.C
# SAVITHRI.K to SAVITHRI.K
# V.SURESH KUMAR to V.SURESH KUMAR
# SADASIVAM.B to SADASIVAM.B
# BALASUBRAMANIAM R. to BALASUBRAMANIAM R.
# RAJAN M. to RAJAN M.
# GOPINATH.P to GOPINATH.P
# VIJAYAKUMAR .D to VIJAYAKUMAR .D
# KANAGA JESURAJ to KANAGA JESURAJ
# G.Suseela to G.Suseela
# M.Visalakshi to M.Visalakshi
# CHANDRAN.V to CHANDRAN.V
# R.BALASUBRAMANIAN to R.BALASUBRAMANIAN
# P.R.P. ENTERPRISES to P.R.P. ENTERPRISES
# VINOTHKUMAR to VINOTHKUMAR
# Balamurali to Balamurali
# Saravanan to Saravanan
# ANTHONYSAMY to ANTHONYSAMY
# FROSTO to FROSTO
# R CHITRA to R CHITRA
# MANOJPRABHAKAR to MANOJPRABHAKAR
# MANIMARAN .R. to MANIMARAN .R.
# KALYANI.K to KALYANI.K
# SHARANALAYAM to SHARANALAYAM
# RAMAKRISHNAN.S to RAMAKRISHNAN.S
# GOPALAKRISHNAN.B to GOPALAKRISHNAN.B
# GANESAN .P to GANESAN .P
# VENKATACHALAM to VENKATACHALAM
# NAGARAJ. K to NAGARAJ. K
# VEERAPANDIYAN.V to VEERAPANDIYAN.V
# T.N S.T.C.  - UPPILIPALAYAM BR to T.N S.T.C.  - UPPILIPALAYAM BR
# ADITHYA AUTO STORES to ADITHYA AUTO STORES
# COMMISS-MUNICI(AMMA UNAVAGAM-P to COMMISS-MUNICI(AMMA UNAVAGAM-P
# R. MUTHUKUMAR to R. MUTHUKUMAR
# D.MOHANKUMAR to D.MOHANKUMAR
# N.Ziya ul Haq to N.Ziya ul Haq
# M.Gunasekaran to M.Gunasekaran
# V.Ravikumar to V.Ravikumar
# M.Jerina to M.Jerina
# ESSTEE EXPORTS  to ESSTEE EXPORTS
# WATER TEC INDIA PVT LTD to WATER TEC INDIA PVT LTD
# V.Pappathi to V.Pappathi
# C.Murugesan to C.Murugesan
# T.Usha to T.Usha
# ABDULNASSAR.C to ABDULNASSAR.C
# l.santhana kumar to l.santhana kumar
# m.sivakumar to m.sivakumar
# K.AYYAMPERUMAL to K.AYYAMPERUMAL
# T.ASOKKUMAR to T.ASOKKUMAR
# FAIZAL RAHMAN to FAIZAL RAHMAN
# R.REVATHI to R.REVATHI
# S.Thilakavathi to S.Thilakavathi
# THIRUMALAI.V to THIRUMALAI.V
# C.SUMATHI to C.SUMATHI
# j.mariyal  to j.mariyal
# s.anuratha to s.anuratha
# J.ASAKPAUL to J.ASAKPAUL
# rajaboovathy to rajaboovathy
# rajan .s. to rajan .s.
# Suganthi. R to Suganthi. R
# Gopalsamy.c. to Gopalsamy.c.
# prathap.n. to prathap.n.
# M Dinesh Kumar to M Dinesh Kumar
# B.KRISHNAVENI  to B.KRISHNAVENI
# raghul.j. to raghul.j.
# S,SAVITHRI to S,SAVITHRI
# MOHAMED YASIN to MOHAMED YASIN
# Pushpavelli to Pushpavelli
# A.DARVIN FARILO to A.DARVIN FARILO
# L.Arul karthigeyan to L.Arul karthigeyan
# P.SATHIYAPERUMAL to P.SATHIYAPERUMAL
# S.RAMA CHANDRA BOSS to S.RAMA CHANDRA BOSS
# C.SURESH KUMAR to C.SURESH KUMAR
# N.SRINIVASAN to N.SRINIVASAN
# JANSIRANI MAHALIR SHG to JANSIRANI MAHALIR SHG
# dakshin.r. to dakshin.r.
# Anthony Gnanasowridass to Anthony Gnanasowridass
# m.ganesh kumar to m.ganesh kumar
# Sandeep to Sandeep
# Punithavathy to Punithavathy
# Balamurali to Balamurali
# A.DARWIN BHARILO to A.DARWIN BHARILO
# A.Manickavasagam to A.Manickavasagam
# v.mohan kumar  to v.mohan kumar
# A.WILSON to A.WILSON
# s.geetha to s.geetha
# GEETHA.S. to GEETHA.S.
# Uma to Uma
# P.SANMUGASUNDARAM to P.SANMUGASUNDARAM
# BHAVANESHWARI .S to BHAVANESHWARI .S
# V.ARULPRAKASH to V.ARULPRAKASH

# %%
for agent in Agent.objects.filter():
    agent.first_name = agent.user_profile.user.first_name
    agent.last_name = agent.user_profile.user.last_name   
    agent.email = agent.user_profile.user.email
    agent_profile_obj = AgentProfile(union_id=agent.user_profile.union.id,
                                    street=agent.user_profile.street,
                                    gender_id=agent.user_profile.gender.id,
                                    taluk_id=agent.user_profile.taluk.id,
                                    district_id=agent.user_profile.district.id,
                                    state_id=agent.user_profile.state.id,
                                    mobile=agent.user_profile.mobile,
                                    alternate_mobile=agent.user_profile.alternate_mobile,
                                    pincode=agent.user_profile.pincode,
                                    image=agent.user_profile.image)
    agent_profile_obj.save()
    agent.agent_profile_id=agent_profile_obj.id
    agent.save()
    
    print('{}'.format(agent.user_profile.user.first_name))
# Out:
# SATHICK BATSHA .J
# RAMAKRISHNAN.S
# G.MANJULA
# THEIVAMANI .C
# G SELVAM
# NAGARAJ .M - [1525]
# MURUGAN .K
# SATHIYASEELAN .S
# PALANISAMY .M
# DHANALAKSHIMI
# BABU.G
# ANANDAKUMAR.R.C - [250]
# M.PREMKUMAR
# M.Ramesh
# M.PREMKUMAR
# MANI .T
# RAJENDRAN .B
# SANTHOH KUMAR S
# KAVITHA .A
# RAJENDERAN.G.M
# SAMIADIYAN.I
# ANANDAKUMAR.R.C - [250]
# SHANTHY .K
# RANJITHAM .D
# Pushpa.S
# LAKSHMI .R
# MANI .P
# MARUTHACHALAM .S
# PARIMALA .P
# KANNAMMAL .P
# ABIRAHAM .E
# MALLIKA.S
# SREENIVASAN.M
# VENUGOPAL.S
# SUMATHI.S
# SUBBULAKSHMI .N
# LATHA .A
# WATER TEC INDIA PVT LTD
# RAMAKRISHNAN .D
# LAKSHMI ELECTRICAL CONTROL SYS
# JAGADEESAN  .C
# JAYACHANDRAN .B
# DEVAKI.G
# MUTHUKRISHNAN .A
# BALASUBRAMANIAN.K.A
# RENUGA
# DHANAGOPAL .S
# SIVARAMAN.S
# RAJESWARI.G
# PALANISAMY.M
# MANIKANDAN.C
# BASHA .B
# LAKSHMI .M
# SENTHILVEL .B
# MANJULA
# LALITHAMANI.K
# SHANTHAMANI.R
# VELLINGIRI.K
# M.Visalakshi
# PAARTHIBAN .J
# AZHA.C
# RATHIKA.T
# KARTHIKEYAN .S.P.
# AMIRTHAM.R
# K.NAVEEN
# JAYANTHI .S
# D.SURESH
# SARAVANAN.M
# MANOJPRABHAKAR
# UDAYAKUMAR .K
# RAVI.V
# MOHAMED YUSUF.K.A
# MUTHUKUMARASWAMY.R
# SANKARI BADRI LAKSHIMI.L
# PUSPAM.M
# SATHYAPRIYA.P
# RANI.A
# JAYAMMA.R
# JAYAKUMAR.P
# SAMPATH.M
# BALASUNDRAM.P
# SHANTHAMANI.R
# SIVAATHAL.R
# VEERAPANDIYAN.V
# KAMATCHI.G
# GEORGE .J
# RAJAPANDIAN.G
# HEMAVATHI.B
# AMBIRAJ.T.S
# COMBODIA MILL
# RANGAVILAS MILL
# PANKAJA MILL
# SRI KANNAPIRAN MILLS
# SanjeevKumar
# SIVAKAMI R
# KUMARAVEL.S
# MANIKANDAN.S
# JAYANTHI.K
# KARTHIKEYAN
# Relaince Retail Ltd- Masakkali
# TNSTC - ONDIPUDUR BRANCH
# UNIT RATION STAND SULUR
# ASG RACE COURSE
# WILMAC ENGG INDIA P LTD
# G-PLAST (P)LTD
# G PLAST  A
# ESWARAN.N.R
# RAJAMANICKAM .V
# MANOKARAN.A.V
# P.BALAMURUGAN
# L.JEGAJEEVAN
# Sarojini.K
# Kavitha.K
# RAJAMMAL.P
# MALAIAPPAN.A
# R.KANCHANA
# P.KANNAN
# V.MUTHURAMAN
# D.SAKTHIVEL
# N.SUSEELA
# C.V.SRINIVASAN
# R.GANDHINATHAN
# V.N.JOTHIMANI
# V.N.RAVANAN
# A.RATHINAM
# M.AMUTHA
# C.RAJU
# N . SUDHA
# R. MUTHUKUMAR
# S.AMSAVENNI
# P . SUGANTHI
# P.UMAMAHESWARI
# Singai Ranganathan
# P.Kalamani
# C.Murugesan
# TNSTC - KARUMATHAMPATTI BRANCH
# KAVIRAJ.R
# LAKSHIMI PRECISION TOOLS LTD
# PSG & SONS FOUNDARY NEELAMB
# DOG SQUAD SULUR POLICE ST CAMP
# l.santhana kumar
# Relaince Retail Ltd- Ramanatha
# S.A.Arumugam
# R.Ashok kumar
# M.Then mozhi
# P.S.KARTHIKEYAN
# J.Solomon
# M.Yasodha Sree
# V.Ravikumar
# K.Mariya joseph
# P.Jayaraman
# V.Shanmuga Sundaram
# Mohanraj
# M.Gaushal vashini
# K.Nithya
# M.Jerina
# K.Ramthilak
# M.Palaniyappa Deva
# Air force Admn - College
# C.DHANAPAL
# MANOHAR
# YesodhaSri
# N TAMILMANI
# D.CHANDRA
# M VAISNAVI
# V SUGANYA
# K
# COSMOPLITON CLUB
# PSG ARTS AND SCIENCE HOSTEL
# PSG
# PSG TECH HOSTEL
# GRG CANTEEN
# GRG LADIES HOSTEL
# PSG HOSPITALS - DIETARY
# GOVTPOLYTECHNIC HOSTEL FOR MEN
# SNR COLLEGE
# RATHNAVEL SUBRAMANIAM COLLEGE
# COIMBATORE MEDICAL COLLEGE LAD
# SNR COLLEGE LADIES
# HINDUSTAN COLLEGE HOSTEL(MEN)
# R JAYASAKTHI
# N NANDHAKUMAR
# K RAJKUMAR
# KV ANANDHI
# R VENKATACHALAM
# V MURUGANANDHAM
# M THANARAJ
# B SHANMUGASUNDARAM
# M THANDAPANI
# B VEERATHAL
# M SIVAKUMAR
# S NARMADHA
# S.NARMATHA
# S.ELAKKIYA
# S.AROKKIYASELI
# P.Prince
# M.Rajeshwari
# R.Manikandan
# A Prabu
# S.JAYAKUMAR
# S.Poongodi
# HINDUSTAN COLLEGE LADIES HOSTE
# N GEETHA LAXMI
# N KARTHIK
# K.Indirani
# RVS LADIES HOSTEL
# NCC CAMP
# TAMILNADU COLLEGE ENGG HOSTEL
# CBE MEDICAL COLL MENS HOSTEL
# TEJAA SAKTHI INSTITUTE OF TECH
# PSG CAFEPERIA
# SRI JAYENDRA SARASWATHY TRUST
# NCC CAMP
# GRDC S MEN S HOSTEL
# GRDC S WOMEN S HOSTEL
# ASST-COMR COPRN (SIN
# PSG TECH CANTEEN
# PARK COLLEGE
# NCC CAMP
# NCC CAMP
# POLICE HPL
# OBSERVATION HOME
# ESI HOSPITAL
# PR SCHOOL
# SULUR GOVT HOSPITAL
# USHA
# m.sivakumar
# PILDOSS.I
# MALARVIZHI
# JOTHI .K
# MOORTHY.A
# ASST-COMR.COPRN (M.K.PALAYAM.
# IRUDAYARAJ
# CHARLES.P
# SULOCHANA .V
# MOORTHY.A
# Reliance Retail Ltd - Fun Mall
# BALASUNDARAM M.
# Shanthi Gears  A&B Unit
# Shanthi Gears Foundary
# KOUSALYA.R
# Mrs.MANICKAM .R
# Shanthi Gears C Unit
# USHA.R
# MOHAN DAS M.
# GBJ Hotels Pvt ltd
# R RAJA
# SENTHILKUMAR
# SULOCHANA V
# BALAN.V
# Thiru Murugar Spinning Mill
# VELUMANI.R
# S.BALASUBRAMANIAN
# Dr NGP School
# RANGANATHAN.S.N.
# IRUDAYARAJ
# TNSTC - SULUR
# P.S.G. HOSTEL - MEDICAL
# DHARAMARAJ.M
# R ARJUNAN
# SERENE ROSE
# SASIKALA.N
# MADURA MESS
# SUSEELA
# GUNASEKARAN.S
# WATER TEC INDIA PVT LTD
# MANI.R
# SARASWATHI.M
# RAJENDRAN.V
# MAHALASHMI.M
# THANGAPANDIAN.P
# SELVI.V
# INDIRA.P
# SUSEELA
# SARASWATHY.S
# RAVICHANDRAN.V
# K.AYYAMPERUMAL
# JOTHIMANI.D
# KENNADY.A
# RAVINDRAN.N
# CHITRA.S.P
# INDRAMANI.N
# REENARAGUPATHY
# RAJAN M.
# RAJASEKAR.R
# KANNAN.R
# V.Narayanan
# RENNUKKA.D
# THANGAM.M
# VANITHA.K
# PALANI.U
# SARADHA
# SRINIVASAN.M
# SORIMUTHU.C
# LALY ABRAHAM
# GOPALAKRISHNAN.B
# VALLIMYIL.R
# VIJAYARAJ.M
# HARIKRISHNAN.T
# SOUNDRAPANDI.T
# RAMESH.R
# VIJAYA.A
# RAMASAMY.N
# SRIGOVINDAN.A.K
# P.Kesavaraj
# MURUGESAN.V
# MOHANASUNDARAM.K
# ANITHAKUMARI. V
# SRINIVASAN.K
# SHANMUGAM.M
# M.ANNADURAI
# DEEPAN.P
# JOSEPH JAYAKUMAR.J
# JANAKARAJ.A
# SORIMUTHU
# KRISHNAMOORTHY
# PECHIMUTHU
# KANNAMAL LADIES HOSTER(BHA
# TNSTC - MARUTHAMALAI BRANCH
# GOVT COLLEGE OF TECH HOSTEL
# GOVT COLLEGE OF TECH CANTEEN
# SFSC STUDENTS MESS
# The Wardern, Studt Hos,TNAU,Cb
# DEAF AND DUMB SCHOOL
# THIRUVALLUVAR HOSTEL(BHA
# ELANGO HOSTEL(BHA
# AHS FACULTY OF EDU
# SPL CAMP AHSENG COLLEGE
# SEKHIZLAR HOSTEL - BHA UNIV
# SELLAMMAL LADIES HOSTEL
# PERIYAR LADIES HOSTEL - BHA UN
# ST PAULS M HR S SCHOOL
# ASST-COMR COPRN (FLOWER MARKET
# NCC Camp Coimbatore
# AMBUJAM.R
# RAMKUMAR
# PALANISAMY.S
# RENUGA.R
# NANDHINIDEVI.G
# KANNAN.K
# NAGARAJ.K
# GUNASEKARAN.S
# KRISHNAMOORTHY.A
# NARAYANAN.T
# NCC Camp-Agri
# DEVARAJ.S
# BALASUBRAMANIAM.M
# GOVINDAN.C.R
# GOVINDAN.C.R
# SULAIGH BEEBI.K.M
# POOBALAKRISHNAN.R
# HIDAYATHULLAH.A
# JOTHIMANI.R
# ARUMUGAM .P
# SUBBURAM.C
# NEELA.S
# RANGARAJ.A
# MANGALAM
# SHANMUGAVALLI.K
# ROBERT .R.M
# THANGARAJ.G
# SENTHILKUMAR.B
# MALLIKA .J
# BALAKRISHNAN.S
# U. ASAN KOYA
# VIJAYAKUMAR.N
# SUBBULAKSHMI.M
# KAMBAR HOSTEL(BHA.UNI)
# SENTHILKANNAN.R
# MOHAN.D
# A.H.S.ENGG.COLLEGE
# KANAGAVALLI.B
# SOTHERN ROADWAYS TSNO8MTP.ROAD
# HARIHARAN..V
# UNION STAFF BENEFIT ACCCOUNT
# SHENAKAVALLI.J
# LATHA R
# B.Chithra
# VANISREE.S
# ALAMELU.A.R
# Kuyili.A
# Chandran.N
# BALASUBRAMANI.P
# RAJAMOHAMAD
# S.Saradhamani
# Amrita Vidyalayam, Nallampalay
# SELLAMAL
# M.Krishnan
# Reliance Retail Ltd- Saibaba C
# B.CHITRADEVI
# R.Seethalakshmi
# P.Jinath
# S.RAVI
# Pannai Pasumai - RS Puram
# Pannai Pasumai - Vadavalli
# SARATHAMANI
# V.SIVALINGAM
# SL.MANIKAM
# E.PALANISAMY
# K CHITRA
# S RATHINAM
# S.SETHU GAYATHRI DEVI
# J DINESH BABU
# K SARAVANAN
# J LAKSHMI
# KV.DURAISAMY
# N.Sharmila
# Vidhya Kala
# N.Renuka
# KANNA MOBILES
# A.Natarajan
# K.Lakshmi
# R.Barathy
# JOHNSON
# BOOPATHY.S
# JOHNSON
# UNION PARLOUR
# EXHIBITION
# SHANMUGAM.K
# V.JAYARAMAN
# MURUGESAN.S
# NARAYANASAMY.K
# Pannai Pasumai - Flower Market
# PECHIMUTHU.K
# RANGARAJ.V
# Pannai Pasumai - Townhall
# VENKATACHALAM.P
# RAJU S.
# Pannai Pasumai - SB Colony
# SARADHAMANI.K
# RAJESWARI.G
# B.U.-KASTHURIBAI HOSTEL
# R.Dharani
# B.U.- VASUGI HOSTEL
# VASAN.R.S
# V DANASEKARAN
# SARASWATHY.A
# Anna University ,coimbatore
# THE MADUKKRAI C.W.E.C.S.LTD
# RAHAMATHDULLA A.
# ABDUL SAMAD.I
# KARANYA GENTS HOSTEL
# MURUGESAN
# YUVARAJ.A
# CHINNARAJ.A
# PARYJOHN BEGHAM.K
# STELLAMARY.M
# VENKATACHALAM.P.A
# SILAMBARASAN.T.M
# KOMARSEBASTIN.G
# SARASWATHY.R
# ABOOTHAHEER
# ANNADURAI.S
# MENAKA.S
# SURESH KUMAR.H
# MANIVANNAN.V
# THANGAM.Y
# KANAGA JESURAJ
# INDIRANI.K
# PARVATHIMUTHU.C
# SARADHA.H
# MUTHULAKSHMI.S
# ABDIL NAZAR
# SUBRAMANIAN.P
# ABUBACKER SITHQUE .A
# LOGANATHA GUPTHA
# SAMYNATHAN.A
# MOHAMAD HANSAR
# Ravikumar.P
# DEVASAGAYAM.D
# MURUGESWARI.N
# KARTHIKEYAN.C
# MALLIKA.K
# PUNITHAVALLI.A
# RAVINDRAN.R
# ARUNACHALAM.S
# GUNASINGH.S.R
# SARASWATHY.D
# SUNDARAVADIVEL.P
# SUBBAIAH.P
# R.Ramesh
# BALAKRISHNAN.S
# MANIMARAN .R.
# T.ASOKKUMAR
# ASHOK KUMAR.P
# KALA.S
# SULIMAN.M.M
# PAGAYARAJ.A
# GOWRI.G
# JAYAGANESH.C
# ANTONISAMY.R
# JAYANACHIAR.S
# PREMAKUMARI.V
# ABDULRAHMAN .V.I
# BABURAJ.P
# RAMESHKUMAR.K
# MAREESWARAN.M
# GEORGE.C.C.
# SOUNTHER JOHN.K
# MOHAMED SALIM.K
# MULLAIVANANAYAKI
# MOHAMMED UBAIS K.A
# VENKATACHALAM
# SATHIYA
# SUBBIAH .K
# RAJAN.S
# MATHIVANAN.V.R
# Umadevi.N
# LavanyaDevi
# Neelaveni.R
# SenthilKumar.P
# ARUMUGAM.N
# MANJU.J
# KRISHNAVENI.K
# S.SENTHILKUMAR
# Ayyasamy.N
# RAMASWAMY.R
# POONITHAVALLI.S
# POONGODI.R
# JAHEER HUSSAN
# S.MUTHUKUMAR
# RANGARAJ . A
# T SURESH KUMAR
# M USHA
# S .POONGODI
# B.DINESHKUMAR
# S.Shanmuganathan
# I.Rifana
# Palanichamy.A
# AMALI SIRUMALAR
# NARAANA PERUMAL.S
# M.R.Vijay
# S.KUMAR
# C.Prakash
# M.Jagatheessan
# Ramesh.R
# N.Ziya ul Haq
# S. SANTHOSH KUMAR
# v.raju
# A.Baby Anthony
# C.SAKTHIVEL
# V.R.Jothimani
# T.SAMINATHAN
# S.Karthika
# M.Velumani
# V.R. BALASUBRAMANI
# Ganesan R.R
# THIRUMANI.S.P
# DHARAMARAJ.M
# BALASUBRAMANIAM R.
# SP.Arunkumar
# RAMACHANDRAN.L
# RAMESH.S
# M.Prakash
# HAJA.S
# SOUNDARARAJAN.R
# A Prabhu
# A.Nagarajan
# KOUSHIK TRADING
# HARIKRISHNAN
# S.GANESH KUMAR
# T.RAJESWARI
# AGRITZ ENTERPRISES
# VI PANDIYAN
# C VADIVELU
# SUDAROLI
# C PERIYASAMY
# S SANKARA NARAYANAN
# MM ISMAIL
# AMUTHAM CANTEEN
# ASSOCIATED CEMENT CO LIMITED
# MILITARY CAMP MADUKKARAI OLD
# TNSTC - UKKADAM BRANCH
# SRI AYYAPPA POOJA SANGHAM
# TAMIL NADU SPL POLICE FORCE
# MILITARY CAMP MADUKKARAI NEW
# AHS CHILD LAB
# AHS HIGHER SECONDARY SCHOOL
# AHS
# THE COMMISSIONER OF POLICE ,
# PRESENTATION CONVENT (HEAD POS
# KARANYAGENTSHOSTEL
# KARUNYA LADIES HOSTEL
# AHS BEd HOSTEL
# KARPAGAM COLLEGE OF ARTS
# AHS SARATHA ILLAM (OLD AGE)
# RAMAKRISHNA INSTITUTE OF TECH
# NCC CAMP POY
# PRG MIDDLE SCHOOL
# REGISTAR AHS PROJECT-II
# AMRITA INSTITUTION MESS
# AMRITA INSTITUTION MESS 2
# ASST-COMR COPRN (THIRUMAL ST A
# ASST-COMR COPRN (KUNIYAMUTHUR
# POTHIES PRIVATELTD
# HINDUSTAN CEP MENS HOSTEL
# N
# CBE MEDICAL COLLEGE HOSPITAL
# GOVT HOSPITAL THONDAMUTHUR
# RAHAMATHDULLA A
# KP MOHAMMED RIYAZ
# IM KARTHIKEYAN
# K VIGNESH
# R CHELLAMANI
# R DIVYA
# I ANTHONY MARIYA JOSEPH
# A.NOORMUHAMAD
# R.THANGAVEL
# S.ARULJOTHI
# M.NAGAMANI
# J.Samitha
# P.Subbulakshmi
# P.K.SAMBU KUMARAN
# Day to day Supermarket
# C.Kailash Raja
# L.Muthukrishnan
# M.Anandakumar
# H.Faizal Rahman
# I.SHEMIR
# RADHAMANI.R
# NANDHINIDEVI.G
# MALARVIZHI
# RAILWAY STATION PARLOUR
# KOILRAJ.P
# SAKTHIANANDAM.S
# SIGNAL & TELECOM CANTEEN
# UTHAYAKUMAR.R
# ALWIN.D
# T.N S.T.C.  - UPPILIPALAYAM BR
# MANICAKM.A
# RAJASEKARAN.K
# KIRTILAL KALIDAS JEWELLERY PVT
# KOUSALYA.V
# DEVASENATHIPATHII.K.P
# NDC CANTEEN
# LAKSHMANAN.K.N
# KALYANI.K
# RAPID ACTION FORCE-CRPF VELLAL
# SHARANALAYAM
# R
# TNSTC - POLLACHI III BRANCH
# TNSTC - POLLACHI ENGG
# TNSTC - UDUMALPET BRANCH
# GOVERNMENT HOSPITAL UDUMALPET
# KARPAGAM ENGG
# GOVT HOSPITAL (POLLACHI)
# SUB-JAIL UDUMALPET
# SUB-JAIL POLLACHI
# valaparai exhibition
# VELLAISAMY.S
# WINNY T D
# HARIKUMAR.RN
# LIVINGSTON MOHANRAJ.T
# VELMURUGAN.P
# MOUNAGURUSAMY.V
# ASST-COMR.COPRN (KURUCHI. AMMA
# RAJAMANIKANDAN.K
# RAJA MUHAMAD.D
# N.C.C.CAMP(KARUNYA) GENTS
# THE CHAIRMEN SIRUVANI MILK STO
# R.RANGARAJ
# NEELAVATHY.G
# COMMIS-MUNICIPALITY(UDUMALAI-A
# ASST COMMISS-CORPN(AMMA UNAVAG
# COMMISS-MUNICI(AMMA UNAVAGAM-P
# G Vasantha Devi
# S.Mayilsamy
# A.Venkatachalapathy
# M.Sabiya Beygam
# N.Devarajan
# S. SAROJINI
# S.Senthil kumaravel
# S.P.Aravinth
# N.Shanthi
# A.Mariammal
# P.Marimuthu
# TN SPL POLICE 4TH BTN KOVAI PU
# GH MADHUKARAI
# HI-TECH PARLOUR
# SERENE INDUS
# SERENE SENBAGAM
# NCC CAMP MADHUKARAI
# SATTVIC FOOD SOLUTION PVT.LTDK
# R.Kannan
# V.Sankili
# M.SARAVANAKUMAR
# P.Dhamodhiran
# K.Aadhisivan
# V.Kumar
# MICHELRAJ.P
# ARUMUGHAM.G
# N. Murugesan
# PALANISAMY
# SELVA RAJ.S.R
# A.P.S. Selvamurali
# SUDHA SHANKAR.D
# MICHELRAJ.P
# BOOPATHY R.
# P. Karunakaran
# ALPHONESMORY
# PAULRAJ.C
# POULOSE.R
# J.Suresh kumar
# MURUGAN.S
# SUDHA SHANKAR.D
# VIJAYA KUMAR.S
# A.Srinivasan
# PAULRAJ.C
# THIAGARAJAN.V
# KRISHNAN.M
# S.Dineshkumar
# MARIAMMAL.M
# THIAGARAJAN.V
# THANGAVELU.S
# K.R.Rasa Gounder,
# LOURDUMARY
# MICHELRAJ
# SUMATHI .S
# V.S.Nataraj Kumar
# PALANI.S
# TAMILARASAN.K
# P. Saraswathi
# SAVITHRI.K
# GOVINDARAJ.M
# A.S.Jabarali
# SENTHILKUMAR .V
# K.ARUCHAMY
# RAJKUMAR.T
# SHANKAR .N
# A.Nagarajan
# ANBU SANTHAM .J
# V.Mahalakshmi
# PADMAVATHY.D
# K.Vellingiri
# K.Sivaganeshan
# S.Velumani
# MANI.D
# Darsath Begam
# K-879 Udumalpet Town co-op soc
# SEDHURAMALINGAM.S
# K.Gnaprakasam
# R SIVAKUMAR
# NCC CAMP POLLACHI
# MANI KANDAN.V
# A ARUL MURALI
# KV RAMKUMAR
# JAYAKUMAR .A
# D NANTHAKUMAR
# RAJILA UDUMALAIPET DIRECT
# BALAJI (UDUMALAI)
# SARAVANAKUMAR.K
# k.vadivel
# K 879 UTCS
# KARTHIK.M
# R.Elangesh
# MALATHI.M
# N.Radhakrishnan
# C.D.Sivakumar
# SELVI.K
# THIRUMALAI.V
# MUTHUMANI .M
# MICHELRAJ
# BALASINGAM.C
# SIVA.G
# RAMAR .T
# JAIPHOON.M
# J.Rajesh
# JAYARAJ .Y
# SELVARAJ.R
# R.DINESH
# SIVASAKTHIVEL
# DHAMODHARAN.A
# JOTHIMANI.P
# LINGA KUMAR.S
# RAMALINGAM.M
# SIVABACKIYAM.R
# MAGESH KUMAR .P
# CHANDHRASEKARAN .P
# LAXMI.M
# ANANDHA PABU
# GOVINDARAJ .P
# THAINIS SAHAYARANI
# MANIKANDAN
# SUBRAMANIAN
# MANIKANDAN.K
# SARASWATHI .S
# SAMPATH
# BALUSAMY.R
# KUMUTHAM.R
# SHARMILA.R
# NANDHA KUMAR
# NAGARAJ. K
# ISAKI SELVAM.S
# KANDASWAMY.S
# SELVARANI .D
# BHARATH KUMAR.N
# RAMASAMY.S
# KRISHNA KUMAR. S
# SIVARAJ .P
# RAMAKRISHNAN.R
# BALAMANI. G
# BHUVANESWARAN .K
# KANAGARAJAN.U
# RAVI .N
# LINGASAMY .M
# PONNUSAMY.P
# MADURAMBAL. B
# THIRUMAL NADAR.R
# BALASUBRAMANIAN.P
# MANOKARAN. A
# SASIKALA.P
# MANI.K
# SUNDRAN .K
# SETHU.K
# Mariya Jagan.J
# CBE RAILWAY USER S WELFAR ASSO
# LAKSHMI.G
# MAZID.P.P
# ITHAYAKANIRAJA.S
# ESWARAN.B
# ASST-COMR.COPRN (R.N.PURAM.80F
# RAJAMANICKEM.M
# T.Marishwari
# KRISHNA KANTH.N
# UMA.V
# PAVITHRAN .K.P
# RAMANI .P.K
# LAKSHMI.M
# MURUGAN MILL
# Nagaraj.A
# Raviprakash.V
# G.Chitra
# Gandhimathy.R
# Senthilkumar.S
# Reliance Retail Ltd-Saravanamp
# MANONMANI
# V.S.NAGARAJ
# RAJATHI
# CHITRA.M
# BALAJI.N
# THAMILSELVAN.J
# MYLSAMY.R
# HOTEL SRI RAGHAVASAI
# S.P.JAISANKAR
# sivakumar
# GANESHAN.S
# VEERABATHIRAN
# ARUKKANI
# CHANDRAN.K.C
# LAKSHMI PRIYA.M
# MANIGANDAN.K
# JAYAPRAKASH.R
# S.SANTHANALAKSHMI
# R.Velumani
# A Rahamathullah
# M.Karthik
# G.Manikandan
# N.Senthaamarai
# M.Saravanan
# S.Gowreeshwari
# M.Nandhini
# D.MOHANKUMAR
# R Jayalakshmi
# A.Chinnathambi
# G.Govindaraj
# Easwari
# R.Selvi,
# G.Mohanraj
# A.M.Krishnamurthy
# P.Saraswathi
# K.Boominathan
# G.MANICKAVALLI
# V.SUBHA
# S.Kumararajapandiyan
# R.Vijay amirtharaj
# Ravishankar ganesh
# D.KRISHNAVENI
# NR.RAJENDRAN
# P.LINGAM
# C.SOUNDHARARAJ
# K.BALASUBRAMANI
# R.JAMUNA RANI
# D VASANTHAKUMARI
# S SIVADHASAN
# A SUMATHI
# DEVI KARUPPUSAMI
# R PATEESWARAN
# IMRANKHAN
# K SURESH KUMAR
# S LOGAPRIYA
# GUNASELAN W
# A Sharmal
# KRISHNAKUMARI
# K SENTHIL
# R CHITRA
# JUSTIN
# S.A.MURUGESAN
# NABISHA BEHAM
# ZAHEER HUSAIN.A.J
# N.SIDHARTHAN
# STEPHAN JOSEPH.D
# GAYATHRI.K
# T SOUNDHARAPANDIYAN
# JAYASELVI.G
# MOORTHY.R
# V SARANYA
# EASWARAN.S
# SREERANGARAJ.P
# G MOHANRAJ
# KALLA PERUMAL.S
# SADAYAPPAN.S
# A MANIKAVASAGAM
# BALASUNDARAM.K
# TNSTC - CBE HEAD OFFICE
# M/S SUNDHARAM & CO, N
# STATE EXPRESS TRANSPORT COPN
# JAI KRISHNA AUTO
# SHIVA DISTILLERIES LTD
# DIST
# CMS Edu&ChariTrust(MenHostel)
# CMS COLLEGE NSS CAMP
# NCC CAMP - GIRLS
# INFO INSTITUTE OF ENGG
# ADITHYA INSTITUTE OF TECH
# SDAT SPORTS HOSTEL COIMBATORE
# ASST-COMR COPRN (SARAVANAMPATT
# CENTRAL PRISON
# CRPF Central Prision
# KALYANASUNDARAM.S
# A.SASIKALA
# CHANDRAN.V
# RATHINASAMY
# S.RANISHANMUGAM
# YASHODHA
# MAHENDRAN.D
# Superentendent of prisons
# BHUVANESWARI.R
# ASRAF ALI.P.T.
# M SARAVAN KUMAR
# GAYATHRI.S
# RAMAKRISHANAN
# T.PREMAVATHI
# S.Gomathi
# RAJAN.A
# M.Srilakshmi
# SENTHILKUMAR .S
# R.Manikandan
# S.Murugesan
# RAVI.N
# A.Parvinbanu
# KAMARAJ.C.P
# J.Ponraj
# KIRTHILAL KALIDASS "A"
# VICE CHAIRMAN CO_OPP STAFF
# VISPARK JEWELLERY MFRS (P)LTD
# KIRTILAL KALIDASS JEWELLRY (P)
# M.Joy Vimal
# SELVI.D
# G.Ravichandran
# SMT.A.HEMALATHA
# L.Rajkumar
# ARUTHAL KUMAR.D
# BHUVANESWARI.T
# PREMILA.N
# MATHANKUMAR .S
# VIJAYAKUMAR
# VENKATESH.R
# MOHANKUMAR .C
# THANGAVEL.K
# BATHAKARA SELVAN
# VIJAYAKUMAR.J
# V.O.C.PARK PARLOUR
# KANAGARAJAN.S
# L.G.BALAKRISHNAN BROS
# T.N.S.T.C. - METTUPPALAYAM BRA
# Reliance Retail Ltd- PN Palaya
# HOTEL EMS MYURA METTUPALAYAM
# SWAMI SATCHITHANANTHA HIGER SE
# TAMIL NADU FOREST COLLEGE & RE
# ELEPHANT CAMP MTP
# PRICOL PLANT 1
# GOVT HOSPITAL (METTUPALAYAM)
# LEAKAGE ALLOWANCE
# TIRUPPUR CO-OP
# VELLAISAMY
# TCMCS
# ADITHYA AUTO STORES
# GOVT POLYTECHNIC HOSTEL FOR WO
# N.C.C.CAMP TPR
# K.VELLAISAMY
# RAJAPERUMAL A
# SIVAKUMAR K
# Mani K
# ASST-COMR.COPRN (MTP.BUS STAND
# ASST-COMR.COPRN (MANI.KARAPALA
# SURESH KUMAR .D
# RAJU.K
# NILGRIS MCCS
# GOVERNMENTHOSPITALTPR
# K.Dhandapani
# COMMISSI-MUNICIPALAITY(MTP-AMM
# T.R.Shanmuga sundaram
# R.Bahyalaskhmi
# P.UMARANI
# A.KAMARAJ
# Iswariya Fertility Centre
# M.Gunasekaran
# P.SAKTHIVEL
# Tamilnadu Hotel
# T.N.S.T.C - ANNUR BRANCH
# HIGH TECH PARLOUR-TPR.
# N.Pragadeeswaran
# Eastman exports global clothin
# R.Kulandaivel
# Tiruppur Ari Co-Op Marketing S
# NCC Camp Boys
# N.C.C CAMP
# ESSTEE EXPORTS
# JOTHIRAJ.G
# M.SATHISH KUMAR
# SYED HARIZ ABDHUL KADHAR
# TRAINING CENTER CENTRAL PRISON
# NCC CAMP MTP
# S SATHYASEELAN
# SRI ALLIMUTHU
# D SATHEESH
# M KARUNAKARAN
# R RAVI
# VIKAS VIDHYALAYA SCHOOL
# SERENE
# R SRINIVASAN
# SM JAMEELAHMED
# R DAISY RANI
# R.JEBA ESTHER RANI
# D MURALIDHARAN
# vishnu clothing company
# SHREEE ABOORVAS  PUR VEG RESTA
# FAIZAL RAHMAN
# A.V.TRADING ENTERPRISES
# SRI KUMARAN ENTERPRISES
# SREE ANNAPOORNA SREE GOWRISANK
# D SATHISH KUMAR
# MULAIVANANAYAGI
# FROSTO
# B
# SK agency
# M THANARAJ
# NANDHINIDEVI
# NANDHINIDEVI
# E
# MANIVANNAN
# KP MOHAMMED RIYAZ
# Day to day Supermarket
# L
# SRI ALLIMUTHU
# S SATHYASEELAN
# D SATHISH KUMAR
# MULAIVANANAYAGI
# FROSTO
# SWAMY AIYAPPAN AGENCIES
# KP MOHAMMED RIYAZ
# PALANISAMY
# PRISON BAZAAR (PETROL OUTLET
# A
# SRI KUMARAN ENTERPRISES
# coim
# abdu
# poot
# R.Sivamanikandan
#
# KP MOHAMMED RIYAZ
# DHARAPURAM
# PALANISAMY.E.
# ERD STAFF MILK
# R DEVAKUMAR
# COLLE PARLOUR
# PRISON BAZAAR (PETROL OUTLET)
# S.Agathursamy
# S.Veralakshmi
# P.Kathiroli
# Y.IMMANUVEL
# A.Rahimabeevi
# S.Thangamani
# D.Nithya
# D.Savithiri
# ABDULNASSAR.C
# suyaraj.L
# P.Jothimani
# Jayabalthomas Koilraj
# K.Karnan Maharaja Krishnan
# P.Rameshkumar
# suresh kumar charles
# Marimuthu.S
# M.Sujini
# K.Arthi
# poorani.s
# R.M.KARMUHILAN
# SUMATHI.L
# DINESH.K
# M.Prakash
# Sri Murugappa Traders
# Annathangaraj.N
# P.Tamilselvi
# J.SELVAN
# M.PALANIVEL
# Coimbatore District Milk Agent
# A.Karuppasamy
# MOHAN .R
# MANORANJITHAM
# C.Paramasivam
# LAKSHMANAN.M
# R.REVATHI
# SIVAKUMAR .K
# SELVA RAJ N.
# TCMPF CHENNAI
# T SURESH KUMAR
# PRITHIVIRAJ.T
# Geetha
# S.K.AGENCES
# V. Ganeshkumar
# DEVARAJAN R.V.
# BOOPATHY RAJAN.N
# M.SENTHILKUMAR
# EZILARASI.S
# PALANISWAMY S.V.
# BABUSHANKER
# SENTHILKUMAR.M
# MANI.T
# K.Sakthivel
# THIRVENI.SMT
# CHINNASAMY.R
# VELLINGIRI P.
# PREMLATHA.S
# SHANMUGASUNDARAM.R - [1992]
# RAJASEKRAN.C
# KAVITHAMANI .S
# PALANISAMY .P.K.
# V.Sasikala Gnasampantham
# MANI.S.M
# SAROJINI .R
# SUNDRAM.R
# ANGAMUTHU.P
# JABASEELAN.I
# RUKKUMANI.P
# POONKOTHAI.B
# MURUGESHAN.N
# SUBBAIYA.M
# GUNASINGH.D
# RAJAPPAN.R
# Thiripurasundari.N
# M Dinesh Kumar
# GOPALAKRISHNAN.V
# Sasikala Hepzibha
# M.R.Geetha
# R.Ramamoorthy
# Prakashraja
# Joseph jeromay
# Selvi
# NAGENDRAN.A
# THAINIS SAHAYARANI
# SELVAPANDIAN.M
# SADHASIVAM .P
# M.Ananda Kumar
# RAJA MOHAMED(A)COVAI RAJA
# RAJKUMAR
# TIRUPPUR
# KALAISELVI
# MAHALAXMI.R
# BASHEER .M.M
# MOHANA.S
# GAYATHRI
# JAYAKUMAR.B
# AMUTHAVALLI.R
# SHANMUGAM.M
# NATARAJAN .R
# DHAMODARAN.C
# R.Shanthi
# SIVAPACKIYAM.M
# SURESHKUMAR.R
# AROKKIYA SWAMY.T
# M.Pappathi
# CHERAMANATHEN .T
# VIJAYALAKSHMI.G
# MALAISAMY.A
# SARASWATHI.R
# PARAMASIVAM .R
# SELVARAJ.A
# SHANMUGASUNDARAM.C
# R.USHA
# UKKADAM BUS STAND PARLOUR
# SOWKKATHALI.S.M
# CBE SPINNING & WEAVING MILL (S
# T.N.S T.C. - SUNGAM BRANCH
# VIJAYA.M
# Eeswari.P
# CHOKALINGAM.K
# SUBRAMANIAN .N
# NAGARAJAN.A
# Kannan.T
# MYTHILI.V
# VASANTHA
# V.Muruganandam
# B.Ravikumar
# K.Karthikeyan
# C.Jananarthanan
# ASST.COMMISSIONER-AMMA UNAVAGA
# V Loganayaki
# K.THANGAVEL
# S.Radha
# M.Shanmugam
# S.Kandasamy
# J.Chitra Devi
# M.P.Kumar
# K.Rajesh
# M.Samsath Nisha
# D.Krishnan
# L.Amudha
# V.Saraswathi
# S.Jayaparvathi
# S.Saminathan
# M.CHANDRASEKARAN
# A.Susheela
# V.JAYALAKSHMI
# M.Madhan kumar
# P.Chairman Rajkumar
# K.Natesan
# CHITHRA
# A.KANNAMAL
# N.VIVEKANANDHAN
# N SOMASUNDHARAM
# DAVID KUMAR
# S LATHA
# T DHANDAPANI
# S.Thilakavathi
# UNION BOOTH CARD
# NDC COFFEE PARLOUR
# LEELAVATHI.R
# C.SUMATHI
# M.Sripriya
# AVINACHIAPPAN.K
# R ARUNKUMAR
# DHANALAKSHIMI
# VINOTHKUMAR
# RAGHAVAN.P
# SWAMY AIYAPPAN AGENCIES
# REKHA.K
# ASAN KOYA
# Tamilselvi
# S RAJESHKUMAR
# GANESAN.K
# P.R.P. ENTERPRISES
# G.ANANDHAKUMAR
# L.VADIVELKUMAR
# GANESAN.K
# A TARUN
# ANTHONYSAMY
# KANNA MOBILES
# joyvimal
# N DURAISAMY
# VIJAYA.S
# Gowtham
# C.GANESH KUMAR
# R.Manimaran
# REXALIN.V.
# P.R.P.ENTERPRISES
# V.SURESH KUMAR
# V.Velmurugan
# SULOCHANA .V
# V.Pappathi
# G.Suseela
# K.Sunilkumar
# P.Vaiyapuri Ganesh
# R.Mohan
# AYYAPPAN.M
# D.BALAJI
# Govt. Hospital Sundakamuthur
# R.Jayamani
# BHARKATH NISHA.S
# R.BALASUBRAMANIAN
# M.Thiyagarajan
# V.Edwin Paul
# Shanthi.P
# NEELAMANI.R
# VAITHEESWARAN.V
# MURUGESAN.A
# ABDUL RAHIMAN.M.K.S
# JAYAMANI .S
# GURUMOORTHY.K
# SHAJAHAN
# SADASIVAM.B
# GANESAN .P
# MOHANKUMAR.V
# RAJESH.N
# KANNAMMAL .A
# BALA MURUGAN .M
# GOPINATH.P
# DULASIAMMAL.V
# Gandhi Puram Bus Stand Parlour
# DEVARAJ .A
# T.N.S.T.C. - POLLACHI II BRANC
# CMS Edu&ChariTrust(WomenHostel
# Selvi.K
# Revathi.P
# JAYARAM.L
# VIJAYAKUMAR .D
# BALAKRISHNAN.B
# SENTHIL KUMAR.R
# R.Vijayakumar
# VADIVEL.K
# GOPALAKRISHNAN.S
# ARCHANA
# MOHANRAJ.V
# FATHIMABEEBE
# Gunasekaran.A
# STELLA.M
# DHANAGOPAL.S.V
# P.BALASUBRAMANIAM
# Chinnadurai.V
# SELVASEKARAN.P
# R.BALASUBRAMANIYAN
# KOUSALYA.S
# KANNAN .A
# JAYASENTHILAN.V
# K JEYA SURIYA
# BABY HEMALATHA
# SURESH LINGAM .M
# k.SHANMUGAVADIVEL
# JEYANTHI.S.M
# UMMAR FARUK.A
# M.Manimekalai
# RAJASHANKER.S.G
# CHARLES JOSEPH.J.M
# D.Deepa Damodaran
# SHANMUGASUNDRAM.N
# M.Swaminathan
# M.Suregha Banu
# Sasikumar
# S.SANTHALINGAM
# S.Arumuga perumal
# C.SATHYAVAN
# M SUBRAMANI
# VS BALAYOGESHWARAN
# A ANTHONY JHON PAUL
# K SUMITHA
# R AKILA
# SATHIYASEELAN .S
# V NARAYANAN
# V NAVAMANI
# S.Saravanan
# B.Tamilselvan
#  S.Sathishkumar
# R.DharmendraDuraikannan
# T.Usha
# K.KRISHNASAMY
# MUHAMMAD SALI KOYILATH
# B.PRAVEENBOOPATHY
# G.S.KALISHWARI
# ELANGOVAN
# D.Alexander
# J.Mahenthiran
# A.DARWIN BHARILO
# j.mariyal
# s.anuratha
# J.ASAKPAUL
# rajaboovathy
# rajan .s.
# Gopalsamy.c.
# prathap.n.
# Natraj
# ALAGESAN.B
# B.KRISHNAVENI
# s.geetha
# Sasireka
# VICE CHAIRMAN CO_OPP STAFF
# raghul.j.
# S.RAMA CHANDRA BOSS
# C.SURESH KUMAR
# N.SRINIVASAN
# JANSIRANI MAHALIR SHG
# dakshin.r.
# Anthony Gnanasowridass
# m.ganesh kumar
# Sandeep
# Punithavathy
# A.Manickavasagam
# Balamurali
# N.RAJAKUMARI
# v.mohan kumar
# S,SAVITHRI
# P.SATHIYAPERUMAL
# Balamurali
# MOHAMED YASIN
# A.DARVIN FARILO
# Pushpavelli
# P.SANMUGASUNDARAM
# A.WILSON
# GEETHA.S.
# Uma
# K.Sameem Mohammed Ali
# Suganthi. R
# KANAGARAJ .C
# Azhagudurai
# KASTHURIGANGA
# UDAYAKUMAR .K
# GEETHA.C
# KARTHIK.L
# SARASWATHI
# SREENIVASAN.R
# A.RADHAMANI
# ASHOK KUMAR.T
# S.GANDHINATHAN
# R.Gopalakrishnan
# Jenifer
# R
# NAGARAJ
# Saravanan
# L.Arul karthigeyan
# GOVT HOSPITAL PERIYACKENPALAYA
# VASANTHI
# BHAVANESHWARI .S
# V.ARULPRAKASH
# RAGHAVAN.P
# Thiudiyalur Urban Coop Agricul
# Velumani
# MANONMANI.G

# %%
Agent.objects.all().count()
# Out:
# 1414

# %%
import pandas as pd
import os
from decimal import Decimal
from reportlab.pdfgen import canvas
from reportlab.platypus import BaseDocTemplate, SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.pagesizes import letter
from reportlab.lib.units import inch
from reportlab.lib import colors
from main.pdf_generate import *
from main.temp_pdf_generate import generate_pdf_for_temp_route
import csv

# %%
def findout_tray_count(count, product_defalut_count, product_id):
    loose_milk_ids = [22, 23, 24]
    if not product_defalut_count == 0:
        remainder_of_tray_count = count % product_defalut_count
        coefieient_of_tray_count = count // product_defalut_count
    else:
        remainder_of_tray_count = 0
        coefieient_of_tray_count = 0
    if not remainder_of_tray_count == 0:
        if not product_id in loose_milk_ids:
            if remainder_of_tray_count > (product_defalut_count / 2):
                return coefieient_of_tray_count + 1
            else:
                return coefieient_of_tray_count
        else:
            if remainder_of_tray_count > 0:
                return coefieient_of_tray_count + 1
            else:
                return coefieient_of_tray_count
    else:
        return coefieient_of_tray_count


def findout_packet_count(count, product_defalut_count, product_id):
    loose_milk_ids = [22, 23, 24]
    if not product_id in loose_milk_ids:
        if not product_defalut_count == 0:
            remainder_of_tray_count = count % product_defalut_count
        else:
            remainder_of_tray_count = 0
        if not remainder_of_tray_count == 0:
            if remainder_of_tray_count <= (product_defalut_count / 2):
                return remainder_of_tray_count
            else:
                return 0
        else:
            return remainder_of_tray_count
    else:
        return 0


def findout_packet_count_in_negative(count, product_defalut_count, tray_count, product_id):
    loose_milk_ids = [22, 23, 24]
    if not tray_count == 0:
        if not product_defalut_count == 0:
            remainder_of_tray_count = count % product_defalut_count
            # coefieient_of_tray_count = count // product_defalut_count
        else:
            remainder_of_tray_count = 0
            # coefieient_of_tray_count = 0
        if not product_id in loose_milk_ids:
            if remainder_of_tray_count > (product_defalut_count / 2):
                return product_defalut_count - remainder_of_tray_count
            else:
                return 0
        else:
            if not remainder_of_tray_count == 0:
                return product_defalut_count - remainder_of_tray_count
            else:
                return 0
    else:
        return 0


def find_leak_packet_percentage(product_id, leak_percentage, count):
    milk_product_ids = list(Product.objects.filter(group_id__in=[1, 3], is_active=True).values_list('id', flat=True))
    if product_id in milk_product_ids:
        return leak_percentage * count
    else:
        return 0


def gatepass_data_for_temp_route(route_id, date, session_id, business_id):
    route_id = route_id
    # date = datetime.datetime.strptime(request.data['date'], '%m/%d/%Y')
    date = date
    session_id = session_id
    data = {
        'route_supervisor': '',
        'route_name': '',
        'date': '',
        'vehicle_number': '',
        'session': '',
        'sales': {},
        'milk': {},
        'fermented': {},
        'other': {}
    }
    # get vehicle details
    data['vehicle_number'] = RouteVehicleMap.objects.get(route_id=route_id).vehicle.licence_number
    data['route_supervisor'] = RouteVehicleMap.objects.get(route_id=route_id).vehicle.driver_name
    data['date'] = date
    data['session'] = Session.objects.get(id=session_id).display_name

    route = Route.objects.get(id=route_id)
    leak_percentage = route.leak_packet_in_percentage
    data['route_name'] = route.name
    business_ids = [business_id]
    sale_group = SaleGroup.objects.filter(business_id__in=business_ids, date=date, session_id=session_id)
    sale_values = Sale.objects.filter(sale_group__in=sale_group,  product__is_active=True).values_list('product_id', 'count')
    sale_columns = ['product_id', 'count']
    sale_df = pd.DataFrame(list(sale_values), columns=sale_columns)

    icustomer_sale_group = ICustomerSaleGroup.objects.filter(business_id__in=business_ids, date__month=date.month,
                                                             date__year=date.year, session_id=session_id)
    icustomer_sale_values = ICustomerSale.objects.filter(icustomer_sale_group__in=icustomer_sale_group, product__is_active=True).values_list(
        'product_id', 'count')
    icustomer_sale_columns = ['product_id', 'count']
    icustomer_sale_df = pd.DataFrame(list(icustomer_sale_values), columns=icustomer_sale_columns)

    combined_df = sale_df.append(icustomer_sale_df)

    product_values = Product.objects.filter(is_active=True).order_by('display_ordinal').values_list('id', 'short_name',
                                                                                                    'unit', 'quantity')
    product_columns = ['id', 'product_short_name', 'unit', 'quantity']
    product_df = pd.DataFrame(list(product_values), columns=product_columns)

    if not combined_df.empty:
        total_sale_df = combined_df.groupby(['product_id'])['count'].sum().reset_index()
        # data['sales'] = dict(zip(total_sale_df['product_id'], total_sale_df['count']))
        merged_df = pd.merge(total_sale_df, product_df, how='left', left_on='product_id', right_on='id')

        # find litre
        data['sales'] = merged_df.groupby('id').apply(lambda x: x.to_dict('r')[0]).to_dict()
        milk_product_ids = list(Product.objects.filter(group_id__in=[1, 3], is_active=True).values_list('id', flat=True))
        curd_product_ids = list(Product.objects.filter(group_id__in=[2], is_active=True).values_list('id', flat=True))
        # find milk total and net total
        data['milk_total_count'] = merged_df[merged_df['id'].isin(milk_product_ids)]['count'].sum()
        data['net_total_count'] = merged_df['count'].sum()

        # find tray count and pocket count
        tray_config_values = ProductTrayConfig.objects.filter(product__is_active=True).values_list('product_id', 'tray_count', 'product_count')
        tray_config_columns = ['product_id', 'p_c_tray_count', 'p_c_product_count']
        tray_config_df = pd.DataFrame(list(tray_config_values), columns=tray_config_columns)
        tray_config_merge_df = pd.merge(merged_df, tray_config_df, how='left', left_on='id', right_on='product_id')

        # finding the tray count based on the defalut product tray count
        tray_config_merge_df['calculated_tray_count'] = tray_config_merge_df.apply(
            lambda x: findout_tray_count(x['count'], x['p_c_product_count'], x['id']), axis=1)
        tray_config_merge_df['calculated_pocket_count'] = tray_config_merge_df.apply(
            lambda x: findout_packet_count(x['count'], x['p_c_product_count'], x['id']), axis=1)
        tray_config_merge_df['calculated_pocket_count_in_negative'] = tray_config_merge_df.apply(
            lambda x: findout_packet_count_in_negative(x['count'], x['p_c_product_count'], x['calculated_tray_count'],
                                                       x['id']), axis=1)
        tray_config_merge_df = tray_config_merge_df.fillna(0)

        # choose coloumn
        tray_config_merge_df = tray_config_merge_df[
            ['id', 'count', 'quantity', 'calculated_tray_count', 'calculated_pocket_count', 'product_short_name',
             'calculated_pocket_count_in_negative']]
        # tray_config_merge_df['leak_packet'] = ((float(leak_percentage) / 100) * tray_config_merge_df['count'])
        tray_config_merge_df['count'] = tray_config_merge_df['count'].astype(int)
        tray_config_merge_df['leak_packet'] = tray_config_merge_df.apply(
            lambda x: find_leak_packet_percentage(x['id'], leak_percentage, x['count']), axis=1)

        # Check 80 pockets for routes
        allowance_business_ids = list(
            BusinessWiseLeakageAllowanceAsPacket.objects.filter(session_id=route.session_id, product__is_active=True).values_list('business_id', flat=True))
        if RouteBusinessMap.objects.filter(route_id=route.id, business_id__in=allowance_business_ids).exists():
            route_business_ids = list(
                RouteBusinessMap.objects.filter(route_id=route.id).values_list('business_id', flat=True))
            allowance_business_obj = BusinessWiseLeakageAllowanceAsPacket.objects.filter( product__is_active=True,
                business_id__in=route_business_ids)
            for allowance_business in allowance_business_obj:
                if not len(tray_config_merge_df[tray_config_merge_df['id'] == allowance_business.product.id]) == 0:
                    tray_config_merge_df.loc[
                        tray_config_merge_df['id'] == allowance_business.product.id, 'leak_packet'] = \
                        tray_config_merge_df['leak_packet'] + allowance_business.packet_count
                else:
                    new_list = [allowance_business.product.id, '0', allowance_business.product.quantity, '0', '0',
                                allowance_business.product.short_name, '0', allowance_business.packet_count]
                    to_index = len(tray_config_merge_df)
                    tray_config_merge_df.loc[to_index] = new_list

        tray_config_merge_df['leak_packet'] = tray_config_merge_df['leak_packet'].astype(int)
        tray_config_merge_df['litre'] = (tray_config_merge_df['quantity'] / 1000) * (
                    tray_config_merge_df['count'] + tray_config_merge_df['leak_packet'])
        tray_config_merge_df['calculated_tray_count'] = tray_config_merge_df['calculated_tray_count'].astype(int)
        tray_config_merge_df['calculated_pocket_count'] = tray_config_merge_df['calculated_pocket_count'].astype(int)
        tray_config_merge_df['calculated_pocket_count_in_negative'] = tray_config_merge_df[
            'calculated_pocket_count_in_negative'].astype(int)
        tray_config_merge_df['leak_packet'] = tray_config_merge_df['leak_packet'].astype(int)

        # make total count
        data['total_product_count'] = tray_config_merge_df['count'].sum()
        data['total_tray_count'] = tray_config_merge_df['calculated_tray_count'].sum()
        data['total_packet_count'] = tray_config_merge_df['calculated_pocket_count'].sum()
        data['total_packet_count_in_negative'] = tray_config_merge_df['calculated_pocket_count_in_negative'].sum()
        data['total_leak_packet_count'] = tray_config_merge_df['leak_packet'].sum()
        data['total_litre_count'] = tray_config_merge_df['litre'].sum()
        data['sales'] = tray_config_merge_df.groupby('id').apply(lambda x: x.to_dict('r')[0]).to_dict()

        # milk product details
        milk_df = tray_config_merge_df[tray_config_merge_df['id'].isin(milk_product_ids)]
        data['milk'] = milk_df.groupby('id').apply(lambda x: x.to_dict('r')[0]).to_dict()
        data['total_milk_product_count'] = milk_df['count'].sum()
        data['total_milk_tray_count'] = milk_df['calculated_tray_count'].sum()
        data['total_milk_packet_count'] = milk_df['calculated_pocket_count'].sum()
        data['total_milk_packet_count_in_negative'] = milk_df['calculated_pocket_count_in_negative'].sum()
        data['total_milk_leak_packet_count'] = milk_df['leak_packet'].sum()
        data['total_milk_litre_count'] = milk_df['litre'].sum()

        # curd product details
        curd_df = tray_config_merge_df[tray_config_merge_df['id'].isin(curd_product_ids)]
        data['curd'] = curd_df.groupby('id').apply(lambda x: x.to_dict('r')[0]).to_dict()
        data['total_curd_product_count'] = curd_df['count'].sum()
        df_without_cup_curd = curd_df[curd_df['id'] != 10]
        data['total_curd_tray_count'] = df_without_cup_curd['calculated_tray_count'].sum()
        data['total_curd_packet_count'] = curd_df['calculated_pocket_count'].sum()
        data['total_curd_packet_count_in_negative'] = curd_df['calculated_pocket_count_in_negative'].sum()
        data['total_curd_leak_packet_count'] = curd_df['leak_packet'].sum()
        data['total_curd_litre_count'] = curd_df['litre'].sum()

        other_df = tray_config_merge_df[~tray_config_merge_df['id'].isin(milk_product_ids)]
        other_df = other_df.fillna(0)
        data['other'] = other_df.groupby('id').apply(lambda x: x.to_dict('r')[0]).to_dict()
    return data


def route_wise_business_data(route_id, session_id, selected_date, buiness_id):
    route_id = route_id
    session_id = session_id
    selected_date = selected_date
    selected_month = selected_date.month
    selected_year = selected_date.year
    business_ids = [buiness_id]
    sales_values = Sale.objects.filter(sale_group__business_id__in=business_ids, sale_group__session_id=session_id, product__is_active=True,
                                       sale_group__date=selected_date).values_list('id', 'sale_group_id', 'count',
                                                                                   'cost', 'product_id',
                                                                                   'product__name',
                                                                                   'sale_group__session_id',
                                                                                   'sale_group__business_id',
                                                                                   'sale_group__business__business_type_id',
                                                                                   'sale_group__business__business_type__name')
    sales_column = ['id', 'sale_group_id', 'count', 'cost', 'product_id', 'product_name', 'session_id', 'business_id',
                    'business_type_id', 'business_type']
    sales_df = pd.DataFrame(list(sales_values), columns=sales_column)

    # serve customer order based on the business ids
    icustomer_sale_obj = ICustomerSale.objects.filter(icustomer_sale_group__date__month=selected_month,
                                                      icustomer_sale_group__date__year=selected_year,product__is_active=True,
                                                      icustomer_sale_group__business_id__in=business_ids,
                                                      icustomer_sale_group__session_id=session_id)
    icustomer_sale_list = list(
        icustomer_sale_obj.values_list('id', 'icustomer_sale_group_id', 'count', 'cost', 'product_id', 'product__name',
                                       'icustomer_sale_group__session_id', 'icustomer_sale_group__business_id',
                                       'icustomer_sale_group__business__business_type_id',
                                       'icustomer_sale_group__business__business_type__name'))
    icustomer_sale_column = ['id', 'sale_group_id', 'count', 'cost', 'product_id', 'product_name', 'session_id',
                             'business_id', 'business_type_id', 'business_type']
    icustomer_sale_df = pd.DataFrame(icustomer_sale_list, columns=icustomer_sale_column)

    # merge icustomer sale with business sale
    final_df = sales_df.merge(icustomer_sale_df, how="outer")
    vehicle_data = RouteVehicleMap.objects.get(route_id=route_id)

    agents_values = BusinessAgentMap.objects.filter(business_id__in=business_ids).values_list('business_id',
                                                                                              'business__code',
                                                                                              'agent__first_name',
                                                                                              'agent__last_name',
                                                                                              'agent__agent_profile__mobile',
                                                                                              'agent__agent_code')
    agent_columns = ['business_id', 'business_code', 'agent_first_name', 'agent_last_name', 'agent_mobile',
                     'agent_code']
    agent_df = pd.DataFrame(list(agents_values), columns=agent_columns)

    business_agent_df = pd.merge(final_df, agent_df, left_on='business_id', right_on='business_id', how='left')
    business_agent_df = business_agent_df.fillna(0)

    products = Product.objects.filter(is_active=True).order_by('id')
    route_wise_data = {
        'booth_types': {},
        'route_name': Route.objects.get(id=route_id).name,
        'vehicle_number': vehicle_data.vehicle.licence_number,
        'session_name': Session.objects.get(id=session_id).display_name,
        'total': {}
    }
    for product in products:
        route_wise_data['total'][product.id] = final_df[final_df['product_id'] == product.id].sum()['count']
    for index, row in business_agent_df.iterrows():
        if not row['business_type_id'] in route_wise_data['booth_types']:
            route_wise_data['booth_types'][row['business_type_id']] = {}
            route_wise_data['booth_types'][row['business_type_id']]['booth_ids'] = []
        if not row['business_id'] in route_wise_data['booth_types'][row['business_type_id']]:
            route_wise_data['booth_types'][row['business_type_id']][row['business_id']] = {}
            route_wise_data['booth_types'][row['business_type_id']]['booth_ids'].append(row['business_id'])
            route_wise_data['booth_types'][row['business_type_id']][row['business_id']]['agent_name'] = row[
                'agent_first_name']
            route_wise_data['booth_types'][row['business_type_id']][row['business_id']]['business_code'] = row[
                'business_code']
            route_wise_data['booth_types'][row['business_type_id']][row['business_id']]['product'] = {}

        if not row['product_id'] in route_wise_data['booth_types'][row['business_type_id']][row['business_id']][
            'product']:
            route_wise_data['booth_types'][row['business_type_id']][row['business_id']]['product'][
                row['product_id']] = 0
        route_wise_data['booth_types'][row['business_type_id']][row['business_id']]['product'][row['product_id']] += \
            row['count']

    return route_wise_data


def get_business_ids(route_id, session_id, date):
    # return ordered_business
    business_ids = list(RouteBusinessMap.objects.filter(route_id=route_id).values_list('business_id', flat=True))
    ordered_business = list(
        SaleGroup.objects.filter(business_id__in=business_ids, date=date, session_id=session_id).values_list(
            'business_id', flat=True))
    selected_date = date
    ordered_business_for_icustomer = list(
        ICustomerSaleGroup.objects.filter(business_id__in=business_ids, date__month=selected_date.month,
                                          date__year=selected_date.year, session_id=session_id).values_list(
            'business_id', flat=True))
    return list(set(ordered_business + ordered_business_for_icustomer))


def find_tray_count_for_indivioul_business(agent_count, icustomer_count, product_defalut_count, tray_count, product_id):
    count = agent_count + icustomer_count
    loose_milk_ids = [22, 23, 24]
    if not product_defalut_count == 0:
        remainder_of_tray_count = count % product_defalut_count
        coefieient_of_tray_count = count // product_defalut_count
        if not product_id in loose_milk_ids:
            tray_count = (count / product_defalut_count) * tray_count
            return tray_count
        else:
            if remainder_of_tray_count > 0:
                return coefieient_of_tray_count + 1
            else:
                return coefieient_of_tray_count
    else:
        return 0


def find_packet_count_for_indivioul_business(agent_count, icustomer_count, product_defalut_count, product_id):
    loose_milk_ids = [22, 23, 24]
    count = agent_count + icustomer_count
    if not product_id in loose_milk_ids:
        if not product_defalut_count == 0:
            packet_count = count % product_defalut_count
            return packet_count
        else:
            return 0
    else:
        return 0


def get_individual_business_data(business_id, session_id, date):
    product_values = Product.objects.filter(is_active=True).values_list('id', 'short_name', 'unit__name', 'quantity')
    product_columns = ['id', 'product_short_name', 'product_unit', 'quantity']
    product_df = pd.DataFrame(list(product_values), columns=product_columns)
    tray_config_values = ProductTrayConfig.objects.filter(product__is_active=True).values_list('product_id', 'tray_count', 'product_count')
    tray_config_columns = ['tray_product_id', 'p_c_tray_count', 'p_c_product_count']
    tray_config_df = pd.DataFrame(list(tray_config_values), columns=tray_config_columns)
    tray_config_df = tray_config_df.fillna(0)
    product_tray_merge_df = pd.merge(product_df, tray_config_df, how='left', left_on='id', right_on='tray_product_id')
    product_tray_merge_df = product_tray_merge_df.fillna(0)
    # business_code = request.data['business_code']
    business = Business.objects.get(id=business_id)
    session_id = session_id
    date = date
    month = date.month
    year = date.year
    # date = date.strftime("%Y-%m-%d")
    route = RouteBusinessMap.objects.get(business=business, route__session_id=session_id).route
    agent = BusinessAgentMap.objects.filter(business=business)[0].agent
    session = Session.objects.get(id=session_id)
    data = {
        'agent_first_name': agent.first_name,
        'agent_last_name': agent.last_name,
        'agent_code': agent.agent_code,
        'route_name': route.name,
        'date': date,
        'session': session.display_name,
        'business_code': business.code,
        'no': '232423',
        'total_cost': None,
        'sales': None
    }
    sale_group = SaleGroup.objects.filter(date=date, session_id=session_id, business_id=business_id)
    # business_sale_group = sale_group[0]
    sales_values = Sale.objects.filter(sale_group__in=sale_group,  product__is_active=True).values_list('sale_group', 'product_id', 'count')
    sales_columns = ['sale_group_id', 'product_id', 'count']
    sale_df = pd.DataFrame(list(sales_values), columns=sales_columns)
    sale_df = sale_df.fillna(0)
    data['total_cost'] = sale_group.aggregate(Sum('total_cost'))['total_cost__sum']
    final_df = pd.merge(sale_df, product_tray_merge_df, how='left', left_on='product_id', right_on='id')
    final_df = final_df.fillna(0)
    business_df = final_df

    icustomer_sale_obj = ICustomerSale.objects.filter(icustomer_sale_group__date__month=month,
                                                      icustomer_sale_group__date__year=year,
                                                      icustomer_sale_group__session_id=session_id,product__is_active=True,
                                                      icustomer_sale_group__business_id=business_id)
    icustomer_sales_values = list(icustomer_sale_obj.values_list('icustomer_sale_group', 'product_id', 'count',
                                                                 'icustomer_sale_group__icustomer'))
    icustomer_sales_columns = ['icustomer_sale_group_id', 'product_id', 'indivioul_icustomer_count', 'icustomer_id']
    icustomer_sale_df = pd.DataFrame(icustomer_sales_values, columns=icustomer_sales_columns)
    icustomer_sale_df['icustomer_count'] = icustomer_sale_df.groupby(['product_id'])[
        'indivioul_icustomer_count'].transform('sum')
    icustomer_sale_df = icustomer_sale_df.drop_duplicates(subset=['product_id'], keep="first")
    icustomer_sale_df = icustomer_sale_df.fillna(0)
    icustomer_sale_df = pd.merge(icustomer_sale_df, product_tray_merge_df, how='left', left_on='product_id',
                                 right_on='id')

    # construct business sale df
    new_df = pd.merge(business_df, icustomer_sale_df, how='outer',
                      left_on=['id', 'product_short_name', 'p_c_product_count', 'p_c_tray_count', 'product_unit'],
                      right_on=['id', 'product_short_name', 'p_c_product_count', 'p_c_tray_count', 'product_unit'])
    new_df = new_df[
        ['id', 'count', 'icustomer_count', 'product_short_name', 'p_c_product_count', 'p_c_tray_count', 'product_unit']]
    new_df['count'] = new_df['count'].fillna(0)
    new_df['icustomer_count'] = new_df['icustomer_count'].fillna(0)
    new_df['count'].astype(int)
    new_df['icustomer_count'].astype(int)
    new_df['calculated_tray_count'] = new_df.apply(
        lambda x: find_tray_count_for_indivioul_business(x['count'], x['icustomer_count'], x['p_c_product_count'],
                                                         x['p_c_tray_count'], x['id']), axis=1)
    new_df['calculated_tray_count'] = new_df['calculated_tray_count'].fillna(0)
    new_df['calculated_tray_count'] = new_df['calculated_tray_count'].astype(int)
    new_df['calculated_pocket_count'] = new_df.apply(
        lambda x: find_packet_count_for_indivioul_business(x['count'], x['icustomer_count'], x['p_c_product_count'],
                                                           x['id']), axis=1)
    new_df['calculated_tray_count'] = new_df['calculated_tray_count'].fillna(0)
    new_df = new_df.fillna(0)
    data['sales'] = new_df.groupby('id').apply(lambda x: x.to_dict('r')[0]).to_dict()
    data['total_business_product_count'] = new_df['count'].sum()
    data['total_icustomer_product_count'] = new_df['icustomer_count'].sum()
    return data

# %%
def generate_pdf_for_temp_route(route_id, session_id, date):
    business_ids = get_business_ids(route_id, session_id, date)
    print(business_ids)
    new_date = datetime.datetime.strftime(date, '%d-%b-%Y')
    directory = 'new'
    session = 'Morning'
    if session_id == 2:
        session = 'Evening'

    file_name = str(date) + '_' + str(route_id) + '_' + str(session) + '.pdf'

    try:
        path = os.path.join('static/media/indent_document/', str(date), session, str(route_id))
        os.makedirs(path)
    except FileExistsError:
        print('already created')
    file_path = os.path.join('static/media/indent_document/' + str(date) + '/' + session + '/' + str(route_id) + '/',
                             file_name)
    mycanvas = canvas.Canvas(file_path, pagesize=A4)

    #     #     -------------------------first page -------------------
    for temp_route_index, business in enumerate(business_ids, start=1):
        data = gatepass_data_for_temp_route(route_id, date, session_id, business)
        business_code = Business.objects.get(id=business).code
        
        prod_ids = data['milk'].keys()

        if 'curd' in data:
            curd_ids = data['curd'].keys()
        else:
            curd_ids = []
        y_axis = 0
        y_for_table2 = 10
        new_y_axis = 0
        loose_milk_ids = [22, 23, 24]
        last_count_for_gate_pass = IndentCodeBank.objects.get(code_for='gate_pass')
        serial_number = int(last_count_for_gate_pass.last_code) + 1
        if serial_number == 999999:
            last_count_for_gate_pass.last_code = 0
        else:
            last_count_for_gate_pass.last_code = serial_number
        last_count_for_gate_pass.save()
       
        x_adjust = 15
        for i in range(2):
            net_total_count = 0
            net_total_tray_count = 0
            net_total_packet_positive_count = 0
            net_total_packet_negative_count = 0
            net_total_packet_negative_count = 0
            net_total_leak_packet_count = 0
            if not i == 0:
                y_for_table2 = y_axis - 110

            mycanvas.setStrokeColor(colors.lightgrey)

            route_supervisor = data['route_supervisor']
            route_date = datetime.datetime.strftime(data['date'], '%d-%m-%Y')
            session_name = data['session']
            route_name = data['route_name']
            vehicle_number = data['vehicle_number']
            mycanvas.setStrokeColor(colors.lightgrey)
            mycanvas.setFont('Helvetica', 12.6)
            mycanvas.drawString(10, 820 - y_for_table2,
                                       'The Coimbatore District Co-Operative Milk Producers Union Ltd, Pachapalayam, Coimbatore - 641 010')
            mycanvas.setFont('Helvetica', 12)

            mycanvas.drawCentredString(300, 800 - y_for_table2, 'DAIRY GATEPASS FOR MILK')
            mycanvas.setFont('Helvetica', 12)
            mycanvas.line(200, 795 - y_for_table2, 390, 795 - y_for_table2)

            # row 1
            mycanvas.drawCentredString(290, 775 - y_for_table2, 'S.NO.' + ' ' + ':' + ' ' + str(serial_number) + "  |  "+'DATE ' + ':' + ' ' + str(route_date) + ' ' + '/' + ' ' + (session_name) +"  |  "+'ROUTE ' + ' ' + ':' + ' ' + str(route_name) + '(' + str(business_code)+ ") |  "+'VEHICLE ' + ' ' + ':' + ' ' + str(vehicle_number))
            y_for_table2 -= 20
            # ------------table header----------
            mycanvas.line(10+ x_adjust, 725 - y_for_table2, 555+ x_adjust, 725 - y_for_table2)
            mycanvas.setFont('Helvetica', 13)
            mycanvas.line(10+ x_adjust, 685 - y_for_table2+15, 555+ x_adjust, 685 - y_for_table2+15)

            # ----------table heading-----------
            # sl.no
            mycanvas.drawString(20+ x_adjust, 698 - y_for_table2+10, 'S.No')
            mycanvas.drawString(100+ x_adjust, 698 - y_for_table2+10, 'Products')
            mycanvas.drawString(180+ x_adjust, 698 - y_for_table2+10, 'Packet')

            mycanvas.drawString(235+ x_adjust, 698 - y_for_table2+10, 'Tray/can')

            mycanvas.drawString(300+ x_adjust, 698 - y_for_table2+10, 'Pkt(+)')
            mycanvas.drawString(360+ x_adjust, 698 - y_for_table2+10, 'Pkt(-)')

            mycanvas.drawString(420+ x_adjust, 698 - y_for_table2+10, 'Leak')

            mycanvas.drawString(480+ x_adjust, 698 - y_for_table2+10, 'Qty (Ltr)')


            # horizontal lines
            y_axis = 680 - y_for_table2
            end_axis = 648 - y_for_table2
            last_index = 0
            mycanvas.setFont('Helvetica', 12)
            for index, prod_id in enumerate(prod_ids, start=1):
                # sl.no
                mycanvas.drawString(30+ x_adjust, y_axis, str(index))
                # item particulars data
                mycanvas.drawString(95+ x_adjust, y_axis, str(data['milk'][prod_id]['product_short_name']))
                if not prod_id in loose_milk_ids:
                    mycanvas.drawRightString(220+ x_adjust, y_axis, str(data['milk'][prod_id]['count']))
                else:
                    mycanvas.drawRightString(220+ x_adjust, y_axis, str(str(data['milk'][prod_id]['count']) + 'L'))
                # tray data
                if not data['milk'][prod_id]['calculated_tray_count'] == 0:
                    mycanvas.drawRightString(280+ x_adjust, y_axis, str(data['milk'][prod_id]['calculated_tray_count']))
                # pkt
                if not data['milk'][prod_id]['calculated_pocket_count'] == 0:
                    mycanvas.drawRightString(335 + x_adjust, y_axis, str(data['milk'][prod_id]['calculated_pocket_count']))
                if not data['milk'][prod_id]['calculated_pocket_count_in_negative'] == 0:
                    mycanvas.drawRightString(380 + x_adjust, y_axis, str(-data['milk'][prod_id]['calculated_pocket_count_in_negative']))
                # leak pkt  
                if not data['milk'][prod_id]['leak_packet'] == 0:
                    mycanvas.drawRightString(425 + x_adjust, y_axis, str(data['milk'][prod_id]['leak_packet']))
                # qty of milk
                mycanvas.drawRightString(540 + x_adjust, y_axis, str(data['milk'][prod_id]['litre']))
                last_index = index

                y_axis -= 15
                end_axis -= 15

            # After Milk entry line
            mycanvas.line(10 + x_adjust, int(y_axis + 12), 555 + x_adjust, int(y_axis + 12))
            mycanvas.setFont('Helvetica', 13)
            mycanvas.drawString(95 + x_adjust, y_axis - 3, 'Milk Total')

            mycanvas.setFont('Helvetica', 12)
            mycanvas.drawRightString(220 + x_adjust, y_axis - 3, str(int(data['milk_total_count'])))
            if not data['total_milk_tray_count'] == 0:
                mycanvas.drawRightString(280 + x_adjust, y_axis - 3, str(data['total_milk_tray_count']))
            if not data['total_milk_packet_count'] == 0:
                mycanvas.drawRightString(335 + x_adjust, y_axis - 3, str(data['total_milk_packet_count']))
            if not data['total_milk_packet_count_in_negative'] == 0:
                mycanvas.drawRightString(380 + x_adjust, y_axis - 3, str(-data['total_milk_packet_count_in_negative']))
            if not data['total_milk_leak_packet_count'] == 0:
                mycanvas.drawRightString(455 + x_adjust, y_axis - 3, str(data['total_milk_leak_packet_count']))
            mycanvas.drawRightString(540 + x_adjust, y_axis - 3, str(data['total_milk_litre_count']))

            # After Milk total line
            mycanvas.line(10 + x_adjust, int(y_axis - 10), 555+15, int(y_axis - 10))

            y_axis -= 20
            mycanvas.setFont('Helvetica', 12)
            if data['total_curd_product_count'] != 0:
                for c_index, curd_id in enumerate(curd_ids, start=last_index):
                    mycanvas.drawString(30 + x_adjust, y_axis - 10, str(c_index + 1))
                    mycanvas.drawString(95 + x_adjust, y_axis - 10, str(data['curd'][curd_id]['product_short_name']))
                    mycanvas.drawRightString(220 + x_adjust, y_axis - 10, str(data['curd'][curd_id]['count']))
                    if not data['curd'][curd_id]['calculated_tray_count'] == 0:
                        mycanvas.drawRightString(280 + x_adjust, y_axis - 10, str(data['curd'][curd_id]['calculated_tray_count']))
                    if not data['curd'][curd_id]['calculated_pocket_count'] == 0:
                        mycanvas.drawRightString(335 + x_adjust, y_axis - 10, str(data['curd'][curd_id]['calculated_pocket_count']))
                    if not data['curd'][curd_id]['calculated_pocket_count_in_negative'] == 0:
                        mycanvas.drawRightString(380 + x_adjust, y_axis - 10,
                                            str(-data['curd'][curd_id]['calculated_pocket_count_in_negative']))
                    if not data['curd'][curd_id]['leak_packet'] == 0:
                        mycanvas.drawRightString(425 + x_adjust, y_axis - 10, str(data['curd'][curd_id]['leak_packet']))

                    mycanvas.drawRightString(540 + x_adjust, y_axis - 10, str(data['curd'][curd_id]['litre']))
                    y_axis -= 15
                    end_axis -= 10

                mycanvas.setFont('Helvetica', 12)
                # Above Curd total
                mycanvas.line(10 + x_adjust, int(y_axis), 555+15, int(y_axis + 3))
                #     y_axis -= 20
                #     end_axis -= 15
                mycanvas.drawString(95 + x_adjust, int(y_axis) - 15, str('Curd Total'))
                mycanvas.drawRightString(220 + x_adjust, int(y_axis) - 15, str(data['total_curd_product_count']))
                if not data['total_curd_tray_count'] == 0:
                    mycanvas.drawRightString(280 + x_adjust, int(y_axis) - 15, str(data['total_curd_tray_count']))
                if not data['total_curd_packet_count'] == 0:
                    mycanvas.drawRightString(335 + x_adjust, int(y_axis) - 15, str(data['total_curd_packet_count']))
                if not data['total_curd_packet_count_in_negative'] == 0:
                    mycanvas.drawRightString(380 + x_adjust, y_axis - 15, str(-data['total_curd_packet_count_in_negative']))
                if not data['total_curd_leak_packet_count'] == 0:
                    mycanvas.drawRightString(425 + x_adjust, int(y_axis) - 15, str(data['total_curd_leak_packet_count']))

                mycanvas.drawRightString(540 + x_adjust, int(y_axis) - 15, str(data['total_curd_litre_count']))

                end_axis = end_axis - 40
                # --------lines--------
                # end line
                mycanvas.line(10 + x_adjust, int(end_axis + 5)+15, 555 + x_adjust, int(end_axis + 5)+15)

            # Net total
            mycanvas.setFont('Helvetica', 12)
            mycanvas.drawString(95 + x_adjust, int(end_axis) , str('Net Total'))
            net_total_count = data['milk_total_count'] + data['total_curd_product_count']
            mycanvas.drawRightString(220 + x_adjust, int(end_axis) , str(int(net_total_count)))
            net_total_tray_count = data['total_milk_tray_count'] + data['total_curd_tray_count']
            mycanvas.drawRightString(280 + x_adjust, int(end_axis) , str(net_total_tray_count))
            net_total_packet_positive_count = data['total_milk_packet_count'] + data['total_curd_packet_count']
            mycanvas.drawRightString(335 + x_adjust, int(end_axis) , str(net_total_packet_positive_count))
            net_total_packet_negative_count = data['total_milk_packet_count_in_negative'] + data[
                'total_curd_packet_count_in_negative']
            mycanvas.drawRightString(380 + x_adjust, int(end_axis) , str(-net_total_packet_negative_count))
            net_total_leak_packet_count = data['total_milk_leak_packet_count'] + data['total_curd_leak_packet_count']

            if not net_total_leak_packet_count == 0:
                mycanvas.drawRightString(425 + x_adjust, int(end_axis), str(net_total_leak_packet_count))
            net_total_litre = data['total_milk_litre_count'] + data['total_curd_litre_count']
            mycanvas.drawRightString(540 + x_adjust, int(end_axis), str(net_total_litre))

            mycanvas.line(10 + x_adjust, int(end_axis - 22)+15, 555 + x_adjust, int(end_axis - 22)+15)

            # right and left border
            mycanvas.line(10 + x_adjust, 715 - y_for_table2+10, 10 + x_adjust, int(end_axis - 22)+15)
            mycanvas.line(555 + x_adjust, 715 - y_for_table2+10, 555 + x_adjust, int(end_axis - 22)+15)

            # data borders
            mycanvas.line(60 + x_adjust, 715 - y_for_table2+10, 60 + x_adjust, int(end_axis - 22)+15)
            mycanvas.line(170 + x_adjust, 715 - y_for_table2+10, 170 + x_adjust, int(end_axis - 22)+15)
            mycanvas.line(230 + x_adjust, 715 - y_for_table2+10, 230 + x_adjust, int(end_axis - 22)+15)
            mycanvas.line(290 + x_adjust, 695 - y_for_table2+30, 290 + x_adjust, int(end_axis - 22)+15)
            mycanvas.line(343 + x_adjust, 695 - y_for_table2+30, 343 + x_adjust, int(end_axis - 22)+15)
            mycanvas.line(405 + x_adjust, 715 - y_for_table2+10, 405 + x_adjust, int(end_axis - 22)+15)
            mycanvas.line(460 + x_adjust, 715 - y_for_table2+10, 460 + x_adjust, int(end_axis - 22)+15)

            mycanvas.setFont('Helvetica', 13)
            y_axis = y_axis - 40
            mycanvas.drawString(10 + x_adjust, int(end_axis - 55)+10, str('Dist.Assistant/M.M.O.'))
            mycanvas.drawString(210 + x_adjust, int(end_axis - 55)+10, str('Counting Officer'))
            mycanvas.drawString(450 + x_adjust, int(end_axis - 55)+10, str('Route Supervisor'))
            test = end_axis - 25

            if i == 0:
                mycanvas.setDash(4,2)
                mycanvas.line(5,y_axis-120,600,y_axis-120)
                mycanvas.setDash(10,0)

    #         if not i == 1:
    #             if test < 600:
    #                 mycanvas.showPage()
        new_y_axis = y_axis

        #    -------------------------second page -------------------
        route_wise_data = route_wise_business_data(route_id, session_id, date,business)
        mycanvas.showPage()
        #     mycanvas.setLineWidth(0)
        mycanvas.setStrokeColor(colors.lightgrey)
        # HEADER
        mycanvas.setFont('Helvetica', 12)
        mycanvas.drawString(20, 800, 'The Coimbatore District Co-Operative Milk Producers Union Ltd, Pachapalayam, Coimbatore - 641 010')
        mycanvas.setFont('Helvetica', 12)
        mycanvas.drawCentredString(300, 785, 'ROUTEWISE MILK DISTRIBUTION STATEMENT')
        mycanvas.line(170, 782, 410, 782)
        # basic head
        # row 1
        #     get the last count number
        last_count_for_route_wise_business = IndentCodeBank.objects.get(code_for='route_wise_business')
        indent_number = int(last_count_for_route_wise_business.last_code) + 1
       
        if indent_number == 999999:
            last_count_for_route_wise_business.last_code = 0
        else:
            last_count_for_route_wise_business.last_code = indent_number
        last_count_for_route_wise_business.save()
        page_number = 1
        route_name = route_wise_data['route_name']
        vehicle_number = route_wise_data['vehicle_number']
        mycanvas.setFont('Helvetica', 12)
        mycanvas.drawCentredString(290, 760, 'No.' + ' ' + ':' + ' ' + str(indent_number) +"  |  "+'Route ' + ' ' + ':' + ' ' + str(route_name) + '(' + str(business_code)+ ") |  " + 'Vehicle ' + ' ' + ':' + ' ' + str(vehicle_number) +"  |  "+'Date ' + ':' + ' ' + str(route_date) + ' ' + '/' + ' ' + (session_name))

        x_ad = 4
        # # ----------table heading-----------
        mycanvas.setFont('Helvetica', 9)
        mycanvas.drawString(10-x_ad, 665+60, 'S.No')
        mycanvas.drawString(35-x_ad, 665+60, 'Booth')
        mycanvas.drawString(70-x_ad, 665+60, 'Agent')
        mycanvas.drawString(110-x_ad, 665+60,'Type')
        # product name on heading
        product_x_axis = 133
        line_product_x_axis = 144
        products = Product.objects.filter(is_active=True).order_by('display_ordinal')
        for product in products:
            # product short name
            if product.short_name == 'CBUK' or product.short_name == 'FMcan' or product.short_name == 'SMcan':
                mycanvas.drawString(product_x_axis-x_ad, 665+60, str(product.short_name[:6]))
            else:
                mycanvas.drawString(product_x_axis+9-x_ad, 670+60, str(product.short_name[:-4]))
                mycanvas.drawString(product_x_axis+9-x_ad, 660+60, str(product.short_name[-4:]))


            #     mycanvas.line(line_product_x_axis, 68, line_product_x_axis, 100)
            product_x_axis += 36
            line_product_x_axis += 38

        # ------------table header----------
        # table head up line
        mycanvas.line(10-x_ad, 680+60, product_x_axis -6, 680+60)
        # table head bottom line
        mycanvas.line(10-x_ad, 655+60, product_x_axis - 6, 655+60)

        y_data = 630+60
        #     value_axis = 30
        line_product_x_axis = 165
        serial_number = 1
        page_number = 1
        booth_types = route_wise_data['booth_types'].keys()
        for booth_type_index, booth_type in enumerate(booth_types, start=1):
            for booth_index, business in enumerate(route_wise_data['booth_types'][booth_type]['booth_ids'], start=1):
                value_axis = 162
                mycanvas.setFont('Helvetica', 10)
                mycanvas.drawString(12-x_ad, y_data, str(serial_number))
                mycanvas.drawString(37-x_ad, y_data,
                                    str(route_wise_data['booth_types'][booth_type][business]['business_code']))
                mycanvas.setFont('Helvetica', 10)
                mycanvas.drawString(65-x_ad, y_data,
                                    str(route_wise_data['booth_types'][booth_type][business]['agent_name'][:5]).lower())
                mycanvas.setFont('Helvetica', 10)

                booth = BusinessType.objects.get(id=booth_type).name
                booth_srt = ''
                if booth == 'Booth':
                    booth_srt = 'BO'
                if booth == 'Parlour' or booth == "Own parlour":
                    booth_srt = "UNI"
                if booth == 'Private Institute' or booth == 'Govt Institute':
                    booth_srt = "INS"
                if booth == "Other unions":
                    booth_srt = "O-UNI"
                if booth == "Other State":
                    booth_srt = "O-ST"
                mycanvas.drawCentredString(117-x_ad, y_data-5, str(booth_srt))
                mycanvas.setFont('Helvetica', 10)

                for product in products:
                    if product.id in route_wise_data['booth_types'][booth_type][business]['product']:
                        mycanvas.drawRightString(value_axis-x_ad, y_data, str(
                            int(route_wise_data['booth_types'][booth_type][business]['product'][product.id])))
                    value_axis = value_axis + 36
                y_data -= 25
                value_axis = 160
                mycanvas.line(line_product_x_axis-x_ad, 300, line_product_x_axis-x_ad, 300)
                line_product_x_axis += 35


                if serial_number % 25 == 0:
                    page_number += 1
                    mycanvas.line(2, 680+60, 3, y_data)
                    mycanvas.line(29, 680+60, 29, y_data)
                    mycanvas.line(59, 680+60, 59, y_data)
                    mycanvas.line(93, 680+60, 93, y_data)
                    x_data = 132

                    for product in products:
                        # line after short name of the product
                        mycanvas.line(x_data-x_ad, 680+60, x_data, y_data)
                        x_data += 36

                    # line after 1st page
                    mycanvas.line(10, y_data, x_data, y_data)

                    # neext
                    mycanvas.showPage()
                    mycanvas.setStrokeColor(colors.lightgrey)

                    # HEADER
                    mycanvas.setFont('Helvetica', 12)
                    mycanvas.drawString(20, 800, 'The Coimbatore District Co-Operative Milk Producers Union Ltd, Pachapalayam, Coimbatore - 641 010')
                    mycanvas.setFont('Helvetica', 12)
                    mycanvas.drawCentredString(300, 785, 'ROUTEWISE MILK DISTRIBUTION STATEMENT')
                    mycanvas.line(170, 782, 410, 782)
                    # basic head
                    # row 1
                    indent_number = 8468
                    page_number = page_number
                    route_name = route_wise_data['route_name']
                    vehicle_number = route_wise_data['vehicle_number']

                    mycanvas.setFont('Helvetica', 12)
                    mycanvas.drawCentredString(290, 760, 'No.' + ' ' + ':' + ' ' + str(indent_number) +"  |  "+'Route ' + ' ' + ':' + ' ' + str(route_name) + "  |  " + 'Vehicle ' + ' ' + ':' + ' ' + str(vehicle_number) +"  |  "+'Date ' + ':' + ' ' + str(route_date) + ' ' + '/' + ' ' + (session_name))

                    x_ad = 4
                    # # ----------table heading-----------
                    mycanvas.setFont('Helvetica', 9)
                    mycanvas.drawString(10-x_ad, 665+60, 'S.No')
                    mycanvas.drawString(35-x_ad, 665+60, 'Booth')
                    mycanvas.drawString(70-x_ad, 665+60, 'Agent')
                    mycanvas.drawString(110-x_ad, 665+60,'Type')
                    # product name on heading
                    product_x_axis = 133
                    line_product_x_axis = 144
                    products = Product.objects.filter(is_active=True).order_by('display_ordinal')
                    for product in products:
                        # product short name
                        if product.short_name == 'CBUK' or product.short_name == 'FMcan' or product.short_name == 'SMcan':
                            mycanvas.drawString(product_x_axis-x_ad, 665+60, str(product.short_name[:6]))
                        else:
                            mycanvas.drawString(product_x_axis+9-x_ad, 670+60, str(product.short_name[:-4]))
                            mycanvas.drawString(product_x_axis+9-x_ad, 660+60, str(product.short_name[-4:]))


                        #     mycanvas.line(line_product_x_axis, 68, line_product_x_axis, 100)
                        product_x_axis += 36
                        line_product_x_axis += 38

                    # ------------table header----------
                    # table head up line
                    mycanvas.line(10-x_ad, 680+60, product_x_axis -6, 680+60)
                    # table head bottom line
                    mycanvas.line(10-x_ad, 655+60, product_x_axis - 6, 655+60)
                    #  next
                    y_data = 645 + 60
                    value_axis = 162
    #                 line_product_x_axis = 165

                serial_number += 1

        # bottom border
        y_data -= 25
        mycanvas.line(10-x_ad, y_data, product_x_axis - 6, y_data)
        mycanvas.line(10-x_ad, y_data + 25, product_x_axis - 6, y_data + 25)
        mycanvas.setFont('Helvetica', 12)
        mycanvas.drawString(10-x_ad, y_data + 11, str('Grand Total'))
        mycanvas.setFont('Helvetica', 10)
        value_axis = 162

        for product in products:
            if not route_wise_data['total'][product.id] == 0:
                mycanvas.drawRightString(value_axis-x_ad, y_data + 11, str(int(route_wise_data['total'][product.id])))
            value_axis = value_axis + 36

    # lines after products
        x_axis_data = 166
        for product in products:
            mycanvas.line(x_axis_data-x_ad, 680+60, x_axis_data-x_ad, y_data)
            if product == products[0]:
                mycanvas.line(x_axis_data-33-x_ad, 680+60, x_axis_data-33-x_ad, y_data)  
            x_axis_data += 36
        mycanvas.line(5-x_ad, 680+60, 5-x_ad, y_data)
        mycanvas.line(34-x_ad, 680+60, 34-x_ad, y_data+25)
        mycanvas.line(64-x_ad, 680+60, 64-x_ad, y_data+25)
        mycanvas.line(99-x_ad, 680+60, 99-x_ad, y_data)

        #     tray and extra pocket
        y_data = y_data - 25

        mycanvas.drawString(450, y_data-30, str('Route Supervisor'))
       
       
       
 
        #         Third page section
       
        business_data = get_individual_business_data(business, session_id, date)
        last_count_for_business_bill = IndentCodeBank.objects.get(code_for='business_bill')
        bill_number = int(last_count_for_business_bill.last_code) + 1
        if bill_number == 999999:
            last_count_for_business_bill.last_code = 0
        else:
            last_count_for_business_bill.last_code = bill_number
        last_count_for_business_bill.save()
        x_new = 50
        third_y = 400
        mycanvas.setFont('Helvetica', 12)
        mycanvas.drawCentredString(110 + x_new, third_y + 5, str('DCMPU-CBE Delivery Note'))
        mycanvas.setFont('Helvetica', 10)
        mycanvas.drawString(x_new - 40, third_y - 25, str(business_data['route_name']) +"  |  "+str('No' + ':' + str(bill_number)+"  |  "+ str(route_date + '/' + business_data['session'])))
        key_id = list(business_data['sales'].keys())

        mycanvas.drawString(x_new - 40, third_y - 45, str('Booth: ')+str(' ' + business_data['business_code'])+"  |  "+str(business_data['agent_first_name'] + ' ' + business_data['agent_last_name'] + '[' + business_data['agent_code'] + ']'))

        mycanvas.setFont('Helvetica', 10)
        #         mycanvas.drawString(200,third_y-55, str(route_date +'/'+ business_data['session']))
        # loop 1 table top line
        mycanvas.line(x_new - 40, third_y - 65, 300 + x_new-55, third_y - 65)
        # loop 1 line aftr table header
        mycanvas.line(x_new - 40, third_y - 85, 300 + x_new-55, third_y - 85)

        mycanvas.drawString(x_new - 35, third_y - 80, str('No'))

        # product
        mycanvas.drawString(5 + x_new-15, third_y - 80, str('Product'))

        # Cash
        mycanvas.drawString(90 + x_new-40, third_y - 80, str('Cash'))

        # Card
        mycanvas.drawString(145 + x_new-40, third_y - 80, str('Card'))

        # Trays
        mycanvas.drawString(192 + x_new-40, third_y - 80, str('Trays'))

        # pkts
        mycanvas.drawString(250 + x_new-40, third_y - 80, str('Pkts'))

        # order products
#         mycanvas.setFont('Helvetica', 12)
        product_axis = third_y - 100
        for sale_index, sale in enumerate(business_data['sales'], start=1):
            mycanvas.drawString(x_new - 30, product_axis, str(sale_index))
            mycanvas.drawString(x_new -10, product_axis, str(business_data['sales'][sale]['product_short_name']))
            mycanvas.drawRightString(135 + x_new-50, product_axis, str(int(business_data['sales'][sale]['count'])))
            mycanvas.drawRightString(185 + x_new-45, product_axis,
                                     str(int(business_data['sales'][sale]['icustomer_count'])))
            mycanvas.drawRightString(240 + x_new-50, product_axis,
                                     str(int(business_data['sales'][sale]['calculated_tray_count'])))
            mycanvas.drawRightString(295 + x_new-55, product_axis,
                                     str(int(business_data['sales'][sale]['calculated_pocket_count'])))
            product_axis -= 15
        # border
        product_axis += 5
        mycanvas.line(x_new - 40, product_axis - 20, x_new - 40, third_y - 65)
        mycanvas.line(300 + x_new-55, product_axis - 20, 300 + x_new-55, third_y - 65)
        # inner lines
        mycanvas.line(x_new - 40, product_axis, 300 + x_new- 55, product_axis)

        mycanvas.line(x_new-15, product_axis, x_new-15, third_y - 65)
        mycanvas.line(85 + x_new-40, product_axis, 85 + x_new-40, third_y - 65)
        mycanvas.line(140 + x_new-40, product_axis, 140 + x_new-40, third_y - 65)
        mycanvas.line(190 + x_new-40, product_axis, 190 + x_new-40, third_y - 65)
        mycanvas.line(245 + x_new-40, product_axis, 245 + x_new-40, third_y - 65)

        # total
#         mycanvas.setFont('Helvetica', 10)
        mycanvas.drawString(x_new - 35, product_axis - 15, str('Milk(Cash Sales)Rs.'))
        mycanvas.drawString(150 + x_new, product_axis - 15, str(business_data['total_cost']))
        mycanvas.line(x_new - 40, product_axis - 20, 300 + x_new-55, product_axis - 20)

        mycanvas.drawString(100 + x_new, product_axis - 40, str('Receiver\'s Signature'))
        mycanvas.showPage()

    mycanvas.save()
    document = {'pdf_data': {}}
    try:
        image_path = file_path
        with open(image_path, 'rb') as image_file:
            encoded_image = b64encode(image_file.read())
            document['pdf_data']['pdf'] = encoded_image
            document['pdf_data']['path'] = image_path
    except Exception as err:
        print(err)
    return document

date = datetime.datetime.now().date()
date += timedelta(days=1)
generate_pdf_for_temp_route(214, 1, date)
# Out:
# [1804]
# already created
# {'pdf_data': {'pdf': b'...',
#   'path': 'static/media/indent_document/2020-07-23/Morning/214/2020-07-23_214_Morning.pdf'}}
